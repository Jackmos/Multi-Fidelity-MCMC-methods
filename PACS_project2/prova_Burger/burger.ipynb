# %% [markdown]
# # Burger

# %%
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.optimizers import Adam,Nadam,Adamax
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LSTM, Dropout
from sklearn.model_selection import train_test_split
from sklearn.utils import extmath
from module_utils import * 
sys.path.append('../utils')
from Structure2 import *
#######################     CONFIGURATIONS     ##########################
seed = 29
train = True
save = True

# %% [markdown]
# # introduction of the data

# %%
# Functions

# High-fidelity model: exact analytical solution
def u_HF(x, t, re):
  A0 = np.exp(re/8.0)
  return x/(t+1)/(1.0+np.exp(re*(x**2)/(4*t+4))*((t+1)/A0)**0.5)

# Low-fidelity model
def u_LF(x, t, re):
  A0 = np.exp(re/8.0)
  return x/(t+1)/(1.0+np.exp(re*(x)/(4*t+4))*((t+1)/A0)**0.5)

# %%
# DATA

# Space-time discretization
nh, nt = 101, 151
T = 2.
L = 1.
x = np.linspace(0, L, nh) # spatial grid
t = np.linspace(0, T, nt) # timepoints

# Uniform sampling of 20 different reynolds numbers
nre = 20
re_min, re_max = 80, 500
re = np.linspace(0, 1, nre) # we sample in [0,1] in order to work with normalized data

# %%
#split in train/test with 20% data for testing
re_train, re_test = train_test_split(re, test_size=0.2, random_state=seed)
nre_train, nre_test = len(re_train), len(re_test)

# normalize = lambda r: (r-re_min)/(re_max-re_min) # maps [80, 500] onto [0, 1]
# denormalize = lambda r: r*(re_max-re_min) + re_min # maps [0, 1] onto [80, 500]

# %%
# Let's see some ground truth simulations
times = [0, nt//2, nt-1]
alphas = [1, 0.5, 0.25] # shades
plt.figure(figsize = (7, 5))
for j in range(3):
  plt.subplot(2,2,1)
  plt.plot(x, u_HF(x, t[times[j]], re = 100), label = "$t$ = %.2f" % t[times[j]], alpha = alphas[j], color = 'steelblue')
  plt.title(" High-fidelity $Re$ = 100", fontsize = 11)
  plt.xlabel('x')
  plt.legend(loc = 'upper right')
  plt.subplot(2,2,2)
  plt.plot(x, u_HF(x, t[times[j]], re = 400), label = "$t$ = %.2f" % t[times[j]], alpha = alphas[j], color = 'steelblue')
  plt.title("High-fidelity $Re$ = 400", fontsize = 11)
  plt.xlabel('x')
  plt.legend(loc = 'upper right')
  plt.subplot(2,2,3)
  plt.plot(x, u_LF(x, t[times[j]], re = 100), label = "$t$ = %.2f" % t[times[j]], alpha = alphas[j], color = 'green')
  plt.title("Low-fidelity $Re$ = 100", fontsize = 11)
  plt.xlabel('x')
  plt.legend(loc = 'upper right')
  plt.subplot(2,2,4)
  plt.plot(x, u_LF(x, t[times[j]], re = 400), label = "$t$ = %.2f" % t[times[j]], alpha = alphas[j], color = 'green')
  plt.title("Low-fidelity $Re$ = 400", fontsize = 11)
  plt.xlabel('x')
  plt.legend(loc = 'upper right')
plt.tight_layout()

# %% [markdown]
# #### (1) Generation of multi-fidelity dataset

# %%
#Generate training data
u_hf = np.zeros((nre, nt, nh))
u_lf = np.zeros((nre, nt, nh))

for p in range(nre_train):
    for n in range(nt):
        for i in range(nh):
            u_hf[p, n, i] = u_HF(x[i], t[n], denormalization(re[p],re_max,re_min))
            u_lf[p, n, i] = u_LF(x[i], t[n], denormalization(re[p],re_max,re_min))


#Generate test data
u_hf_test = np.zeros((nre_test, nt, nh))
u_lf_test = np.zeros((nre_test, nt, nh))

for p in range(nre_test):
    for n in range(nt):
        for i in range(nh):
            u_hf_test[p, n, i] = u_HF(x[i], t[n], denormalization(re_test[p],re_max,re_min))
            u_lf_test[p, n, i] = u_LF(x[i], t[n], denormalization(re_test[p],re_max,re_min))

# Plot the data
# ind_re = 1 # Re = 367


for ind_re in range(15):
    t_grid, x_grid = np.meshgrid(t, x)
    fig = plt.figure(figsize=(6, 5))
    ax = fig.add_subplot(211)
    surf = ax.contourf(t_grid, x_grid, u_lf[ind_re].T, cmap='plasma', levels=10)
    plt.xlabel('t', fontsize=12)
    plt.ylabel('x', fontsize=12, labelpad=15, rotation = 0)
    cbar = fig.colorbar(surf, ax=ax)
    cbar.ax.set_ylabel('u', fontsize=12, labelpad=15, rotation = 0)
    plt.title('Low-fidelity $Re = $' + str(int(denormalization(re_train[ind_re],re_max,re_min))), fontsize=14)
    ax = fig.add_subplot(212)
    surf = ax.contourf(t_grid, x_grid, u_hf[ind_re].T, cmap='plasma', levels=10)
    plt.xlabel('t', fontsize=12)
    plt.ylabel('x', fontsize=12, labelpad=15, rotation = 0)
    cbar = fig.colorbar(surf, ax=ax)
    cbar.ax.set_ylabel('u', fontsize=12, labelpad=15, rotation = 0)
    plt.title('High-fidelity $Re = $' + str(int(denormalization(re_train[ind_re],re_max,re_min))), fontsize=14)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### (2) Dimensionality reduction via POD

# %%
def compute_randomized_SVD(S, N_POD, N_h, n_channels):
    U = np.zeros((n_channels * N_h, N_POD))
    for i in range(n_channels):
        U[i * N_h: (i + 1) * N_h], Sigma, Vh = extmath.randomized_svd(S[i * N_h: (i + 1) * N_h, :],
                                                                      n_components=N_POD, transpose=False,
                                                                      flip_sign=False, random_state=123)
    return U, Sigma


#########################   Proper Orthogonal Decomposition (POD)   ##########################
n_POD = 16 # we consider the first 16 basis functions

#Reshape for POD
u_hf_pod = np.reshape(u_hf, (nre*nt,nh))
#POD on HF training data
basis, S = compute_randomized_SVD(u_hf_pod, n_POD, nh, 1)

# %% [markdown]
# #### (3) Computing reduced-coordinates via projection

# %%
#########################   PROJECTION ONTO POD BASIS    ##########################
u_lf_pod = np.reshape(u_lf, (nre*nt,nh))
u_lf_pod_test = np.reshape(u_lf_test, (nre_test*nt,nh))
u_hf_pod_test = np.reshape(u_hf_test, (nre_test*nt,nh))

ulf_train = u_lf_pod @ basis      # ATTENTION same basis as u_hf_pod of before 
uhf_train = u_hf_pod @ basis
ulf_test = u_lf_pod_test @ basis
uhf_test = u_hf_pod_test @ basis

#Reshape to make data suitable to LSTM network
ulf_train = np.reshape(ulf_train, (nre, nt, n_POD))
uhf_train = np.reshape(uhf_train, (nre, nt, n_POD))
ulf_test = np.reshape(ulf_test, (nre_test, nt, n_POD))
uhf_test = np.reshape(uhf_test, (nre_test, nt, n_POD))

# %% [markdown]
# projection

# %%
#Plot POD coefficients: LF vs HF
fig = plt.figure(figsize=(12,6))
plt.subplots_adjust(hspace=0.5)
fig.suptitle('POD coefficients: LF vs HF', fontsize=14)
for mode in range(6):
    ax = fig.add_subplot(231 + mode)
    plt.plot(t, ulf_train[ind_re,:,mode], label = 'LF', linewidth = 2, color = 'green', linestyle = '--')
    plt.plot(t, uhf_train[ind_re, :, mode], label = 'HF', linewidth = 2, color = 'blue')
    ax.title.set_text('POD coord. ' + str(mode+1))
    plt.xlabel('t')
    plt.legend()
plt.show()

# %% [markdown]
# #### (4) Training LSTM neural network surrogate model

# %%
# Reshape to make data suitable to LSTM network

# Train
# dai come ingresso u_lf proiettato su basi 
t_grid_lstm, re_grid_lstm = np.meshgrid(t, re)
input_train = np.concatenate((t_grid_lstm[:,:,np.newaxis], re_grid_lstm[:,:,np.newaxis], ulf_train), axis = 2)
output_train = uhf_train

#Test
t_grid_lstm_test, re_grid_lstm_test = np.meshgrid(t, re_test)
input_test = np.concatenate((t_grid_lstm_test[:,:,np.newaxis], re_grid_lstm_test[:,:,np.newaxis], ulf_test), axis = 2)
output_test = uhf_test

#########################   LSTM NN HYPERPARAMETERS    ##########################
params_NN = { 'lay': 1,
             'nodes': 64,
             'lr':  1e-3,
             'opt': 'Adamax',
             'sequence_freq': 2,
             'sequence_length': 10,
             'epochs':  500,
             'patience' : 50,
             'dropout' : 0.1}

model=NetworkFactory.build_network("LSTM", params=params_NN, data_train=input_train, output_train=output_train, N=params_NN["epochs"],train=True,do_HPO=False,verbose=False)
# ############################   TRAINING/LOADING    ##############################

# if train:
#     #Split the data into subsequences
#     sequence_length = int(params_NN['sequence_length'])
#     sequence_freq = int(params_NN['sequence_freq'])
#     input_train_seq, output_train_seq = sliding_windows(input_train, output_train, sequence_length, sequence_freq)

#     #Create the LSTM NN model
#     model = create_model(params_NN, dim_input = n_POD + 2, dim_output = n_POD) #dim_input = param + time + POD modes ==  1 + 1 + n_POD

#     #Train the model
#     callback = tf.keras.callbacks.EarlyStopping(monitor='mse', patience=params_NN['patience'], restore_best_weights=True)
#     tf.keras.utils.set_random_seed(seed)
#     tf.config.experimental.enable_op_determinism() # for reproducibility
#     hist = model.fit(input_train_seq, output_train_seq, epochs=params_NN['epochs'], verbose = 1, callbacks=[callback])

# else:
#     name = './models/MF_POD_model'
#     model = tf.keras.models.load_model(name)
# if save:
#     name = './models/MF_POD_model_new'
#     model.save(name)
# Out:
# The function training took 86.30622243881226 seconds.

# %%
#########################   PREDICTION    ##########################

# Predictions on test data
output_pred = model.prediction(input_test)

# Plot predicted POD coordinates
ind_test = [0] # Re = 235
for ind_re in ind_test:
    fig = plt.figure(figsize=(12,6))
    plt.subplots_adjust(hspace=0.5)
    fig.suptitle('Re = ' + str(int(denormalization(re_test[ind_re],re_max,re_min))), fontsize=15)
    for mode in range(6):
      plt.subplot(231 + mode)
      plt.plot(t, output_test[ind_re,:,mode],'b-', label = 'HF', linewidth = 2)
      plt.plot(t, output_pred[ind_re, :, mode], 'r--', label = 'HF pred', linewidth = 2)
      plt.xlabel('t')
      plt.title('POD coord. ' + str(mode+1))
      plt.legend()
    plt.show()

# %%
#Reconstruct solution

u_pred = output_pred @ basis.T

#Compare with HF solution
for ind_re in ind_test:
  fig = plt.figure(figsize=(6, 7.5))
  plt.suptitle('Re = ' + str(int(denormalization(re_test[ind_re],re_max,re_min))), fontsize = 14)
  
  ax = fig.add_subplot(311)
  surf = ax.contourf(t_grid, x_grid, u_lf_test[ind_re].T, cmap='plasma', levels=10)
  plt.xlabel('t', fontsize=12)
  plt.ylabel('x', fontsize=12, labelpad=15, rotation = 0)
  cbar = fig.colorbar(surf, ax=ax)
  cbar.ax.set_ylabel('u', fontsize=12, labelpad=15, rotation = 0)
  plt.title('Low-fidelity', fontsize=12)
  
  ax = fig.add_subplot(312)
  surf = ax.contourf(t_grid, x_grid, u_hf_test[ind_re].T, cmap='plasma', levels=10)
  plt.xlabel('t', fontsize=12)
  plt.ylabel('x', fontsize=12, labelpad=15, rotation = 0)
  cbar = fig.colorbar(surf, ax=ax)
  cbar.ax.set_ylabel('u', fontsize=12, labelpad=15, rotation = 0)
  plt.title('High-fidelity', fontsize=12)
  
  ax = fig.add_subplot(313)
  surf = ax.contourf(t_grid, x_grid, u_pred[ind_re].T, cmap='plasma', levels=10)
  plt.xlabel('t', fontsize=12)
  plt.ylabel('x', fontsize=12, labelpad=15, rotation = 0)
  cbar = fig.colorbar(surf, ax=ax)
  cbar.ax.set_ylabel('u', fontsize=12, labelpad=15, rotation = 0)
  plt.title('MF-POD prediction', fontsize=12)
  
  plt.tight_layout()
  plt.show()

# %%
#Compute and plot errors
rel_err_lf = np.linalg.norm(u_lf_test - u_hf_test)/np.linalg.norm(u_hf_test[ind_re])
rel_err_pred = np.linalg.norm(u_pred - u_hf_test)/np.linalg.norm(u_hf_test[ind_re])

abs_err_lf = np.abs(u_lf_test - u_hf_test)
abs_err_pred = np.abs(u_pred - u_hf_test)

for ind_re in ind_test:
  fig = plt.figure(figsize=(6, 5))
  plt.suptitle('Re = ' + str(int(denormalization(re_test[ind_re],re_max,re_min))), fontsize = 14)
  ax = fig.add_subplot(211)
  surf = ax.contourf(t_grid, x_grid, abs_err_lf[ind_re].T, cmap='bwr', levels=10)
  cbar = fig.colorbar(surf, ax=ax)
  cbar.ax.set_ylabel('abs. err.', fontsize=12, labelpad=15)
  plt.xlabel('t', fontsize=12)
  plt.ylabel('x', fontsize=12, labelpad=15, rotation = 0)
  plt.title('Absolute error for LF', fontsize=12)
  ax = fig.add_subplot(212)
  surf = ax.contourf(t_grid, x_grid, abs_err_pred[ind_re].T, cmap='bwr', levels=10)
  cbar = fig.colorbar(surf, ax=ax)
  cbar.ax.set_ylabel('abs. err.', fontsize=12, labelpad=15)
  plt.xlabel('t', fontsize=12)
  plt.ylabel('x', fontsize=12, labelpad=15, rotation = 0)
  plt.title('Absolute error for MF-POD', fontsize=12)
  plt.tight_layout()
  plt.show()

# %%
# true parameters
sigma_noise=[0.05,0.1]
n_data=[110]
parameter=np.array([re_grid_lstm_test[0,0]])
#indices = np.where(input_test[:,:,1] == parameter)[0]
mean_prior=np.array([.5])
cov_prior=np.diag([1])
# cov_linkelihood
sigma=np.array([1,2,4.])   # NB, con sigma piccolo (e.g. 1) funzia, sigma troppo gaìrande no

# adaptive metropolis
rwmh_cov = np.eye(1)
rmwh_scaling = np.array([0.1,0.2,0.05])
rwmh_adaptive = True
iterations =3000
burnin = 1500
n_chains=3

algo="MH"


estimateMF, errorMF= run_simulation(basis,input_test, T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
# FUnziona, obiettivo ora, ridurre varianza della posterior
# Out:
# Noise: 0.05
# Number of data: 110
# sigma: 1.0
# step random walk: 0.1
# (1, 110, 18)
# real values are [0.36842105]
# Sampling chain 1/3
# Running chain, α = 0.21: 100%|██████████| 3000/3000 [14:29<00:00,  3.45it/s]
# Sampling chain 2/3
# Running chain, α = 0.25: 100%|██████████| 3000/3000 [14:40<00:00,  3.41it/s]
# Sampling chain 3/3
# Running chain, α = 0.21: 100%|██████████| 3000/3000 [14:42<00:00,  3.40it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [0.196]
#      mean    sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  0.196  0.06   0.074    0.272      0.003    0.002     370.0     214.0
#
#     r_hat
# x0   1.01
# Autocorrelation...
# the difference between estimated values [0.17242105]
# The function param_inverse took 2634.8561754226685 seconds.
# step random walk: 0.2
# (1, 110, 18)
# real values are [0.36842105]
# Sampling chain 1/3
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_13904\3456175106.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Running chain, α = 0.23: 100%|██████████| 3000/3000 [14:45<00:00,  3.39it/s]
# Sampling chain 2/3
# Running chain, α = 0.15: 100%|██████████| 3000/3000 [14:43<00:00,  3.40it/s]
# Sampling chain 3/3
# Running chain, α = 0.18: 100%|██████████| 3000/3000 [14:53<00:00,  3.36it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [0.195]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  0.195  0.062   0.059    0.273      0.002    0.002     616.0     462.0
#
#     r_hat
# x0   1.01
# Autocorrelation...
# the difference between estimated values [0.17342105]
# The function param_inverse took 2664.108906507492 seconds.
# step random walk: 0.05
# (1, 110, 18)
# real values are [0.36842105]
# Sampling chain 1/3
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_13904\3456175106.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Running chain, α = 0.23: 100%|██████████| 3000/3000 [15:54<00:00,  3.14it/s]
# Sampling chain 2/3
# Running chain, α = 0.40: 100%|██████████| 3000/3000 [14:56<00:00,  3.35it/s]
# Sampling chain 3/3
# Running chain, α = 0.11: 100%|██████████| 3000/3000 [14:57<00:00,  3.34it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [0.175]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  0.175  0.888   -1.04    1.051      0.504    0.396       4.0      19.0
#
#     r_hat
# x0   2.09
# Autocorrelation...
# the difference between estimated values [0.19342105]
# The function param_inverse took 2749.7209055423737 seconds.
# sigma: 2.0
# step random walk: 0.1
# (1, 110, 18)
# real values are [0.36842105]
# Sampling chain 1/3
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_13904\3456175106.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Running chain, α = 0.19: 100%|██████████| 3000/3000 [14:40<00:00,  3.41it/s]
# Sampling chain 2/3
# Running chain, α = 0.21: 100%|██████████| 3000/3000 [15:15<00:00,  3.28it/s]
# Sampling chain 3/3
# Running chain, α = 0.25: 100%|██████████| 3000/3000 [15:17<00:00,  3.27it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [0.408]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  0.408  0.433  -0.049    1.328      0.024    0.017     339.0     660.0
#
#     r_hat
# x0   1.01
# Autocorrelation...
# the difference between estimated values [0.03957895]
# The function param_inverse took 2714.9893550872803 seconds.
# step random walk: 0.2
# (1, 110, 18)
# real values are [0.36842105]
# Sampling chain 1/3
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_13904\3456175106.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Running chain, α = 0.37:  24%|██▍       | 726/3000 [03:47<11:51,  3.20it/s]
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[21], line 22
#
#      17 n_chains=3
#
#      19 algo="MH"
#
# ---> 22 estimateMF, errorMF= run_simulation(basis,input_test, T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
#
#      23 # FUnziona, obiettivo ora, ridurre varianza della posterior
#
#
#
# Cell In[14], line 103, in run_simulation(basis, datahf, T, mean_prior, cov_prior, Yhf, sigma_noise, n_data, parameters, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, final_model, algo)
#
#     101             nearest_x, y_obs = process_data(datahf, parameters, t_eval, Yhf)
#
#     102             print(nearest_x.shape)
#
# --> 103             estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
#
#     105 smallest_index = np.unravel_index(np.argmin(error), error.shape)
#
#     106 print(f"The best estimate is given by: sigma_noise={sigma_noise[smallest_index[0]]}, number of data= {n_data[smallest_index[1]]}, sigma={sigma[smallest_index[2]]}, rmwh_scaling={rmwh_scaling[smallest_index[3]]}")
#
#
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:101, in compute_time.<locals>.wrapper(*args, **kwargs)
#
#      99 def wrapper(*args, **kwargs):
#
#     100     init = time.time()
#
# --> 101     res = function(*args, **kwargs)
#
#     102     end = time.time()
#
#     103     timespam = end - init
#
#
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:1117, in LSTM.param_inverse(self, basis, mean_prior, x_data, cov_prior, cov_noise, cov_likelihood, y_obs, x_real, number_chains, N, burn_in, levels, diagnostic, rwmh_cov, rmwh_scaling, rwmh_adaptive, algo, transformation)
#
#    1114 if(rwmh_cov is None):
#
#    1115     rwmh_cov = np.eye(len(x_real))
#
# -> 1117 estimates=MCMC(my_posterior,N,burn_in,number_chains,diagnostic=diagnostic,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive,algo=algo,dim=dim)
#
#    1119 if diagnostic is True:
#
#    1120     plot_hist(estimates,x_real, self.wrapper_prediction(estimates), self.wrapper_prediction(x_real))
#
#
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\module_utils.py:64, in MCMC(my_posterior, N, burnin, n, diagnostic, rwmh_cov, rmwh_scaling, period, t0, rwmh_adaptive, algo, dim)
#
#      61 else:
#
#      62     raise ValueError("Unknown algorithm %s"%algo)
#
# ---> 64 my_chains = tda.sample(my_posterior, my_proposal, iterations=N, n_chains=n, force_sequential=True, initial_parameters=MAP)
#
#      65 idata = tda.to_inference_data(my_chains, burnin=burnin)
#
#      66 estimates=np.array(az.summary(idata)['mean'])
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\sampler.py:198, in sample(posteriors, proposal, iterations, n_chains, initial_parameters, subsampling_rate, adaptive_error_model, store_coarse_chain, force_sequential, force_progress_bar)
#
#     195 if n_levels == 1:
#
#     196     # sequential sampling.
#
#     197     if not ray_is_available or n_chains == 1 or force_sequential:
#
# --> 198         samples = _sample_sequential(
#
#     199             posteriors, proposal, iterations, n_chains, initial_parameters
#
#     200         )
#
#     201     # parallel sampling.
#
#     202     else:
#
#     203         samples = _sample_parallel(
#
#     204             posteriors,
#
#     205             proposal,
#
#    (...)
#
#     209             force_progress_bar,
#
#     210         )
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\sampler.py:283, in _sample_sequential(posteriors, proposal, iterations, n_chains, initial_parameters)
#
#     281     print("Sampling chain {}/{}".format(i + 1, n_chains))
#
#     282     chains.append(Chain(posteriors[0], proposal[i], initial_parameters[i]))
#
# --> 283     chains[i].sample(iterations)
#
#     285 info = {"sampler": "MH", "n_chains": n_chains, "iterations": iterations + 1}
#
#     286 chains = {"chain_{}".format(i): chain.chain for i, chain in enumerate(chains)}
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\chain.py:105, in Chain.sample(self, iterations, progressbar)
#
#     102 proposal = self.proposal.make_proposal(self.chain[-1])
#
#     104 # create a link from that proposal.
#
# --> 105 proposal_link = self.posterior.create_link(proposal)
#
#     107 # compute the acceptance probability, which is unique to
#
#     108 # the proposal.
#
#     109 alpha = self.proposal.get_acceptance(proposal_link, self.chain[-1])
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\posterior.py:80, in Posterior.create_link(self, parameters)
#
#      77 prior = self.prior.logpdf(parameters)
#
#      79 # get the model output and the qoi.
#
# ---> 80 model_output = self.model(parameters)
#
#      82 # extract model output and qoi.
#
#      83 if isinstance(model_output, tuple):
#
#
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:1025, in LSTM.wrapper_prediction(self, x_test, multi_input)
#
#    1023 for n in range(self.inputs.shape[1]):
#
#    1024     for i in range(x.shape[0]):
#
# -> 1025         u_lf[0, n, i] = u_LF(x[i], self.inputs[0,n,0], denormalization(x_final[0],re_max,re_min))
#
#    1026         u_hf[0, n, i] = u_HF(x[i], self.inputs[0,n,0], denormalization(x_final[0],re_max,re_min))
#
#    1029 u_hf=np.reshape(u_hf, (110,nh))
#
#
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\module_utils.py:40, in denormalization(x, xmax, xmin)
#
#      35 def  normalization(x, xmax,xmin):
#
#      36     return (x - xmin) / (
#
#      37     xmax - xmin
#
#      38 )
#
# ---> 40 def  denormalization(x, xmax,xmin ):
#
#      41     return x*(xmax-xmin) +xmin
#
#      43 def MCMC(my_posterior,N, burnin, n=1, diagnostic=True,rwmh_cov=None,rmwh_scaling=0.1, period=100, t0=0, rwmh_adaptive=False,algo="MH",dim=0):
#
#      44     #print("check 1")
#
#
#
# KeyboardInterrupt:

# %% [markdown]
# ## Inversion

# %%
# potrebbero andare in utils
def process_data(datahf, parameters, t_eval, Yhf):
    # """
    # Find the elements of a dataset nearest to the ones given
    # """
    mask = datahf[:,:,1] == parameters
    datahf_values=datahf[mask]
    datahf_values=np.expand_dims(datahf_values, axis=0)

    t_eval_values = t_eval[:, 0]  # Simplify t_eval to a 1D array if not already
    t_eval_values = t_eval_values[np.newaxis, :]

    # Extract the first dimension slice (:, :, 0) from the original matrix
    slice_0 = datahf_values[0, :, 0]

    # Compute the absolute differences in a vectorized manner
    # The result will be of shape (151, 50)
    differences = np.abs(slice_0[:, np.newaxis] - t_eval_values[0, np.newaxis, :])

    # Find the indices of the minimum values along axis 0
    indices = np.argmin(differences, axis=0)

    # Use the indices to extract the rows from the original matrix
    new_matrix = datahf_values[:, indices, :]

    y_obs=Yhf[np.where(mask==True)[0][0],indices,:]

    return new_matrix, np.expand_dims(y_obs, axis=0)




    # indices = np.where(datahf[:,:,1] == parameters)
    # indices = np.column_stack((indices[0], indices[1]))
    
    # if len(indices)==0:
    #     raise ValueError(f" No observations related to parameter: {parameters}")
    
    # rows = indices[:, 0]
    # cols = indices[:, 1]

    # # Assuming you want to extract the elements from all "depth" levels of the 3D array
    # depth_indices = np.arange(datahf.shape[2])

    # # Use broadcasting to create the full index set



    # datahf_values = datahf[rows[:, np.newaxis], cols[:, np.newaxis], depth_indices]
    # datahf_values = datahf_values[:, np.newaxis]
    # t_eval_values = t_eval[:, 0]  # Simplify t_eval to a 1D array if not already
    # t_eval_values = t_eval_values[np.newaxis, :]
    # differences = np.abs(datahf_values[:,:,0] - t_eval_values)
    # closest_indices = np.argmin(differences, axis=0)

    # rows = indices[closest_indices, 0]
    # cols = indices[closest_indices, 1]


    # # nearest_x = datahf[rows,cols, 0]  # x values closest to each t_eval
    # # nearest_y = datahf[rows,cols, 2] #
    # # nearest_z = datahf[rows,cols, 3] #
    # # y_obs = Yhf[rows,cols,:]  # Corresponding y values from Yhf


    # nearest_x = datahf[rows, cols, 0].reshape(-1,1)  # x values closest to each t_eval
    # last_dims = datahf[rows, cols, 2:]  # Selec-1,1t the last 16 dimensions

    # # Stack the first dimension with the last 16 dimensions
    # stacked_datahf = np.concatenate((nearest_x, last_dims), axis=-1)
    # y_obs = Yhf[rows, cols, :]  # Corresponding y values from Yhf





    # return stacked_datahf, y_obs.reshape(1,y_obs.shape[0],y_obs.shape[1])



def run_simulation(basis,datax,datahf, nh,nt,T, mean_prior, cov_prior, Yhf, sigma_noise, n_data, parameters, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, final_model,algo):
    
    error = np.zeros((len(sigma_noise), len(n_data), sigma.shape[0], rmwh_scaling.shape[0]))
    estimate_MF=np.zeros((len(sigma_noise), len(n_data), sigma.shape[0], rmwh_scaling.shape[0]))


    for i,noise in enumerate(sigma_noise):

        print(f"Noise: {noise}")

        for k,n in enumerate(n_data):
            print(f"Number of data: {n}")
            for t,s in enumerate(sigma):
                print(f"sigma: {s}")
                for j,r in enumerate(rmwh_scaling):

                    print(f"step random walk: {r}")       
                    
                    t_eval = np.linspace(0., T, n).reshape(-1,1)
                    
                    nearest_x, y_obs = process_data(datahf, parameters, t_eval, Yhf)
                    print(nearest_x.shape)
                    estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,datax,mean_prior, nh,nt,nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
                    
        smallest_index = np.unravel_index(np.argmin(error), error.shape)
        print(f"The best estimate is given by: sigma_noise={sigma_noise[smallest_index[0]]}, number of data= {n_data[smallest_index[1]]}, sigma={sigma[smallest_index[2]]}, rmwh_scaling={rmwh_scaling[smallest_index[3]]}")

    return estimate_MF[smallest_index],error

# %%
basis.shape
# Out:
# (101, 16)

# %%
basis
# Out:
# array([[ 1.10044352e-01,  1.95484154e-01,  2.46457095e-01, ...,
#          1.73731031e-01,  1.47758173e-01, -1.23540826e-01],
#        [ 1.10061228e-01,  1.90652323e-01,  2.27334161e-01, ...,
#         -2.68229971e-01, -2.86613747e-01,  2.92031117e-01],
#        [ 1.10064517e-01,  1.85773350e-01,  2.08615701e-01, ...,
#         -1.46215714e-01, -7.95204979e-02,  4.54469970e-03],
#        ...,
#        [ 8.43318040e-02, -1.31595630e-01,  1.55833216e-01, ...,
#          1.18440033e-01, -1.44816133e-01, -1.64292652e-01],
#        [ 8.40162527e-02, -1.32671196e-01,  1.61093920e-01, ...,
#         -4.43674452e-05, -3.34932724e-02, -6.61875270e-02],
#        [ 8.37018462e-02, -1.33715740e-01,  1.66300937e-01, ...,
#         -2.31044152e-01,  2.22097543e-01,  2.11913781e-01]])

# %%
[re_grid_lstm_test[:,0]]
# Out:
# [array([0.36842105, 0.57894737, 0.78947368, 0.89473684])]

# %%
basis_new=basis[::2, :]

# %%
print(basis_new)
# Out:
# [[ 0.11004435  0.19548415  0.24645709  0.28231792 -0.3055357  -0.31719778
#   -0.31865114 -0.31142419  0.29718846  0.27750027  0.25390017 -0.22786026
#   -0.20075223  0.17373103  0.14775817 -0.12354083]
#  [ 0.11006452  0.18577335  0.2086157   0.19566689 -0.15180147 -0.0844751
#   -0.00425278  0.07709178 -0.14831609 -0.20023742 -0.22670811  0.22522709
#    0.19696702 -0.14621571 -0.0795205   0.0045447 ]
#  [ 0.11003172  0.17589547  0.17248716  0.12035099 -0.0352568   0.06033641
#    0.14144452  0.18739005 -0.18693552 -0.14065128 -0.060277   -0.03460046
#   -0.12159154  0.1809783   0.2000868  -0.17570258]
#  [ 0.10994871  0.16589227  0.13824074  0.05608338  0.04850583  0.13667314
#    0.17552553  0.15069201 -0.07133406  0.03382692  0.12726832 -0.17625299
#   -0.16420875  0.09594677 -0.00477455  0.10407629]
#  [ 0.10981819  0.15580336  0.10601346  0.00242719  0.10399629  0.16201089
#    0.14320108  0.05618335  0.05775804  0.14489059  0.16453487 -0.10789582
#   -0.00152748 -0.10572773 -0.16550529  0.15164704]
#  [ 0.10964282  0.14566602  0.07591145 -0.04117791  0.13568576  0.15159928
#    0.07864474 -0.04081522  0.13688334  0.15358023  0.08136001  0.03788978
#    0.13568438 -0.15657267 -0.08927524 -0.02799128]
#  [ 0.10942518  0.13551516  0.04801178 -0.07538986  0.14788979  0.11834085
#    0.0062165  -0.11082782  0.15132028  0.08711208 -0.03738661  0.13647106
#    0.1424395  -0.05159555  0.07424267 -0.15051842]
#  [ 0.1091678   0.12538315  0.02236452 -0.10093971  0.14467541  0.07279113
#   -0.05808897 -0.14288309  0.11310721 -0.00751692 -0.12243223  0.13997357
#    0.04639492  0.08402277  0.14861426 -0.09718199]
#  [ 0.10887311  0.11529987 -0.00100498 -0.11860905  0.12979132  0.02325467
#   -0.10510652 -0.13818538  0.04532506 -0.08910245 -0.14288113  0.06726749
#   -0.0692576   0.1437163   0.08957532  0.04449752]
#  [ 0.1085435   0.10529266 -0.02209377 -0.1292095   0.10661938 -0.02404702
#   -0.13098616 -0.10495918 -0.0281408  -0.1329872  -0.10292511 -0.03158454
#   -0.13441327  0.10195072 -0.03293465  0.13513154]
#  [ 0.10818123  0.09538639 -0.04091884 -0.13356466  0.07814501 -0.06475811
#   -0.13578078 -0.05449449 -0.08838914 -0.1323445  -0.02784754 -0.108078
#   -0.12344815  0.00123573 -0.12256695  0.11091109]
#  [ 0.10778853  0.08560349 -0.05751474 -0.13249436  0.0469442  -0.09614155
#   -0.1221904   0.00167793 -0.12394209 -0.09430849  0.05113031 -0.13422144
#   -0.05331872 -0.0927855  -0.12627081  0.00668591]
#  [ 0.10736749  0.07596405 -0.07193123 -0.12680137  0.01518427 -0.11681931
#   -0.09449433  0.05361622 -0.13087722 -0.03412032  0.1082541  -0.10707755
#    0.03615135 -0.13178671 -0.05356086 -0.0953438 ]
#  [ 0.10692017  0.06648588 -0.08423104 -0.11726043 -0.01536408 -0.1265134
#   -0.05768388  0.09397258 -0.11155573  0.03062805  0.12928004 -0.04318799
#    0.10476796 -0.10359437  0.04499312 -0.12998972]
#  [ 0.10644849  0.05718465 -0.09448772 -0.10460948 -0.04330598 -0.12579835
#   -0.01679314  0.11835581 -0.07267054  0.08448941  0.11257732  0.03160335
#    0.12773892 -0.02904845  0.11408483 -0.08403045]
#  [ 0.10595432  0.04807396 -0.10278366 -0.08954281 -0.0675951  -0.11587263
#    0.02358519  0.12522786 -0.02314839  0.11693698  0.06671483  0.09229685
#    0.10138756  0.05430204  0.12216182  0.00770714]
#  [ 0.10543943  0.03916553 -0.10920825 -0.07270617 -0.08750189 -0.09835423
#    0.05961911  0.11549347  0.02773728  0.1234443   0.00622363  0.12196684
#    0.04006662  0.11099974  0.07142549  0.0908687 ]
#  [ 0.10490551  0.03046922 -0.11385621 -0.05469345 -0.10257916 -0.07510326
#    0.08841632  0.09191791  0.07183835  0.10518052 -0.05296872  0.11497485
#   -0.03211422  0.12109596 -0.00960792  0.12314468]
#  [ 0.10435417  0.02199325 -0.11682603 -0.03604472 -0.11262637 -0.04807271
#    0.10808866  0.0584805   0.10310559  0.06776196 -0.09735995  0.07645045
#   -0.09074242  0.08480324 -0.08305368  0.09287802]
#  [ 0.10378694  0.01374426 -0.11821867 -0.01724555 -0.11765401 -0.01918722
#    0.11772774  0.01974454  0.11806896  0.01951587 -0.11836038  0.01914691
#   -0.11862472  0.01904134 -0.11883063  0.01946065]
#  [ 0.10320526  0.00572747 -0.11813631  0.00127262 -0.11784891  0.0097518
#    0.11731567 -0.01970092  0.11588758 -0.0303464  -0.11328553 -0.04092986
#   -0.10970844 -0.0509914  -0.10536288 -0.0602544 ]
#  [ 0.1026105  -0.00205326 -0.1166813   0.01913136 -0.11354126  0.03713642
#    0.10759236 -0.05569401  0.09806515 -0.07334641 -0.08501413 -0.08882972
#   -0.06915835 -0.10137135 -0.05130347 -0.11056291]
#  [ 0.10200397 -0.00959523 -0.11395527  0.03600339 -0.10517393  0.06160067
#    0.0898976  -0.08483186  0.06793803 -0.10295536 -0.04066729 -0.11396456
#   -0.01040288 -0.11692562  0.02041344 -0.1118088 ]
#  [ 0.10138688 -0.01689687 -0.11005834  0.05161019 -0.09327433  0.08204997
#    0.06600317 -0.10467985  0.03004067 -0.11532232  0.01025685 -0.11191295
#    0.04948015 -0.0948155   0.08258454 -0.06638952]
#  [ 0.10076041 -0.02395758 -0.10508845  0.06571925 -0.07842921  0.09767444
#    0.03794669 -0.11386639 -0.01055973 -0.10951173  0.05787137 -0.08464184
#    0.0945855  -0.04393037  0.11368377  0.0047795 ]
#  [ 0.10012564 -0.03077768 -0.09914083  0.07814105 -0.0612623   0.10794896
#    0.00787615 -0.11207841 -0.04888608 -0.08731032  0.09366496 -0.03938798
#    0.11402487  0.01899297  0.10451577  0.07234912]
#  [ 0.0994836  -0.03735827 -0.09230753  0.08872579 -0.04241493  0.11262269
#   -0.02208865 -0.09997611 -0.08057825 -0.05270314  0.1118029   0.01335873
#    0.10407058  0.07492707  0.06001291  0.11043525]
#  [ 0.09883527 -0.04370117 -0.08467712  0.09736011 -0.02252944  0.11170062
#   -0.04997402 -0.0790473  -0.10229098 -0.01113648  0.10984115  0.06225186
#    0.06838323  0.10805982 -0.00363874  0.10584417]
#  [ 0.09818154 -0.04980882 -0.07633437  0.10396376 -0.00223534  0.10541917
#   -0.07404751 -0.05142097 -0.1119475   0.03131357  0.0888359   0.0973765
#    0.01654907  0.10983969 -0.06502673  0.06180264]
#  [ 0.09752329 -0.05568424 -0.06736008  0.1084863   0.017862    0.0942181
#   -0.09289012 -0.01965858 -0.10884854  0.06875984  0.05291623  0.11204133
#   -0.03854067  0.08073409 -0.10452538 -0.00436889]
#  [ 0.09686131 -0.06133092 -0.05783093  0.1109039   0.03719042  0.07871005
#   -0.10544607  0.01346117 -0.09364774  0.09622318  0.00844647  0.10382976
#   -0.08378996  0.02953686 -0.11016969 -0.06819168]
#  [ 0.09619635 -0.06675274 -0.04781944  0.11121623  0.05521786  0.05964936
#   -0.11105202  0.04515082 -0.06821281  0.11018864 -0.03706311  0.07481677
#   -0.10880208 -0.02935513 -0.08085554 -0.10685061]
#  [ 0.09552911 -0.07195399 -0.03739388  0.10944353  0.07145742  0.03790114
#   -0.10944778  0.07280564 -0.03539607  0.10896072 -0.07613109  0.03099676
#   -0.10803477 -0.07987433 -0.02621653 -0.10692888]
#  [ 0.09486027 -0.07693923 -0.02661836  0.10562387  0.08547077  0.01441145
#   -0.10077108  0.09417072  0.00125927  0.09280269 -0.10241033 -0.01892267
#   -0.08184951 -0.10842603  0.03654811 -0.06868418]
#  [ 0.09419042 -0.08171327 -0.01555281  0.09981049  0.09687016 -0.00982062
#   -0.08553914  0.10747891  0.03785144  0.06386488 -0.11159525 -0.06513324
#   -0.03632643 -0.10729052  0.08787345 -0.00573   ]
#  [ 0.09352015 -0.08628115 -0.0042531   0.09206948  0.1053192  -0.03376865
#   -0.06461972  0.11155694  0.07046668  0.0259231  -0.10203601 -0.09848273
#    0.01806452 -0.07655431  0.11159993  0.05962031]
#  [ 0.09284999 -0.09064804  0.00722888  0.08247751  0.11053264 -0.05640201
#   -0.03919413  0.10589938  0.09551903 -0.01604095 -0.07500224 -0.11211446
#    0.06866327 -0.02417706  0.09979018  0.1038387 ]
#  [ 0.09218043 -0.09481926  0.01884509  0.07111985  0.11227525 -0.07670618
#   -0.01071474  0.09071118  0.11006554 -0.05637776 -0.03457559 -0.10275722
#    0.10329036  0.03581721  0.05533112  0.11022055]
#  [ 0.09151195 -0.09880022  0.03055123  0.05808851  0.11036015 -0.09370026
#    0.019141    0.0669212   0.11208332 -0.08938458  0.01281671 -0.07148303
#    0.11292491  0.08667432 -0.00841481  0.07502915]
#  [ 0.09084497 -0.1025964   0.04230653  0.04348063  0.1046465  -0.10645173
#    0.04851808  0.03616952  0.10069876 -0.10995438  0.05918799 -0.02381127
#    0.09392291  0.11312516 -0.07097961  0.00973898]
#  [ 0.09017988 -0.10621328  0.05407368  0.02739698  0.0950368  -0.11408848
#    0.07543144  0.00077229  0.07636273 -0.11422005  0.09603851  0.03089604
#    0.04935883  0.10564396 -0.11056135 -0.0616753 ]
#  [ 0.08951706 -0.1096564   0.06581861  0.00994067  0.08147401 -0.1158083
#    0.09781217 -0.03633216  0.04096921 -0.10015963  0.11558924  0.08074054
#   -0.01083664  0.06383276 -0.11097011 -0.11019295]
#  [ 0.08885685 -0.11293124  0.07751032 -0.00878399  0.06393831 -0.11088599
#    0.1135513  -0.07165197 -0.00208248 -0.06813399  0.11212434  0.11323171
#   -0.07115426 -0.00195206 -0.06807756 -0.11237352]
#  [ 0.08819956 -0.11604329  0.08912076 -0.02867253  0.04244393 -0.09867836
#    0.12054044 -0.10122131 -0.04787937 -0.02133527  0.08336259  0.11776056
#   -0.11328336 -0.07148468  0.00613024 -0.06134394]
#  [ 0.08754548 -0.11899797  0.10062465 -0.04962115  0.01703579 -0.07862727
#    0.11670871 -0.12068737 -0.09003599  0.03386917  0.03178326  0.08846196
#   -0.12034706 -0.11861496  0.08379791  0.02560061]
#  [ 0.08689487 -0.12180063  0.11199927 -0.07152748 -0.01221374 -0.05026095
#    0.10005556 -0.12540127 -0.12077939  0.08770596 -0.03416023  0.02730514
#   -0.08244002 -0.11857005  0.12742811  0.10703169]
#  [ 0.08624799 -0.12445657  0.12322438 -0.09429123 -0.04520806 -0.01319385
#    0.06867923 -0.11051023 -0.13107145  0.1268809  -0.09899435 -0.05275507
#   -0.00321922 -0.0586376   0.10337686  0.12933444]
#  [ 0.08560505 -0.126971    0.13428198 -0.11781466 -0.08182942  0.03287478
#    0.0208009  -0.07104819 -0.1107614   0.13457805 -0.13939006 -0.12472966
#    0.09277205  0.04801044  0.00337337  0.05437379]
#  [ 0.08496626 -0.12934902  0.14515622 -0.1420031  -0.12194191  0.08816337
#   -0.04521547 -0.0020231  -0.04876153  0.09056605 -0.12356807 -0.1448
#    0.15241015  0.14583187 -0.12578323 -0.09419906]
#  [ 0.0843318  -0.13159563  0.15583322 -0.16676522 -0.16539426  0.15281141
#   -0.13084753  0.10150113  0.06676085 -0.02859791 -0.0109616  -0.04990573
#    0.08630756  0.11844003 -0.14481613 -0.16429265]
#  [ 0.08370185 -0.13371574  0.16630094 -0.19201336 -0.21202251  0.22688345
#   -0.23740284  0.24432911  0.24818186 -0.24927898  0.24785816  0.2441784
#   -0.23848579 -0.23104415  0.22209754  0.21191378]]

# %%
# true parameters
sigma_noise=[0.05,0.1]
n_data=[70]
parameter=np.array([re_grid_lstm_test[0,0]])
indices = np.where(input_test[:,:,1] == parameter)[0]
mean_prior=np.array([.5])
cov_prior=np.diag([ .5])
# cov_linkelihood
sigma=np.array([.5,4.])   # NB, con sigma piccolo (e.g. 1) funzia, sigma troppo gaìrande no

# adaptive metropolis
rwmh_cov = np.eye(1)
rmwh_scaling = np.array([0.1,0.5,2.])
rwmh_adaptive = True
iterations =2000
burnin = 1000
n_chains=2

algo="AM"
nh=51


estimateMF, errorMF= run_simulation(basis_new,input_test,nh, T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
# FUnziona, obiettivo ora, ridurre varianza della posterior
# Out:
# Noise: 0.05
# Number of data: 70
# sigma: 0.5
# step random walk: 0.1
# (1, 70, 18)
# real values are [0.36842105]
# Sampling chain 1/2
# Running chain, α = 0.18: 100%|██████████| 2000/2000 [02:52<00:00, 11.57it/s]
# Sampling chain 2/2
# Running chain, α = 0.32:  38%|███▊      | 757/2000 [01:07<01:48, 11.44it/s]c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1638: RuntimeWarning: overflow encountered in exp
#   return x/(t+1)/(1.0+np.exp(re*(x)/(4*t+4))*((t+1)/A0)**0.5)
# Running chain, α = 0.15: 100%|██████████| 2000/2000 [03:00<00:00, 11.09it/s]
# c:\Users\Giacomo\miniconda3\Lib\site-packages\arviz\data\inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [1.083]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  1.083  0.351   0.546    1.781      0.022    0.016     252.0     241.0
#
#     r_hat
# x0   1.01
# Autocorrelation...
# the difference between estimated values [0.71457895]
# The function param_inverse took 363.26810479164124 seconds.
# step random walk: 0.5
# (1, 70, 18)
# real values are [0.36842105]
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_407400\851770737.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nh,nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Sampling chain 1/2
# Running chain, α = 0.31:  80%|███████▉  | 1593/2000 [02:25<00:36, 11.04it/s]c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1638: RuntimeWarning: overflow encountered in exp
#   return x/(t+1)/(1.0+np.exp(re*(x)/(4*t+4))*((t+1)/A0)**0.5)
# Running chain, α = 0.30: 100%|██████████| 2000/2000 [03:02<00:00, 10.94it/s]
# Sampling chain 2/2
# Running chain, α = 0.26: 100%|██████████| 2000/2000 [03:08<00:00, 10.60it/s]
# c:\Users\Giacomo\miniconda3\Lib\site-packages\arviz\data\inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [1.056]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  1.056  0.372    0.47    1.825      0.019    0.013     392.0     303.0
#
#     r_hat
# x0    1.0
# Autocorrelation...
# the difference between estimated values [0.68757895]
# The function param_inverse took 383.97195982933044 seconds.
# step random walk: 2.0
# (1, 70, 18)
# real values are [0.36842105]
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_407400\851770737.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nh,nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 23
#      19 algo="AM"
#      20 nh=51
# ---> 23 estimateMF, errorMF= run_simulation(basis_new,input_test,nh, T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
#      24 # FUnziona, obiettivo ora, ridurre varianza della posterior
#
# Cell In[14], line 103, in run_simulation(basis, datahf, nh, T, mean_prior, cov_prior, Yhf, sigma_noise, n_data, parameters, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, final_model, algo)
#     101             nearest_x, y_obs = process_data(datahf, parameters, t_eval, Yhf)
#     102             print(nearest_x.shape)
# --> 103             estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nh,nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
#     105 smallest_index = np.unravel_index(np.argmin(error), error.shape)
#     106 print(f"The best estimate is given by: sigma_noise={sigma_noise[smallest_index[0]]}, number of data= {n_data[smallest_index[1]]}, sigma={sigma[smallest_index[2]]}, rmwh_scaling={rmwh_scaling[smallest_index[3]]}")
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:121, in compute_time.<locals>.wrapper(*args, **kwargs)
#     119 def wrapper(*args, **kwargs):
#     120     init = time.time()
# --> 121     res = function(*args, **kwargs)
#     122     end = time.time()
#     123     timespam = end - init
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1747, in LSTM.param_inverse(self, basis, mean_prior, nh, x_data, cov_prior, cov_noise, cov_likelihood, y_obs, x_real, number_chains, N, burn_in, levels, diagnostic, rwmh_cov, rmwh_scaling, rwmh_adaptive, algo, transformation)
#    1744 if(rwmh_cov is None):
#    1745     rwmh_cov = np.eye(len(x_real))
# -> 1747 estimates=MCMC(my_posterior,N,burn_in,number_chains,diagnostic=diagnostic,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive,algo=algo,dim=dim)
#    1749 if diagnostic is True:
#    1750     plot_hist(estimates,x_real, self.wrapper_prediction(estimates), self.wrapper_prediction(x_real))
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\module_utils.py:50, in MCMC(my_posterior, N, burnin, n, diagnostic, rwmh_cov, rmwh_scaling, period, t0, rwmh_adaptive, algo, dim)
#      43 def MCMC(my_posterior,N, burnin, n=1, diagnostic=True,rwmh_cov=None,rmwh_scaling=0.1, period=100, t0=0, rwmh_adaptive=False,algo="MH",dim=0):
#      44     #print("check 1")
#      45     # if(dim!=1):
#      46     #      MAP = tda.get_MAP(my_posterior)
#      47     # else:
#      48     #     MAP=None
# ---> 50     MAP = tda.get_MAP(my_posterior)
#      52     #if(adaptive_MH is True):
#      53    # print("check2")
#      54     if algo == "MH":
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tinyDA\utils.py:232, in get_MAP(posterior, **kwargs)
#     230 else:
#     231     initial_parameters = kwargs.pop("initial_parameters", posterior.prior.rvs())
# --> 232     MAP = minimize(
#     233         negative_log_posterior, initial_parameters, method=method, **kwargs
#     234     )
#     235 return MAP["x"]
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_minimize.py:708, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     706     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     707 elif meth == 'bfgs':
# --> 708     res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     709 elif meth == 'newton-cg':
#     710     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     711                              **options)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_optimize.py:1503, in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, c1, c2, hess_inv0, **unknown_options)
#    1500 pk = -np.dot(Hk, gfk)
#    1501 try:
#    1502     alpha_k, fc, gc, old_fval, old_old_fval, gfkp1 = \
# -> 1503              _line_search_wolfe12(f, myfprime, xk, pk, gfk,
#    1504                                   old_fval, old_old_fval, amin=1e-100,
#    1505                                   amax=1e100, c1=c1, c2=c2)
#    1506 except _LineSearchError:
#    1507     # Line search failed to find a better solution.
#    1508     warnflag = 2
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_optimize.py:1239, in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#    1225 """
#    1226 Same as line_search_wolfe1, but fall back to line_search_wolfe2 if
#    1227 suitable step length is not found, and raise an exception if a
#    (...)
#    1234
#    1235 """
#    1237 extra_condition = kwargs.pop('extra_condition', None)
# -> 1239 ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#    1240                          old_fval, old_old_fval,
#    1241                          **kwargs)
#    1243 if ret[0] is not None and extra_condition is not None:
#    1244     xp1 = xk + ret[0] * pk
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_linesearch.py:94, in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      90     return np.dot(gval[0], pk)
#      92 derphi0 = np.dot(gfk, pk)
# ---> 94 stp, fval, old_fval = scalar_search_wolfe1(
#      95         phi, derphi, old_fval, old_old_fval, derphi0,
#      96         c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#      98 return stp, fc[0], gc[0], fval, old_fval, gval[0]
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_linesearch.py:171, in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     168 maxiter = 100
#     170 dcsrch = DCSRCH(phi, derphi, c1, c2, xtol, amin, amax)
# --> 171 stp, phi1, phi0, task = dcsrch(
#     172     alpha1, phi0=phi0, derphi0=derphi0, maxiter=maxiter
#     173 )
#     175 return stp, phi1, phi0
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_dcsrch.py:256, in DCSRCH.__call__(self, alpha1, phi0, derphi0, maxiter)
#     254     alpha1 = stp
#     255     phi1 = self.phi(stp)
# --> 256     derphi1 = self.derphi(stp)
#     257 else:
#     258     break
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_linesearch.py:88, in line_search_wolfe1.<locals>.derphi(s)
#      87 def derphi(s):
# ---> 88     gval[0] = fprime(xk + s*pk, *args)
#      89     gc[0] += 1
#      90     return np.dot(gval[0], pk)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_differentiable_functions.py:284, in ScalarFunction.grad(self, x)
#     282 if not np.array_equal(x, self.x):
#     283     self._update_x_impl(x)
# --> 284 self._update_grad()
#     285 return self.g
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_differentiable_functions.py:267, in ScalarFunction._update_grad(self)
#     265 def _update_grad(self):
#     266     if not self.g_updated:
# --> 267         self._update_grad_impl()
#     268         self.g_updated = True
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_differentiable_functions.py:181, in ScalarFunction.__init__.<locals>.update_grad()
#     179 self._update_fun()
#     180 self.ngev += 1
# --> 181 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     182                            **finite_diff_options)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_numdiff.py:519, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     516     use_one_sided = False
#     518 if sparsity is None:
# --> 519     return _dense_difference(fun_wrapped, x0, f0, h,
#     520                              use_one_sided, method)
#     521 else:
#     522     if not issparse(sparsity) and len(sparsity) == 2:
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_numdiff.py:590, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     588     x = x0 + h_vecs[i]
#     589     dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 590     df = fun(x) - f0
#     591 elif method == '3-point' and use_one_sided[i]:
#     592     x1 = x0 + h_vecs[i]
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_numdiff.py:470, in approx_derivative.<locals>.fun_wrapped(x)
#     467 if xp.isdtype(x.dtype, "real floating"):
#     468     x = xp.astype(x, x0.dtype)
# --> 470 f = np.atleast_1d(fun(x, *args, **kwargs))
#     471 if f.ndim > 1:
#     472     raise RuntimeError("`fun` return value has "
#     473                        "more than 1 dimension.")
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tinyDA\utils.py:223, in get_MAP.<locals>.<lambda>(parameters)
#     204 def get_MAP(posterior, **kwargs):
#     205     """Returns the Maximum a Posteriori estimate of a posterior.
#     206
#     207     Parameters
#    (...)
#     220         Maximum a Posteriori estimate.
#     221     """
# --> 223     negative_log_posterior = lambda parameters: -posterior.create_link(
#     224         parameters
#     225     ).posterior
#     227     method = kwargs.pop("method", None)
#     228     if method == "differential_evolution":
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tinyDA\posterior.py:95, in Posterior.create_link(self, parameters)
#      92 prior = self.prior.logpdf(parameters)
#      94 # get the model output and the qoi.
# ---> 95 model_output = self.model(parameters)
#      97 # extract model output and qoi.
#      98 if isinstance(model_output, tuple):
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1670, in LSTM.wrapper_prediction(self, x_test, multi_input)
#    1663         new_inputs = np.concatenate((t_grid_lstm[:,:,_], re_grid_lstm[:,:,_], ulf_train), axis = 2)
#    1665 #        new_inputs=new_inputs.reshape(1,new_inputs.shape[0],new_inputs.shape[1])
#    1666
#    1667 # # ATTENZIONE  sarebbe da rivedere. Qui stai adattando a dimensioni e ordine del caso Bruger, sarebbe da generalizzare mettendo parametri sempre in fondo o quanto meno specificare
#    1668 #         # new_inputs = np.concatenate((self.inputs[:, :1], x_final, self.inputs[:, 1:]), axis=1)
#    1669 #         # new_inputs=new_inputs.reshape(1,new_inputs.shape[0],new_inputs.shape[1])
# -> 1670         rep=self.prediction(new_inputs).flatten()
#    1672         return rep
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1586, in LSTM.prediction(self, x_test)
#    1583 else:
#    1584     with Suppressor():
# -> 1586         y_pred = self.model.predict(x_test)#[:,0]       # <--------------- commentato il 6/03
#    1587 return y_pred
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:505, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     503 outputs = None
#     504 with epoch_iterator.catch_stop_iteration():
# --> 505     for step, iterator in epoch_iterator.enumerate_epoch():
#     506         callbacks.on_predict_batch_begin(step)
#     507         data = get_data(iterator)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:649, in TFEpochIterator.enumerate_epoch(self)
#     647         yield step, self._current_iterator
#     648 else:
# --> 649     iterator = iter(self._distributed_dataset)
#     650     if self.num_batches:
#     651         for step in range(
#     652             0, self.num_batches, self.steps_per_execution
#     653         ):
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:501, in DatasetV2.__iter__(self)
#     499 if context.executing_eagerly() or ops.inside_function():
#     500   with ops.colocate_with(self._variant_tensor):
# --> 501     return iterator_ops.OwnedIterator(self)
#     502 else:
#     503   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     504                      "iteration in eager mode or within tf.function.")
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:709, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     705   if (components is not None or element_spec is not None):
#     706     raise ValueError(
#     707         "When `dataset` is provided, `element_spec` and `components` must "
#     708         "not be specified.")
# --> 709   self._create_iterator(dataset)
#     711 self._get_next_call_count = 0
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:748, in OwnedIterator._create_iterator(self, dataset)
#     745   assert len(fulltype.args[0].args[0].args) == len(
#     746       self._flat_output_types)
#     747   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 748 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3509, in make_iterator(dataset, iterator, name)
#    3507 if tld.is_eager:
#    3508   try:
# -> 3509     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3510       _ctx, "MakeIterator", name, dataset, iterator)
#    3511     return _result
#    3512   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# true parameters
sigma_noise=[0.05,0.1]
n_data=[75]
parameter=np.array([re_grid_lstm_test[0,0]])
indices = np.where(input_test[:,:,1] == parameter)[0]
mean_prior=np.array([.5])
cov_prior=np.diag([ .5])
# cov_linkelihood
sigma=np.array([.1,4.])   # NB, con sigma piccolo (e.g. 1) funzia, sigma troppo gaìrande no

# adaptive metropolis
rwmh_cov = np.eye(1)
rmwh_scaling = np.array([0.5,2.])
rwmh_adaptive = True
iterations =2000
burnin = 1000
n_chains=2

algo="AM"
nh=101


estimateMF, errorMF= run_simulation(basis,input_test,nh, n_data[0],T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
# FUnziona, obiettivo ora, ridurre varianza della posterior
# Out:
# Noise: 0.05
# Number of data: 75
# sigma: 0.1
# step random walk: 0.5
# (1, 75, 18)
# real values are [0.36842105]
# Sampling chain 1/2
# Running chain, α = 0.33: 100%|██████████| 2000/2000 [04:32<00:00,  7.33it/s]
# Sampling chain 2/2
# Running chain, α = 0.28: 100%|██████████| 2000/2000 [04:30<00:00,  7.39it/s]
# c:\Users\Giacomo\miniconda3\Lib\site-packages\arviz\data\inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [0.356]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  0.356  0.032   0.293    0.417      0.002    0.001     365.0     354.0
#
#     r_hat
# x0   1.01
# Autocorrelation...
# the difference between estimated values [0.01242105]
# The function param_inverse took 560.9769537448883 seconds.
# step random walk: 2.0
# (1, 75, 18)
# real values are [0.36842105]
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_111132\1086389234.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nh,nt,nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 23
#      19 algo="AM"
#      20 nh=101
# ---> 23 estimateMF, errorMF= run_simulation(basis,input_test,nh, n_data[0],T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
#      24 # FUnziona, obiettivo ora, ridurre varianza della posterior
#
# Cell In[14], line 103, in run_simulation(basis, datahf, nh, nt, T, mean_prior, cov_prior, Yhf, sigma_noise, n_data, parameters, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, final_model, algo)
#     101             nearest_x, y_obs = process_data(datahf, parameters, t_eval, Yhf)
#     102             print(nearest_x.shape)
# --> 103             estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nh,nt,nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
#     105 smallest_index = np.unravel_index(np.argmin(error), error.shape)
#     106 print(f"The best estimate is given by: sigma_noise={sigma_noise[smallest_index[0]]}, number of data= {n_data[smallest_index[1]]}, sigma={sigma[smallest_index[2]]}, rmwh_scaling={rmwh_scaling[smallest_index[3]]}")
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:121, in compute_time.<locals>.wrapper(*args, **kwargs)
#     119 def wrapper(*args, **kwargs):
#     120     init = time.time()
# --> 121     res = function(*args, **kwargs)
#     122     end = time.time()
#     123     timespam = end - init
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1747, in LSTM.param_inverse(self, basis, mean_prior, nh, nt, x_data, cov_prior, cov_noise, cov_likelihood, y_obs, x_real, number_chains, N, burn_in, levels, diagnostic, rwmh_cov, rmwh_scaling, rwmh_adaptive, algo, transformation)
#    1744 if(rwmh_cov is None):
#    1745     rwmh_cov = np.eye(len(x_real))
# -> 1747 estimates=MCMC(my_posterior,N,burn_in,number_chains,diagnostic=diagnostic,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive,algo=algo,dim=dim)
#    1749 if diagnostic is True:
#    1750     plot_hist(estimates,x_real, self.wrapper_prediction(estimates), self.wrapper_prediction(x_real))
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\module_utils.py:50, in MCMC(my_posterior, N, burnin, n, diagnostic, rwmh_cov, rmwh_scaling, period, t0, rwmh_adaptive, algo, dim)
#      43 def MCMC(my_posterior,N, burnin, n=1, diagnostic=True,rwmh_cov=None,rmwh_scaling=0.1, period=100, t0=0, rwmh_adaptive=False,algo="MH",dim=0):
#      44     #print("check 1")
#      45     # if(dim!=1):
#      46     #      MAP = tda.get_MAP(my_posterior)
#      47     # else:
#      48     #     MAP=None
# ---> 50     MAP = tda.get_MAP(my_posterior)
#      52     #if(adaptive_MH is True):
#      53    # print("check2")
#      54     if algo == "MH":
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tinyDA\utils.py:232, in get_MAP(posterior, **kwargs)
#     230 else:
#     231     initial_parameters = kwargs.pop("initial_parameters", posterior.prior.rvs())
# --> 232     MAP = minimize(
#     233         negative_log_posterior, initial_parameters, method=method, **kwargs
#     234     )
#     235 return MAP["x"]
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_minimize.py:708, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     706     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     707 elif meth == 'bfgs':
# --> 708     res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     709 elif meth == 'newton-cg':
#     710     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     711                              **options)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_optimize.py:1503, in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, c1, c2, hess_inv0, **unknown_options)
#    1500 pk = -np.dot(Hk, gfk)
#    1501 try:
#    1502     alpha_k, fc, gc, old_fval, old_old_fval, gfkp1 = \
# -> 1503              _line_search_wolfe12(f, myfprime, xk, pk, gfk,
#    1504                                   old_fval, old_old_fval, amin=1e-100,
#    1505                                   amax=1e100, c1=c1, c2=c2)
#    1506 except _LineSearchError:
#    1507     # Line search failed to find a better solution.
#    1508     warnflag = 2
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_optimize.py:1239, in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#    1225 """
#    1226 Same as line_search_wolfe1, but fall back to line_search_wolfe2 if
#    1227 suitable step length is not found, and raise an exception if a
#    (...)
#    1234
#    1235 """
#    1237 extra_condition = kwargs.pop('extra_condition', None)
# -> 1239 ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#    1240                          old_fval, old_old_fval,
#    1241                          **kwargs)
#    1243 if ret[0] is not None and extra_condition is not None:
#    1244     xp1 = xk + ret[0] * pk
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_linesearch.py:94, in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      90     return np.dot(gval[0], pk)
#      92 derphi0 = np.dot(gfk, pk)
# ---> 94 stp, fval, old_fval = scalar_search_wolfe1(
#      95         phi, derphi, old_fval, old_old_fval, derphi0,
#      96         c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#      98 return stp, fc[0], gc[0], fval, old_fval, gval[0]
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_linesearch.py:171, in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     168 maxiter = 100
#     170 dcsrch = DCSRCH(phi, derphi, c1, c2, xtol, amin, amax)
# --> 171 stp, phi1, phi0, task = dcsrch(
#     172     alpha1, phi0=phi0, derphi0=derphi0, maxiter=maxiter
#     173 )
#     175 return stp, phi1, phi0
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_dcsrch.py:255, in DCSRCH.__call__(self, alpha1, phi0, derphi0, maxiter)
#     253 if task[:2] == b"FG":
#     254     alpha1 = stp
# --> 255     phi1 = self.phi(stp)
#     256     derphi1 = self.derphi(stp)
#     257 else:
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_linesearch.py:85, in line_search_wolfe1.<locals>.phi(s)
#      83 def phi(s):
#      84     fc[0] += 1
# ---> 85     return f(xk + s*pk, *args)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_differentiable_functions.py:278, in ScalarFunction.fun(self, x)
#     276 if not np.array_equal(x, self.x):
#     277     self._update_x_impl(x)
# --> 278 self._update_fun()
#     279 return self.f
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_differentiable_functions.py:262, in ScalarFunction._update_fun(self)
#     260 def _update_fun(self):
#     261     if not self.f_updated:
# --> 262         self._update_fun_impl()
#     263         self.f_updated = True
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_differentiable_functions.py:163, in ScalarFunction.__init__.<locals>.update_fun()
#     162 def update_fun():
# --> 163     self.f = fun_wrapped(self.x)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\scipy\optimize\_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tinyDA\utils.py:223, in get_MAP.<locals>.<lambda>(parameters)
#     204 def get_MAP(posterior, **kwargs):
#     205     """Returns the Maximum a Posteriori estimate of a posterior.
#     206
#     207     Parameters
#    (...)
#     220         Maximum a Posteriori estimate.
#     221     """
# --> 223     negative_log_posterior = lambda parameters: -posterior.create_link(
#     224         parameters
#     225     ).posterior
#     227     method = kwargs.pop("method", None)
#     228     if method == "differential_evolution":
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tinyDA\posterior.py:95, in Posterior.create_link(self, parameters)
#      92 prior = self.prior.logpdf(parameters)
#      94 # get the model output and the qoi.
# ---> 95 model_output = self.model(parameters)
#      97 # extract model output and qoi.
#      98 if isinstance(model_output, tuple):
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1670, in LSTM.wrapper_prediction(self, x_test, multi_input)
#    1663         new_inputs = np.concatenate((t_grid_lstm[:,:,_], re_grid_lstm[:,:,_], ulf_train), axis = 2)
#    1665 #        new_inputs=new_inputs.reshape(1,new_inputs.shape[0],new_inputs.shape[1])
#    1666
#    1667 # # ATTENZIONE  sarebbe da rivedere. Qui stai adattando a dimensioni e ordine del caso Bruger, sarebbe da generalizzare mettendo parametri sempre in fondo o quanto meno specificare
#    1668 #         # new_inputs = np.concatenate((self.inputs[:, :1], x_final, self.inputs[:, 1:]), axis=1)
#    1669 #         # new_inputs=new_inputs.reshape(1,new_inputs.shape[0],new_inputs.shape[1])
# -> 1670         rep=self.prediction(new_inputs).flatten()
#    1672         return rep
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1586, in LSTM.prediction(self, x_test)
#    1583 else:
#    1584     with Suppressor():
# -> 1586         y_pred = self.model.predict(x_test)#[:,0]       # <--------------- commentato il 6/03
#    1587 return y_pred
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:446, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     441 @traceback_utils.filter_traceback
#     442 def predict(
#     443     self, x, batch_size=None, verbose="auto", steps=None, callbacks=None
#     444 ):
#     445     # Create an iterator that yields batches of input data.
# --> 446     epoch_iterator = TFEpochIterator(
#     447         x=x,
#     448         batch_size=batch_size,
#     449         steps_per_epoch=steps,
#     450         shuffle=False,
#     451         distribute_strategy=self.distribute_strategy,
#     452         steps_per_execution=self.steps_per_execution,
#     453     )
#     455     # Container that configures and calls callbacks.
#     456     if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:629, in TFEpochIterator.__init__(self, distribute_strategy, *args, **kwargs)
#     627 super().__init__(*args, **kwargs)
#     628 self._distribute_strategy = distribute_strategy
# --> 629 dataset = self._get_iterator()
#     630 if not isinstance(dataset, tf.distribute.DistributedDataset):
#     631     dataset = self._distribute_strategy.experimental_distribute_dataset(
#     632         dataset
#     633     )
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:638, in TFEpochIterator._get_iterator(self)
#     637 def _get_iterator(self):
# --> 638     return self.data_adapter.get_tf_dataset()
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:232, in ArrayDataAdapter.get_tf_dataset(self)
#     229     dataset = dataset.with_options(options)
#     230     return dataset
# --> 232 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     233 if shuffle == "batch":
#     234     indices_dataset = indices_dataset.map(tf.random.shuffle)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2356, in DatasetV2.flat_map(self, map_func, name)
#    2352 # Loaded lazily due to a circular dependency (dataset_ops -> flat_map_op ->
#    2353 # dataset_ops).
#    2354 # pylint: disable=g-import-not-at-top,protected-access
#    2355 from tensorflow.python.data.ops import flat_map_op
# -> 2356 return flat_map_op._flat_map(self, map_func, name=name)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\data\ops\flat_map_op.py:24, in _flat_map(input_dataset, map_func, name)
#      22 def _flat_map(input_dataset, map_func, name=None):  # pylint: disable=unused-private-name
#      23   """See `Dataset.flat_map()` for details."""
# ---> 24   return _FlatMapDataset(input_dataset, map_func, name)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\data\ops\flat_map_op.py:33, in _FlatMapDataset.__init__(self, input_dataset, map_func, name)
#      30 def __init__(self, input_dataset, map_func, name=None):
#      32   self._input_dataset = input_dataset
# ---> 33   self._map_func = structured_function.StructuredFunctionWrapper(
#      34       map_func, self._transformation_name(), dataset=input_dataset)
#      35   if not isinstance(self._map_func.output_structure, dataset_ops.DatasetSpec):
#      36     raise TypeError(
#      37         "The `map_func` argument must return a `Dataset` object. Got "
#      38         f"{dataset_ops.get_type(self._map_func.output_structure)!r}.")
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\data\ops\structured_function.py:265, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     258       warnings.warn(
#     259           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     260           "option is set, this option does not apply to tf.data functions. "
#     261           "To force eager execution of tf.data functions, please use "
#     262           "`tf.data.experimental.enable_debug_mode()`.")
#     263     fn_factory = trace_tf_function(defun_kwargs)
# --> 265 self._function = fn_factory()
#     266 # There is no graph to add in eager mode.
#     267 add_to_graph &= not context.executing_eagerly()
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:1251, in Function.get_concrete_function(self, *args, **kwargs)
#    1249 def get_concrete_function(self, *args, **kwargs):
#    1250   # Implements PolymorphicFunction.get_concrete_function.
# -> 1251   concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1252   concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1253   return concrete
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:1221, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1219   if self._variable_creation_config is None:
#    1220     initializers = []
# -> 1221     self._initialize(args, kwargs, add_initializers_to=initializers)
#    1222     self._initialize_uninitialized_variables(initializers)
#    1224 if self._created_variables:
#    1225   # In this case we have created variables on the first call, so we run the
#    1226   # version which is guaranteed to never create variables.
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:599, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     595 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597   # the function a weak reference to itself to avoid a reference cycle.
#     598   with OptionalXlaContext(compile_with_xla):
# --> 599     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600   return out
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\data\ops\structured_function.py:231, in StructuredFunctionWrapper.__init__.<locals>.trace_tf_function.<locals>.wrapped_fn(*args)
#     230 def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 231   ret = wrapper_helper(*args)
#     232   ret = structure.to_tensor_list(self._output_structure, ret)
#     233   return [ops.convert_to_tensor(t) for t in ret]
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\data\ops\structured_function.py:161, in StructuredFunctionWrapper.__init__.<locals>.wrapper_helper(*args)
#     159 if not _should_unpack(nested_args):
#     160   nested_args = (nested_args,)
# --> 161 ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     162 ret = variable_utils.convert_variables_to_tensors(ret)
#     163 if _should_pack(ret):
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:168, in ArrayDataAdapter.get_tf_dataset.<locals>.slice_batch_indices(indices)
#     165 flat_dataset = tf.data.Dataset.from_tensor_slices(first_k_indices)
#     166 if self._partial_batch_size:
#     167     index_remainder = tf.data.Dataset.from_tensors(
# --> 168         tf.slice(
#     169             indices, [num_in_full_batch], [self._partial_batch_size]
#     170         )
#     171     )
#     172     flat_dataset = flat_dataset.concatenate(index_remainder)
#     174 return flat_dataset
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\ops\array_ops.py:990, in slice(input_, begin, size, name)
#     938 @tf_export("slice")
#     939 @dispatch.add_dispatch_support
#     940 def slice(input_, begin, size, name=None):
#     941   # pylint: disable=redefined-builtin
#     942   """Extracts a slice from a tensor.
#     943
#     944   See also `tf.strided_slice`.
#    (...)
#     988     A `Tensor` the same type as `input_`.
#     989   """
# --> 990   return gen_array_ops._slice(input_, begin, size, name=name)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\ops\gen_array_ops.py:12197, in _slice(input, begin, size, name)
#   12195     pass  # Add nodes to the TensorFlow graph.
#   12196 # Add nodes to the TensorFlow graph.
# > 12197 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   12198       "Slice", input=input, begin=begin, size=size, name=name)
#   12199 _result = _outputs[:]
#   12200 if _execute.must_record_gradient():
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\op_def_library.py:778, in _apply_op_helper(op_type_name, name, **keywords)
#     776 with g.as_default(), ops.name_scope(name) as scope:
#     777   if fallback:
# --> 778     _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     779                            keywords, default_type_attr_map, attrs, inputs,
#     780                            input_types)
#     781     _ExtractRemainingAttrs(op_type_name, op_def, keywords,
#     782                            default_type_attr_map, attrs)
#     783     _ExtractAttrProto(op_type_name, op_def, attrs, attr_protos)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\op_def_library.py:551, in _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map, keywords, default_type_attr_map, attrs, inputs, input_types)
#     545       values = ops.convert_to_tensor(
#     546           values,
#     547           name=input_arg.name,
#     548           as_ref=input_arg.is_ref,
#     549           preferred_dtype=default_dtype)
#     550   else:
# --> 551     values = ops.convert_to_tensor(
#     552         values,
#     553         name=input_arg.name,
#     554         dtype=dtype,
#     555         as_ref=input_arg.is_ref,
#     556         preferred_dtype=default_dtype)
#     557 except TypeError as err:
#     558   if dtype is None:
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\ops.py:713, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     711 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     712 preferred_dtype = preferred_dtype or dtype_hint
# --> 713 return tensor_conversion_registry.convert(
#     714     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     715 )
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)
#     230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\constant_tensor_conversion.py:29, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#      26 from tensorflow.python.framework import constant_op  # pylint: disable=g-import-not-at-top
#      28 _ = as_ref
# ---> 29 return constant_op.constant(v, dtype=dtype, name=name)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\constant_op.py:276, in constant(value, dtype, shape, name)
#     177 @tf_export("constant", v1=[])
#     178 def constant(
#     179     value, dtype=None, shape=None, name="Const"
#     180 ) -> Union[ops.Operation, ops._EagerTensorBase]:
#     181   """Creates a constant tensor from a tensor-like object.
#     182
#     183   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     274     ValueError: if called on a symbolic tensor.
#     275   """
# --> 276   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     277                         allow_broadcast=True)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\constant_op.py:291, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     288       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     289   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 291 const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     292     value, dtype, shape, name, verify_shape, allow_broadcast
#     293 )
#     294 return const_tensor
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\ops.py:281, in _create_graph_constant(value, dtype, shape, name, verify_shape, allow_broadcast)
#     279 dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     280 attrs = {"value": tensor_value, "dtype": dtype_value}
# --> 281 const_tensor = g._create_op_internal(  # pylint: disable=protected-access
#     282     "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     284 if op_callbacks.should_invoke_op_callbacks():
#     285   # TODO(b/147670703): Once the special-op creation code paths
#     286   # are unified. Remove this `if` block.
#     287   callback_outputs = op_callbacks.invoke_op_callbacks(
#     288       "Const", tuple(), attrs, (const_tensor,), op_name=name, graph=g)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\func_graph.py:670, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     668   inp = self.capture(inp)
#     669   captured_inputs.append(inp)
# --> 670 return super()._create_op_internal(  # pylint: disable=protected-access
#     671     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     672     compute_device)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\ops.py:2682, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    2679 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    2680 # Session.run call cannot occur between creating and mutating the op.
#    2681 with self._mutation_lock():
# -> 2682   ret = Operation.from_node_def(
#    2683       node_def,
#    2684       self,
#    2685       inputs=inputs,
#    2686       output_types=dtypes,
#    2687       control_inputs=control_inputs,
#    2688       input_types=input_types,
#    2689       original_op=self._default_original_op,
#    2690       op_def=op_def,
#    2691   )
#    2692   self._create_op_helper(ret, compute_device=compute_device)
#    2693 return ret
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\ops.py:1177, in Operation.from_node_def(***failed resolving arguments***)
#    1174     control_input_ops.append(control_op)
#    1176 # Initialize c_op from node_def and other inputs
# -> 1177 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    1178 self = Operation(c_op, SymbolicTensor)
#    1179 self._init(g)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\ops.py:1034, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1030   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1031                                          serialized)
#    1033 try:
# -> 1034   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1035 except errors.InvalidArgumentError as e:
#    1036   # Convert to ValueError for backwards compatibility.
#    1037   raise ValueError(e.message)
#
# KeyboardInterrupt:

# %%
# true parameters
sigma_noise=[0.05,0.1]
n_data=[75]
parameter=np.array([re_grid_lstm_test[0,0]])
indices = np.where(input_test[:,:,1] == parameter)[0]
mean_prior=np.array([.5])
cov_prior=np.diag([ .5])
# cov_linkelihood
sigma=np.array([.1,4.])   # NB, con sigma piccolo (e.g. 1) funzia, sigma troppo gaìrande no

# adaptive metropolis
rwmh_cov = np.eye(1)
rmwh_scaling = np.array([0.5,2.])
rwmh_adaptive = True
iterations =2000
burnin = 1000
n_chains=2

algo="AM"
nh=91
random_indices =np.sort( np.random.choice(basis.shape[0], size=nh, replace=False))
print(random_indices)

estimateMF, errorMF= run_simulation(basis[random_indices,:],x_grid[random_indices,0],input_test,nh, n_data[0],T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
# FUnziona, obiettivo ora, ridurre varianza della posterior
# Out:
# Running chain, α = 0.18: 100%|██████████| 2000/2000 [03:53<00:00,  8.57it/s]
# Running chain, α = 0.22: 100%|██████████| 2000/2000 [04:09<00:00,  8.00it/s]
# c:\Users\Giacomo\miniconda3\Lib\site-packages\arviz\data\inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_239992\2860183556.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,datax,mean_prior, nh,nt,nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Running chain, α = 0.37: 100%|██████████| 2000/2000 [04:25<00:00,  7.54it/s]
# Running chain, α = 0.32: 100%|██████████| 2000/2000 [04:12<00:00,  7.92it/s]
# c:\Users\Giacomo\miniconda3\Lib\site-packages\arviz\data\inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_239992\2860183556.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,datax,mean_prior, nh,nt,nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Running chain, α = 0.34:  37%|███▋      | 731/2000 [01:35<02:59,  7.07it/s]c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1638: RuntimeWarning: overflow encountered in exp
#   return x/(t+1)/(1.0+np.exp(re*(x)/(4*t+4))*((t+1)/A0)**0.5)
# Running chain, α = 0.18:  78%|███████▊  | 1553/2000 [03:23<00:58,  7.64it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 24
#      21 random_indices =np.sort( np.random.choice(basis.shape[0], size=nh, replace=False))
#      22 print(random_indices)
# ---> 24 estimateMF, errorMF= run_simulation(basis[random_indices,:],x_grid[random_indices,0],input_test,nh, n_data[0],T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
#      25 # FUnziona, obiettivo ora, ridurre varianza della posterior
#
# Cell In[24], line 103, in run_simulation(basis, datax, datahf, nh, nt, T, mean_prior, cov_prior, Yhf, sigma_noise, n_data, parameters, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, final_model, algo)
#     101             nearest_x, y_obs = process_data(datahf, parameters, t_eval, Yhf)
#     102             print(nearest_x.shape)
# --> 103             estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,datax,mean_prior, nh,nt,nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
#     105 smallest_index = np.unravel_index(np.argmin(error), error.shape)
#     106 print(f"The best estimate is given by: sigma_noise={sigma_noise[smallest_index[0]]}, number of data= {n_data[smallest_index[1]]}, sigma={sigma[smallest_index[2]]}, rmwh_scaling={rmwh_scaling[smallest_index[3]]}")
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:121, in compute_time.<locals>.wrapper(*args, **kwargs)
#     119 def wrapper(*args, **kwargs):
#     120     init = time.time()
# --> 121     res = function(*args, **kwargs)
#     122     end = time.time()
#     123     timespam = end - init
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1749, in LSTM.param_inverse(self, basis, datax, mean_prior, nh, nt, x_data, cov_prior, cov_noise, cov_likelihood, y_obs, x_real, number_chains, N, burn_in, levels, diagnostic, rwmh_cov, rmwh_scaling, rwmh_adaptive, algo, transformation)
#    1746 if(rwmh_cov is None):
#    1747     rwmh_cov = np.eye(len(x_real))
# -> 1749 estimates=MCMC(my_posterior,N,burn_in,number_chains,diagnostic=diagnostic,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive,algo=algo,dim=dim)
#    1751 if diagnostic is True:
#    1752     plot_hist(estimates,x_real, self.wrapper_prediction(estimates), self.wrapper_prediction(x_real))
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\module_utils.py:67, in MCMC(my_posterior, N, burnin, n, diagnostic, rwmh_cov, rmwh_scaling, period, t0, rwmh_adaptive, algo, dim)
#      64 else:
#      65     raise ValueError("Unknown algorithm %s"%algo)
# ---> 67 my_chains = tda.sample(my_posterior, my_proposal, iterations=N, n_chains=n, force_sequential=True, initial_parameters=MAP)
#      68 idata = tda.to_inference_data(my_chains, burnin=burnin)
#      69 estimates=np.array(az.summary(idata)['mean'])
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tinyDA\sampler.py:198, in sample(posteriors, proposal, iterations, n_chains, initial_parameters, subsampling_rate, adaptive_error_model, store_coarse_chain, force_sequential, force_progress_bar)
#     195 if n_levels == 1:
#     196     # sequential sampling.
#     197     if not ray_is_available or n_chains == 1 or force_sequential:
# --> 198         samples = _sample_sequential(
#     199             posteriors, proposal, iterations, n_chains, initial_parameters
#     200         )
#     201     # parallel sampling.
#     202     else:
#     203         samples = _sample_parallel(
#     204             posteriors,
#     205             proposal,
#    (...)
#     209             force_progress_bar,
#     210         )
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tinyDA\sampler.py:283, in _sample_sequential(posteriors, proposal, iterations, n_chains, initial_parameters)
#     281     print("Sampling chain {}/{}".format(i + 1, n_chains))
#     282     chains.append(Chain(posteriors[0], proposal[i], initial_parameters[i]))
# --> 283     chains[i].sample(iterations)
#     285 info = {"sampler": "MH", "n_chains": n_chains, "iterations": iterations + 1}
#     286 chains = {"chain_{}".format(i): chain.chain for i, chain in enumerate(chains)}
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tinyDA\chain.py:105, in Chain.sample(self, iterations, progressbar)
#     102 proposal = self.proposal.make_proposal(self.chain[-1])
#     104 # create a link from that proposal.
# --> 105 proposal_link = self.posterior.create_link(proposal)
#     107 # compute the acceptance probability, which is unique to
#     108 # the proposal.
#     109 alpha = self.proposal.get_acceptance(proposal_link, self.chain[-1])
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tinyDA\posterior.py:95, in Posterior.create_link(self, parameters)
#      92 prior = self.prior.logpdf(parameters)
#      94 # get the model output and the qoi.
# ---> 95 model_output = self.model(parameters)
#      97 # extract model output and qoi.
#      98 if isinstance(model_output, tuple):
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1671, in LSTM.wrapper_prediction(self, x_test, multi_input)
#    1664         new_inputs = np.concatenate((t_grid_lstm[:,:,_], re_grid_lstm[:,:,_], ulf_train), axis = 2)
#    1666 #        new_inputs=new_inputs.reshape(1,new_inputs.shape[0],new_inputs.shape[1])
#    1667
#    1668 # # ATTENZIONE  sarebbe da rivedere. Qui stai adattando a dimensioni e ordine del caso Bruger, sarebbe da generalizzare mettendo parametri sempre in fondo o quanto meno specificare
#    1669 #         # new_inputs = np.concatenate((self.inputs[:, :1], x_final, self.inputs[:, 1:]), axis=1)
#    1670 #         # new_inputs=new_inputs.reshape(1,new_inputs.shape[0],new_inputs.shape[1])
# -> 1671         rep=self.prediction(new_inputs).flatten()
#    1673         return rep
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1586, in LSTM.prediction(self, x_test)
#    1583 else:
#    1584     with Suppressor():
# -> 1586         y_pred = self.model.predict(x_test)#[:,0]       # <--------------- commentato il 6/03
#    1587 return y_pred
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:446, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     441 @traceback_utils.filter_traceback
#     442 def predict(
#     443     self, x, batch_size=None, verbose="auto", steps=None, callbacks=None
#     444 ):
#     445     # Create an iterator that yields batches of input data.
# --> 446     epoch_iterator = TFEpochIterator(
#     447         x=x,
#     448         batch_size=batch_size,
#     449         steps_per_epoch=steps,
#     450         shuffle=False,
#     451         distribute_strategy=self.distribute_strategy,
#     452         steps_per_execution=self.steps_per_execution,
#     453     )
#     455     # Container that configures and calls callbacks.
#     456     if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:629, in TFEpochIterator.__init__(self, distribute_strategy, *args, **kwargs)
#     627 super().__init__(*args, **kwargs)
#     628 self._distribute_strategy = distribute_strategy
# --> 629 dataset = self._get_iterator()
#     630 if not isinstance(dataset, tf.distribute.DistributedDataset):
#     631     dataset = self._distribute_strategy.experimental_distribute_dataset(
#     632         dataset
#     633     )
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:638, in TFEpochIterator._get_iterator(self)
#     637 def _get_iterator(self):
# --> 638     return self.data_adapter.get_tf_dataset()
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:232, in ArrayDataAdapter.get_tf_dataset(self)
#     229     dataset = dataset.with_options(options)
#     230     return dataset
# --> 232 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     233 if shuffle == "batch":
#     234     indices_dataset = indices_dataset.map(tf.random.shuffle)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2356, in DatasetV2.flat_map(self, map_func, name)
#    2352 # Loaded lazily due to a circular dependency (dataset_ops -> flat_map_op ->
#    2353 # dataset_ops).
#    2354 # pylint: disable=g-import-not-at-top,protected-access
#    2355 from tensorflow.python.data.ops import flat_map_op
# -> 2356 return flat_map_op._flat_map(self, map_func, name=name)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\data\ops\flat_map_op.py:24, in _flat_map(input_dataset, map_func, name)
#      22 def _flat_map(input_dataset, map_func, name=None):  # pylint: disable=unused-private-name
#      23   """See `Dataset.flat_map()` for details."""
# ---> 24   return _FlatMapDataset(input_dataset, map_func, name)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\data\ops\flat_map_op.py:42, in _FlatMapDataset.__init__(self, input_dataset, map_func, name)
#      40 self._structure = self._map_func.output_structure._element_spec
#      41 self._name = name
# ---> 42 variant_tensor = gen_dataset_ops.flat_map_dataset(
#      43     input_dataset._variant_tensor,  # pylint: disable=protected-access
#      44     self._map_func.function.captured_inputs,
#      45     f=self._map_func.function,
#      46     **self._common_args)
#      47 super().__init__(input_dataset, variant_tensor)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:2445, in flat_map_dataset(input_dataset, other_arguments, f, output_types, output_shapes, metadata, name)
#    2443 if tld.is_eager:
#    2444   try:
# -> 2445     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    2446       _ctx, "FlatMapDataset", name, input_dataset, other_arguments, "f", f,
#    2447       "output_types", output_types, "output_shapes", output_shapes,
#    2448       "metadata", metadata)
#    2449     return _result
#    2450   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# true parameters
sigma_noise=[0.05,0.1]
n_data=[50]
parameter=np.array([re_grid_lstm_test[0,0]])
indices = np.where(input_test[:,:,1] == parameter)[0]
mean_prior=np.array([.5])
cov_prior=np.diag([ .5])
# cov_linkelihood
sigma=np.array([.1,4.])   # NB, con sigma piccolo (e.g. 1) funzia, sigma troppo gaìrande no

# adaptive metropolis
rwmh_cov = np.eye(1)
rmwh_scaling = np.array([0.5,2.])
rwmh_adaptive = True
iterations =2000
burnin = 1000
n_chains=2

algo="AM"
nh=101
random_indices =np.sort( np.random.choice(basis.shape[0], size=nh, replace=False))
print(random_indices)

estimateMF, errorMF= run_simulation(basis[random_indices,:],x_grid[random_indices,0],input_test,nh, n_data[0],T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
# FUnziona, obiettivo ora, ridurre varianza della posterior
# Out:
# Running chain, α = 0.22: 100%|██████████| 2000/2000 [03:20<00:00,  9.98it/s]
# Running chain, α = 0.27: 100%|██████████| 2000/2000 [03:31<00:00,  9.44it/s]
# c:\Users\Giacomo\miniconda3\Lib\site-packages\arviz\data\inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_239992\2860183556.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,datax,mean_prior, nh,nt,nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Running chain, α = 0.32: 100%|██████████| 2000/2000 [03:43<00:00,  8.94it/s]
# Running chain, α = 0.28: 100%|██████████| 2000/2000 [03:50<00:00,  8.67it/s]
# c:\Users\Giacomo\miniconda3\Lib\site-packages\arviz\data\inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_239992\2860183556.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,datax,mean_prior, nh,nt,nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Running chain, α = 0.29:  50%|█████     | 1003/2000 [01:53<01:45,  9.46it/s]c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1638: RuntimeWarning: overflow encountered in exp
#   return x/(t+1)/(1.0+np.exp(re*(x)/(4*t+4))*((t+1)/A0)**0.5)
# Running chain, α = 0.21: 100%|██████████| 2000/2000 [03:44<00:00,  8.89it/s]
# Running chain, α = 0.24: 100%|██████████| 2000/2000 [03:43<00:00,  8.94it/s]
# c:\Users\Giacomo\miniconda3\Lib\site-packages\arviz\data\inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_239992\2860183556.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,datax,mean_prior, nh,nt,nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Running chain, α = 0.28:  45%|████▌     | 909/2000 [01:43<02:01,  9.00it/s]c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1638: RuntimeWarning: overflow encountered in exp
#   return x/(t+1)/(1.0+np.exp(re*(x)/(4*t+4))*((t+1)/A0)**0.5)
# Running chain, α = 0.22: 100%|██████████| 2000/2000 [03:46<00:00,  8.82it/s]
# Running chain, α = 0.25: 100%|██████████| 2000/2000 [03:48<00:00,  8.77it/s]
# c:\Users\Giacomo\miniconda3\Lib\site-packages\arviz\data\inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_239992\2860183556.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,datax,mean_prior, nh,nt,nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Running chain, α = 0.23: 100%|██████████| 2000/2000 [03:46<00:00,  8.83it/s]
# Running chain, α = 0.25: 100%|██████████| 2000/2000 [03:45<00:00,  8.87it/s]
# c:\Users\Giacomo\miniconda3\Lib\site-packages\arviz\data\inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_239992\2860183556.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,datax,mean_prior, nh,nt,nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Running chain, α = 0.23: 100%|██████████| 2000/2000 [03:46<00:00,  8.82it/s]
# Running chain, α = 0.28: 100%|██████████| 2000/2000 [03:46<00:00,  8.82it/s]
# c:\Users\Giacomo\miniconda3\Lib\site-packages\arviz\data\inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_239992\2860183556.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,datax,mean_prior, nh,nt,nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Running chain, α = 0.32:  61%|██████    | 1220/2000 [02:18<01:34,  8.27it/s]c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1638: RuntimeWarning: overflow encountered in exp
#   return x/(t+1)/(1.0+np.exp(re*(x)/(4*t+4))*((t+1)/A0)**0.5)
# Running chain, α = 0.21: 100%|██████████| 2000/2000 [03:47<00:00,  8.78it/s]
# Running chain, α = 0.22: 100%|██████████| 2000/2000 [03:50<00:00,  8.69it/s]
# c:\Users\Giacomo\miniconda3\Lib\site-packages\arviz\data\inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_239992\2860183556.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,datax,mean_prior, nh,nt,nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Running chain, α = 0.27:  35%|███▍      | 693/2000 [01:19<02:41,  8.08it/s]c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1638: RuntimeWarning: overflow encountered in exp
#   return x/(t+1)/(1.0+np.exp(re*(x)/(4*t+4))*((t+1)/A0)**0.5)
# Running chain, α = 0.14: 100%|██████████| 2000/2000 [03:49<00:00,  8.73it/s]
# Running chain, α = 0.30: 100%|██████████| 2000/2000 [03:53<00:00,  8.58it/s]
# c:\Users\Giacomo\miniconda3\Lib\site-packages\arviz\data\inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_239992\2860183556.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,datax,mean_prior, nh,nt,nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)

# %%
x_grid[random_indices,0].shape
# Out:
# (70,)

# %%
x
# Out:
# (10,)

# %%
random_indices
# Out:
# array([ 13,  60,  41,  74,  76,  84,   9,  90,  63,  27,  68,  24,  53,
#         43,  39,  87,  30,  59,  89,  67,  94,  73,  32,  57,  11,  34,
#         40,  36,   2,  91,  81,  38,  72,  54,  52,   3,  20,  17,  37,
#         48,  28,   6,  85,  96,  95,  56,  71,  33,  10,  44,  77,   1,
#         64,  55,  19,  86,  21,  66,  93, 100,  31,  26,  97,  80,   4,
#         79,  78,  58,   8,  62])

# %%
x_grid[random_indices,:].shape
# Out:
# (70, 151)

# %%
basis.shape
# Out:
# (101, 16)

# %%
# true parameters
sigma_noise=[0.05,0.1]
n_data=[70]
parameter=np.array([re_grid_lstm_test[2,0]])
#indices = np.where(input_test[:,:,1] == parameter)[0]
mean_prior=np.array([.5])
cov_prior=np.diag([.5])
# cov_linkelihood
sigma=np.array([0.1,0.3,0.5,1,2,4.])   # NB, con sigma piccolo (e.g. 1) funzia, sigma troppo gaìrande no

# adaptive metropolis
rwmh_cov = np.eye(1)
rmwh_scaling = np.array([0.2])    # 0.05 sembra problema sia esplorazione
rwmh_adaptive = True
iterations =3000
burnin = 2000
n_chains=3

algo="MH"


# # true parameters
# sigma_noise=[0.05,0.1]
# n_data=[70]
# parameter=np.array([re_grid_lstm_test[0,0]])
# indices = np.where(input_test[:,:,1] == parameter)[0]
# mean_prior=np.array([.5])
# cov_prior=np.diag([ .5])
# # cov_linkelihood
# sigma=np.array([.5,4.])   # NB, con sigma piccolo (e.g. 1) funzia, sigma troppo gaìrande no

# # adaptive metropolis
# rwmh_cov = np.eye(1)
# rmwh_scaling = np.array([0.1,0.5,2.])
# rwmh_adaptive = True
# iterations =2000
# burnin = 1000
# n_chains=2

# algo="MH"
nh=50


estimateMF, errorMF= run_simulation(basis_new,input_test, T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
# FUnziona, obiettivo ora, ridurre varianza della posterior
# Out:
# Noise: 0.05
# Number of data: 70
# sigma: 0.1
# step random walk: 0.2
# (1, 70, 18)
# real values are [0.78947368]
# Sampling chain 1/3
# Running chain, α = 0.30: 100%|██████████| 3000/3000 [04:52<00:00, 10.26it/s]
# Sampling chain 2/3
# Running chain, α = 0.22: 100%|██████████| 3000/3000 [04:54<00:00, 10.17it/s]
# Sampling chain 3/3
# Running chain, α = 0.30: 100%|██████████| 3000/3000 [04:58<00:00, 10.05it/s]
# c:\Users\Giacomo\miniconda3\Lib\site-packages\arviz\data\inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [1.168]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  1.168  0.085   1.005    1.312      0.004    0.003     535.0     619.0
#
#     r_hat
# x0   1.01
# Autocorrelation...
# the difference between estimated values [0.37852632]
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_30144\3456175106.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# The function param_inverse took 886.9803185462952 seconds.
# sigma: 0.3
# step random walk: 0.2
# (1, 70, 18)
# real values are [0.78947368]
# Sampling chain 1/3
# Running chain, α = 0.29: 100%|██████████| 3000/3000 [04:59<00:00, 10.01it/s]
# Sampling chain 2/3
# Running chain, α = 0.50:   0%|          | 2/3000 [00:00<05:55,  8.44it/s]c:\Users\Giacomo\miniconda3\Lib\site-packages\tinyDA\proposal.py:236: RuntimeWarning: overflow encountered in exp
#   return np.exp(proposal_link.posterior - previous_link.posterior)
# Running chain, α = 0.21: 100%|██████████| 3000/3000 [05:12<00:00,  9.59it/s]
# Sampling chain 3/3
# Running chain, α = 0.20: 100%|██████████| 3000/3000 [05:29<00:00,  9.09it/s]
# c:\Users\Giacomo\miniconda3\Lib\site-packages\arviz\data\inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [1.094]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  1.094  0.199   0.723    1.444      0.009    0.006     522.0     506.0
#
#     r_hat
# x0   1.01
# Autocorrelation...
# the difference between estimated values [0.30452632]
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_30144\3456175106.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# The function param_inverse took 943.6198673248291 seconds.
# sigma: 0.5
# step random walk: 0.2
# (1, 70, 18)
# real values are [0.78947368]
# Sampling chain 1/3
# Running chain, α = 0.27: 100%|██████████| 3000/3000 [05:04<00:00,  9.87it/s]
# Sampling chain 2/3
# Running chain, α = 1.00:   0%|          | 0/3000 [00:00<?, ?it/s]c:\Users\Giacomo\miniconda3\Lib\site-packages\tinyDA\proposal.py:236: RuntimeWarning: overflow encountered in exp
#   return np.exp(proposal_link.posterior - previous_link.posterior)
# Running chain, α = 0.23: 100%|██████████| 3000/3000 [05:09<00:00,  9.69it/s]
# Sampling chain 3/3
# Running chain, α = 0.24:  83%|████████▎ | 2477/3000 [04:05<00:50, 10.28it/s]c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1639: RuntimeWarning: overflow encountered in exp
#   return x/(t+1)/(1.0+np.exp(re*(x)/(4*t+4))*((t+1)/A0)**0.5)
# Running chain, α = 0.22: 100%|██████████| 3000/3000 [04:58<00:00, 10.05it/s]
# c:\Users\Giacomo\miniconda3\Lib\site-packages\arviz\data\inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [1.091]
#      mean   sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  r_hat
# x0  1.091  0.3   0.529    1.614      0.013    0.009     569.0     627.0   1.01
# Autocorrelation...
# the difference between estimated values [0.30152632]
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_30144\3456175106.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# The function param_inverse took 913.4855852127075 seconds.
# sigma: 1.0
# step random walk: 0.2
# (1, 70, 18)
# real values are [0.78947368]
# Sampling chain 1/3
# Running chain, α = 0.94:   2%|▏         | 46/3000 [00:05<05:29,  8.97it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\ops\array_ops.py:4958, in gather(***failed resolving arguments***)
#    4955 try:
#    4956   # TODO(apassos) find a less bad way of detecting resource variables
#    4957   # without introducing a circular dependency.
# -> 4958   return params.sparse_read(indices, name=name)
#    4959 except AttributeError:
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\tensor.py:260, in Tensor.__getattr__(self, name)
#     255   raise AttributeError(
#     256       f"{type(self).__name__} object has no attribute '{name}'. " + """
#     257     If you are looking for numpy-related methods, please run the following:
#     258     tf.experimental.numpy.experimental_enable_numpy_behavior()
#     259   """)
# --> 260 self.__getattribute__(name)
#
# AttributeError: 'SymbolicTensor' object has no attribute 'sparse_read'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 44
#      22 # # true parameters
#      23 # sigma_noise=[0.05,0.1]
#      24 # n_data=[70]
#    (...)
#      39
#      40 # algo="MH"
#      41 nh=50
# ---> 44 estimateMF, errorMF= run_simulation(basis_new,input_test, T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
#      45 # FUnziona, obiettivo ora, ridurre varianza della posterior
#
# Cell In[17], line 103, in run_simulation(basis, datahf, T, mean_prior, cov_prior, Yhf, sigma_noise, n_data, parameters, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, final_model, algo)
#     101             nearest_x, y_obs = process_data(datahf, parameters, t_eval, Yhf)
#     102             print(nearest_x.shape)
# --> 103             estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
#     105 smallest_index = np.unravel_index(np.argmin(error), error.shape)
#     106 print(f"The best estimate is given by: sigma_noise={sigma_noise[smallest_index[0]]}, number of data= {n_data[smallest_index[1]]}, sigma={sigma[smallest_index[2]]}, rmwh_scaling={rmwh_scaling[smallest_index[3]]}")
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:121, in compute_time.<locals>.wrapper(*args, **kwargs)
#     119 def wrapper(*args, **kwargs):
#     120     init = time.time()
# --> 121     res = function(*args, **kwargs)
#     122     end = time.time()
#     123     timespam = end - init
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1748, in LSTM.param_inverse(self, basis, mean_prior, x_data, cov_prior, cov_noise, cov_likelihood, y_obs, x_real, number_chains, N, burn_in, levels, diagnostic, rwmh_cov, rmwh_scaling, rwmh_adaptive, algo, transformation)
#    1745 if(rwmh_cov is None):
#    1746     rwmh_cov = np.eye(len(x_real))
# -> 1748 estimates=MCMC(my_posterior,N,burn_in,number_chains,diagnostic=diagnostic,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive,algo=algo,dim=dim)
#    1750 if diagnostic is True:
#    1751     plot_hist(estimates,x_real, self.wrapper_prediction(estimates), self.wrapper_prediction(x_real))
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\module_utils.py:64, in MCMC(my_posterior, N, burnin, n, diagnostic, rwmh_cov, rmwh_scaling, period, t0, rwmh_adaptive, algo, dim)
#      61 else:
#      62     raise ValueError("Unknown algorithm %s"%algo)
# ---> 64 my_chains = tda.sample(my_posterior, my_proposal, iterations=N, n_chains=n, force_sequential=True, initial_parameters=MAP)
#      65 idata = tda.to_inference_data(my_chains, burnin=burnin)
#      66 estimates=np.array(az.summary(idata)['mean'])
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tinyDA\sampler.py:198, in sample(posteriors, proposal, iterations, n_chains, initial_parameters, subsampling_rate, adaptive_error_model, store_coarse_chain, force_sequential, force_progress_bar)
#     195 if n_levels == 1:
#     196     # sequential sampling.
#     197     if not ray_is_available or n_chains == 1 or force_sequential:
# --> 198         samples = _sample_sequential(
#     199             posteriors, proposal, iterations, n_chains, initial_parameters
#     200         )
#     201     # parallel sampling.
#     202     else:
#     203         samples = _sample_parallel(
#     204             posteriors,
#     205             proposal,
#    (...)
#     209             force_progress_bar,
#     210         )
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tinyDA\sampler.py:283, in _sample_sequential(posteriors, proposal, iterations, n_chains, initial_parameters)
#     281     print("Sampling chain {}/{}".format(i + 1, n_chains))
#     282     chains.append(Chain(posteriors[0], proposal[i], initial_parameters[i]))
# --> 283     chains[i].sample(iterations)
#     285 info = {"sampler": "MH", "n_chains": n_chains, "iterations": iterations + 1}
#     286 chains = {"chain_{}".format(i): chain.chain for i, chain in enumerate(chains)}
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tinyDA\chain.py:105, in Chain.sample(self, iterations, progressbar)
#     102 proposal = self.proposal.make_proposal(self.chain[-1])
#     104 # create a link from that proposal.
# --> 105 proposal_link = self.posterior.create_link(proposal)
#     107 # compute the acceptance probability, which is unique to
#     108 # the proposal.
#     109 alpha = self.proposal.get_acceptance(proposal_link, self.chain[-1])
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tinyDA\posterior.py:95, in Posterior.create_link(self, parameters)
#      92 prior = self.prior.logpdf(parameters)
#      94 # get the model output and the qoi.
# ---> 95 model_output = self.model(parameters)
#      97 # extract model output and qoi.
#      98 if isinstance(model_output, tuple):
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1672, in LSTM.wrapper_prediction(self, x_test, multi_input)
#    1665         new_inputs = np.concatenate((t_grid_lstm[:,:,_], re_grid_lstm[:,:,_], ulf_train), axis = 2)
#    1667 #        new_inputs=new_inputs.reshape(1,new_inputs.shape[0],new_inputs.shape[1])
#    1668
#    1669 # # ATTENZIONE  sarebbe da rivedere. Qui stai adattando a dimensioni e ordine del caso Bruger, sarebbe da generalizzare mettendo parametri sempre in fondo o quanto meno specificare
#    1670 #         # new_inputs = np.concatenate((self.inputs[:, :1], x_final, self.inputs[:, 1:]), axis=1)
#    1671 #         # new_inputs=new_inputs.reshape(1,new_inputs.shape[0],new_inputs.shape[1])
# -> 1672         rep=self.prediction(new_inputs).flatten()
#    1674         return rep
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1586, in LSTM.prediction(self, x_test)
#    1583 else:
#    1584     with Suppressor():
# -> 1586         y_pred = self.model.predict(x_test)#[:,0]       # <--------------- commentato il 6/03
#    1587 return y_pred
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:446, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     441 @traceback_utils.filter_traceback
#     442 def predict(
#     443     self, x, batch_size=None, verbose="auto", steps=None, callbacks=None
#     444 ):
#     445     # Create an iterator that yields batches of input data.
# --> 446     epoch_iterator = TFEpochIterator(
#     447         x=x,
#     448         batch_size=batch_size,
#     449         steps_per_epoch=steps,
#     450         shuffle=False,
#     451         distribute_strategy=self.distribute_strategy,
#     452         steps_per_execution=self.steps_per_execution,
#     453     )
#     455     # Container that configures and calls callbacks.
#     456     if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:629, in TFEpochIterator.__init__(self, distribute_strategy, *args, **kwargs)
#     627 super().__init__(*args, **kwargs)
#     628 self._distribute_strategy = distribute_strategy
# --> 629 dataset = self._get_iterator()
#     630 if not isinstance(dataset, tf.distribute.DistributedDataset):
#     631     dataset = self._distribute_strategy.experimental_distribute_dataset(
#     632         dataset
#     633     )
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:638, in TFEpochIterator._get_iterator(self)
#     637 def _get_iterator(self):
# --> 638     return self.data_adapter.get_tf_dataset()
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:236, in ArrayDataAdapter.get_tf_dataset(self)
#     233 if shuffle == "batch":
#     234     indices_dataset = indices_dataset.map(tf.random.shuffle)
# --> 236 dataset = slice_inputs(indices_dataset, self._inputs)
#     238 options = tf.data.Options()
#     239 options.experimental_distribute.auto_shard_policy = (
#     240     tf.data.experimental.AutoShardPolicy.DATA
#     241 )
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:215, in ArrayDataAdapter.get_tf_dataset.<locals>.slice_inputs(indices_dataset, inputs)
#     211         return x
#     213     return tree.traverse(grab_one, data)
# --> 215 dataset = dataset.map(
#     216     grab_batch, num_parallel_calls=tf.data.AUTOTUNE
#     217 )
#     219 # Default optimizations are disabled to avoid the overhead of
#     220 # (unnecessary) input pipeline graph serialization & deserialization
#     221 options = tf.data.Options()
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2311, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2307 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2308 # dataset_ops).
#    2309 # pylint: disable=g-import-not-at-top,protected-access
#    2310 from tensorflow.python.data.ops import map_op
# -> 2311 return map_op._map_v2(
#    2312     self,
#    2313     map_func,
#    2314     num_parallel_calls=num_parallel_calls,
#    2315     deterministic=deterministic,
#    2316     name=name)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\data\ops\map_op.py:40, in _map_v2(input_dataset, map_func, num_parallel_calls, deterministic, name)
#      37   return _MapDataset(
#      38       input_dataset, map_func, preserve_cardinality=True, name=name)
#      39 else:
# ---> 40   return _ParallelMapDataset(
#      41       input_dataset,
#      42       map_func,
#      43       num_parallel_calls=num_parallel_calls,
#      44       deterministic=deterministic,
#      45       preserve_cardinality=True,
#      46       name=name)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\data\ops\map_op.py:148, in _ParallelMapDataset.__init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#     146 self._input_dataset = input_dataset
#     147 self._use_inter_op_parallelism = use_inter_op_parallelism
# --> 148 self._map_func = structured_function.StructuredFunctionWrapper(
#     149     map_func,
#     150     self._transformation_name(),
#     151     dataset=input_dataset,
#     152     use_legacy_function=use_legacy_function)
#     153 if deterministic is None:
#     154   self._deterministic = "default"
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\data\ops\structured_function.py:265, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     258       warnings.warn(
#     259           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     260           "option is set, this option does not apply to tf.data functions. "
#     261           "To force eager execution of tf.data functions, please use "
#     262           "`tf.data.experimental.enable_debug_mode()`.")
#     263     fn_factory = trace_tf_function(defun_kwargs)
# --> 265 self._function = fn_factory()
#     266 # There is no graph to add in eager mode.
#     267 add_to_graph &= not context.executing_eagerly()
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:1251, in Function.get_concrete_function(self, *args, **kwargs)
#    1249 def get_concrete_function(self, *args, **kwargs):
#    1250   # Implements PolymorphicFunction.get_concrete_function.
# -> 1251   concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1252   concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1253   return concrete
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:1221, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1219   if self._variable_creation_config is None:
#    1220     initializers = []
# -> 1221     self._initialize(args, kwargs, add_initializers_to=initializers)
#    1222     self._initialize_uninitialized_variables(initializers)
#    1224 if self._created_variables:
#    1225   # In this case we have created variables on the first call, so we run the
#    1226   # version which is guaranteed to never create variables.
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:599, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     595 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597   # the function a weak reference to itself to avoid a reference cycle.
#     598   with OptionalXlaContext(compile_with_xla):
# --> 599     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600   return out
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\data\ops\structured_function.py:231, in StructuredFunctionWrapper.__init__.<locals>.trace_tf_function.<locals>.wrapped_fn(*args)
#     230 def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 231   ret = wrapper_helper(*args)
#     232   ret = structure.to_tensor_list(self._output_structure, ret)
#     233   return [ops.convert_to_tensor(t) for t in ret]
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\data\ops\structured_function.py:161, in StructuredFunctionWrapper.__init__.<locals>.wrapper_helper(*args)
#     159 if not _should_unpack(nested_args):
#     160   nested_args = (nested_args,)
# --> 161 ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     162 ret = variable_utils.convert_variables_to_tensors(ret)
#     163 if _should_pack(ret):
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:213, in ArrayDataAdapter.get_tf_dataset.<locals>.slice_inputs.<locals>.grab_batch(i, data)
#     210         return tf.gather(x, i, axis=0)
#     211     return x
# --> 213 return tree.traverse(grab_one, data)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\tree\tree_api.py:88, in traverse(func, structure, top_down)
#      41 @keras_export("keras.tree.traverse")
#      42 def traverse(func, structure, top_down=True):
#      43     """Traverses the given nested structure, applying the given function.
#      44
#      45     The traversal is depth-first. If `top_down` is True (default), parents
#    (...)
#      86         The structured output from the traversal.
#      87     """
# ---> 88     return tree_impl.traverse(func, structure, top_down=top_down)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\tree\optree_impl.py:51, in traverse(func, structure, top_down)
#      45         return optree.tree_unflatten(
#      46             treedef,
#      47             [traverse(func, c, top_down=top_down) for c in children],
#      48         )
#      50 if top_down:
# ---> 51     ret = func(structure)
#      52     if ret is None:
#      53         return traverse_children()
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:210, in ArrayDataAdapter.get_tf_dataset.<locals>.slice_inputs.<locals>.grab_batch.<locals>.grab_one(x)
#     208     return None
#     209 if tf.is_tensor(x):
# --> 210     return tf.gather(x, i, axis=0)
#     211 return x
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\ops\array_ops.py:4971, in gather_v2(params, indices, validate_indices, axis, batch_dims, name)
#    4963 @tf_export("gather", v1=[])
#    4964 @dispatch.add_dispatch_support
#    4965 def gather_v2(params,
#    (...)
#    4969               batch_dims=0,
#    4970               name=None):
# -> 4971   return gather(
#    4972       params,
#    4973       indices,
#    4974       validate_indices=validate_indices,
#    4975       name=name,
#    4976       axis=axis,
#    4977       batch_dims=batch_dims)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\util\deprecation.py:588, in deprecated_args.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     580         _PRINTED_WARNING[(func, arg_name)] = True
#     581       _log_deprecation(
#     582           'From %s: calling %s (from %s) with %s is deprecated and will '
#     583           'be removed %s.\nInstructions for updating:\n%s',
#    (...)
#     586           'in a future version' if date is None else ('after %s' % date),
#     587           instructions)
# --> 588 return func(*args, **kwargs)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\ops\array_ops.py:4960, in gather(***failed resolving arguments***)
#    4958   return params.sparse_read(indices, name=name)
#    4959 except AttributeError:
# -> 4960   return gen_array_ops.gather_v2(params, indices, axis, name=name)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\ops\gen_array_ops.py:4875, in gather_v2(params, indices, axis, batch_dims, name)
#    4873   batch_dims = 0
#    4874 batch_dims = _execute.make_int(batch_dims, "batch_dims")
# -> 4875 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    4876       "GatherV2", params=params, indices=indices, axis=axis,
#    4877                   batch_dims=batch_dims, name=name)
#    4878 _result = _outputs[:]
#    4879 if _execute.must_record_gradient():
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\op_def_library.py:778, in _apply_op_helper(op_type_name, name, **keywords)
#     776 with g.as_default(), ops.name_scope(name) as scope:
#     777   if fallback:
# --> 778     _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     779                            keywords, default_type_attr_map, attrs, inputs,
#     780                            input_types)
#     781     _ExtractRemainingAttrs(op_type_name, op_def, keywords,
#     782                            default_type_attr_map, attrs)
#     783     _ExtractAttrProto(op_type_name, op_def, attrs, attr_protos)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\op_def_library.py:551, in _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map, keywords, default_type_attr_map, attrs, inputs, input_types)
#     545       values = ops.convert_to_tensor(
#     546           values,
#     547           name=input_arg.name,
#     548           as_ref=input_arg.is_ref,
#     549           preferred_dtype=default_dtype)
#     550   else:
# --> 551     values = ops.convert_to_tensor(
#     552         values,
#     553         name=input_arg.name,
#     554         dtype=dtype,
#     555         as_ref=input_arg.is_ref,
#     556         preferred_dtype=default_dtype)
#     557 except TypeError as err:
#     558   if dtype is None:
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\ops.py:713, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     711 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     712 preferred_dtype = preferred_dtype or dtype_hint
# --> 713 return tensor_conversion_registry.convert(
#     714     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     715 )
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)
#     230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\constant_tensor_conversion.py:29, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#      26 from tensorflow.python.framework import constant_op  # pylint: disable=g-import-not-at-top
#      28 _ = as_ref
# ---> 29 return constant_op.constant(v, dtype=dtype, name=name)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\constant_op.py:276, in constant(value, dtype, shape, name)
#     177 @tf_export("constant", v1=[])
#     178 def constant(
#     179     value, dtype=None, shape=None, name="Const"
#     180 ) -> Union[ops.Operation, ops._EagerTensorBase]:
#     181   """Creates a constant tensor from a tensor-like object.
#     182
#     183   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     274     ValueError: if called on a symbolic tensor.
#     275   """
# --> 276   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     277                         allow_broadcast=True)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\constant_op.py:291, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     288       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     289   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 291 const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     292     value, dtype, shape, name, verify_shape, allow_broadcast
#     293 )
#     294 return const_tensor
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\ops.py:281, in _create_graph_constant(value, dtype, shape, name, verify_shape, allow_broadcast)
#     279 dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     280 attrs = {"value": tensor_value, "dtype": dtype_value}
# --> 281 const_tensor = g._create_op_internal(  # pylint: disable=protected-access
#     282     "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     284 if op_callbacks.should_invoke_op_callbacks():
#     285   # TODO(b/147670703): Once the special-op creation code paths
#     286   # are unified. Remove this `if` block.
#     287   callback_outputs = op_callbacks.invoke_op_callbacks(
#     288       "Const", tuple(), attrs, (const_tensor,), op_name=name, graph=g)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\func_graph.py:670, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     668   inp = self.capture(inp)
#     669   captured_inputs.append(inp)
# --> 670 return super()._create_op_internal(  # pylint: disable=protected-access
#     671     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     672     compute_device)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\ops.py:2682, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    2679 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    2680 # Session.run call cannot occur between creating and mutating the op.
#    2681 with self._mutation_lock():
# -> 2682   ret = Operation.from_node_def(
#    2683       node_def,
#    2684       self,
#    2685       inputs=inputs,
#    2686       output_types=dtypes,
#    2687       control_inputs=control_inputs,
#    2688       input_types=input_types,
#    2689       original_op=self._default_original_op,
#    2690       op_def=op_def,
#    2691   )
#    2692   self._create_op_helper(ret, compute_device=compute_device)
#    2693 return ret
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\ops.py:1177, in Operation.from_node_def(***failed resolving arguments***)
#    1174     control_input_ops.append(control_op)
#    1176 # Initialize c_op from node_def and other inputs
# -> 1177 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    1178 self = Operation(c_op, SymbolicTensor)
#    1179 self._init(g)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tensorflow\python\framework\ops.py:1034, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1030   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1031                                          serialized)
#    1033 try:
# -> 1034   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1035 except errors.InvalidArgumentError as e:
#    1036   # Convert to ValueError for backwards compatibility.
#    1037   raise ValueError(e.message)
#
# KeyboardInterrupt:

# %%
# true parameters
sigma_noise=[0.05,0.1]
n_data=[70]
parameter=np.array([re_grid_lstm_test[0,0]])
#indices = np.where(input_test[:,:,1] == parameter)[0]
mean_prior=np.array([.5])
cov_prior=np.diag([.5])
# cov_linkelihood
sigma=np.array([0.1,0.3,0.5,1,2,4.])   # NB, con sigma piccolo (e.g. 1) funzia, sigma troppo gaìrande no

# adaptive metropolis
rwmh_cov = np.eye(1)
rmwh_scaling = np.array([0.2])    # 0.05 sembra problema sia esplorazione
rwmh_adaptive = True
iterations =3000
burnin = 2000
n_chains=3

algo="MH"


# # true parameters
# sigma_noise=[0.05,0.1]
# n_data=[70]
# parameter=np.array([re_grid_lstm_test[0,0]])
# indices = np.where(input_test[:,:,1] == parameter)[0]
# mean_prior=np.array([.5])
# cov_prior=np.diag([ .5])
# # cov_linkelihood
# sigma=np.array([.5,4.])   # NB, con sigma piccolo (e.g. 1) funzia, sigma troppo gaìrande no

# # adaptive metropolis
# rwmh_cov = np.eye(1)
# rmwh_scaling = np.array([0.1,0.5,2.])
# rwmh_adaptive = True
# iterations =2000
# burnin = 1000
# n_chains=2

# algo="MH"
nh=50


estimateMF, errorMF= run_simulation(basis_new,input_test, T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
# FUnziona, obiettivo ora, ridurre varianza della posterior
# Out:
# Noise: 0.05
# Number of data: 70
# sigma: 0.1
# step random walk: 0.2
# (1, 70, 18)
# real values are [0.36842105]
# Sampling chain 1/3
# Running chain, α = 0.23: 100%|██████████| 3000/3000 [05:01<00:00,  9.95it/s]
# Sampling chain 2/3
# Running chain, α = 0.24: 100%|██████████| 3000/3000 [05:16<00:00,  9.47it/s]
# Sampling chain 3/3
# Running chain, α = 0.21: 100%|██████████| 3000/3000 [06:20<00:00,  7.89it/s]
# c:\Users\Giacomo\miniconda3\Lib\site-packages\arviz\data\inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [-1.083]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0 -1.083  2.871  -5.182    1.058       1.65    1.303       5.0      43.0
#
#     r_hat
# x0   1.69
# Autocorrelation...
# the difference between estimated values [1.45142105]
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_30144\3456175106.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# The function param_inverse took 999.8561813831329 seconds.
# sigma: 0.3
# step random walk: 0.2
# (1, 70, 18)
# real values are [0.36842105]
# Sampling chain 1/3
# Running chain, α = 0.19: 100%|██████████| 3000/3000 [05:58<00:00,  8.37it/s]
# Sampling chain 2/3
# Running chain, α = 0.24: 100%|██████████| 3000/3000 [07:27<00:00,  6.70it/s]
# Sampling chain 3/3
# Running chain, α = 0.22: 100%|██████████| 3000/3000 [06:36<00:00,  7.57it/s]
# c:\Users\Giacomo\miniconda3\Lib\site-packages\arviz\data\inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [0.892]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  0.892  0.218   0.519    1.277       0.01    0.007     442.0     436.0
#
#     r_hat
# x0   1.02
# Autocorrelation...
# the difference between estimated values [0.52357895]
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_30144\3456175106.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# The function param_inverse took 1203.4075808525085 seconds.
# sigma: 0.5
# step random walk: 0.2
# (1, 70, 18)
# real values are [0.36842105]
# Sampling chain 1/3
# Running chain, α = 0.25:   0%|          | 2/3000 [00:00<05:26,  9.19it/s]c:\Users\Giacomo\miniconda3\Lib\site-packages\tinyDA\proposal.py:236: RuntimeWarning: overflow encountered in exp
#   return np.exp(proposal_link.posterior - previous_link.posterior)
# Running chain, α = 0.42:  14%|█▎        | 408/3000 [00:43<04:35,  9.40it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 44
#      22 # # true parameters
#      23 # sigma_noise=[0.05,0.1]
#      24 # n_data=[70]
#    (...)
#      39
#      40 # algo="MH"
#      41 nh=50
# ---> 44 estimateMF, errorMF= run_simulation(basis_new,input_test, T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
#      45 # FUnziona, obiettivo ora, ridurre varianza della posterior
#
# Cell In[17], line 103, in run_simulation(basis, datahf, T, mean_prior, cov_prior, Yhf, sigma_noise, n_data, parameters, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, final_model, algo)
#     101             nearest_x, y_obs = process_data(datahf, parameters, t_eval, Yhf)
#     102             print(nearest_x.shape)
# --> 103             estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
#     105 smallest_index = np.unravel_index(np.argmin(error), error.shape)
#     106 print(f"The best estimate is given by: sigma_noise={sigma_noise[smallest_index[0]]}, number of data= {n_data[smallest_index[1]]}, sigma={sigma[smallest_index[2]]}, rmwh_scaling={rmwh_scaling[smallest_index[3]]}")
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:121, in compute_time.<locals>.wrapper(*args, **kwargs)
#     119 def wrapper(*args, **kwargs):
#     120     init = time.time()
# --> 121     res = function(*args, **kwargs)
#     122     end = time.time()
#     123     timespam = end - init
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1748, in LSTM.param_inverse(self, basis, mean_prior, x_data, cov_prior, cov_noise, cov_likelihood, y_obs, x_real, number_chains, N, burn_in, levels, diagnostic, rwmh_cov, rmwh_scaling, rwmh_adaptive, algo, transformation)
#    1745 if(rwmh_cov is None):
#    1746     rwmh_cov = np.eye(len(x_real))
# -> 1748 estimates=MCMC(my_posterior,N,burn_in,number_chains,diagnostic=diagnostic,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive,algo=algo,dim=dim)
#    1750 if diagnostic is True:
#    1751     plot_hist(estimates,x_real, self.wrapper_prediction(estimates), self.wrapper_prediction(x_real))
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\module_utils.py:64, in MCMC(my_posterior, N, burnin, n, diagnostic, rwmh_cov, rmwh_scaling, period, t0, rwmh_adaptive, algo, dim)
#      61 else:
#      62     raise ValueError("Unknown algorithm %s"%algo)
# ---> 64 my_chains = tda.sample(my_posterior, my_proposal, iterations=N, n_chains=n, force_sequential=True, initial_parameters=MAP)
#      65 idata = tda.to_inference_data(my_chains, burnin=burnin)
#      66 estimates=np.array(az.summary(idata)['mean'])
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tinyDA\sampler.py:198, in sample(posteriors, proposal, iterations, n_chains, initial_parameters, subsampling_rate, adaptive_error_model, store_coarse_chain, force_sequential, force_progress_bar)
#     195 if n_levels == 1:
#     196     # sequential sampling.
#     197     if not ray_is_available or n_chains == 1 or force_sequential:
# --> 198         samples = _sample_sequential(
#     199             posteriors, proposal, iterations, n_chains, initial_parameters
#     200         )
#     201     # parallel sampling.
#     202     else:
#     203         samples = _sample_parallel(
#     204             posteriors,
#     205             proposal,
#    (...)
#     209             force_progress_bar,
#     210         )
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tinyDA\sampler.py:283, in _sample_sequential(posteriors, proposal, iterations, n_chains, initial_parameters)
#     281     print("Sampling chain {}/{}".format(i + 1, n_chains))
#     282     chains.append(Chain(posteriors[0], proposal[i], initial_parameters[i]))
# --> 283     chains[i].sample(iterations)
#     285 info = {"sampler": "MH", "n_chains": n_chains, "iterations": iterations + 1}
#     286 chains = {"chain_{}".format(i): chain.chain for i, chain in enumerate(chains)}
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tinyDA\chain.py:105, in Chain.sample(self, iterations, progressbar)
#     102 proposal = self.proposal.make_proposal(self.chain[-1])
#     104 # create a link from that proposal.
# --> 105 proposal_link = self.posterior.create_link(proposal)
#     107 # compute the acceptance probability, which is unique to
#     108 # the proposal.
#     109 alpha = self.proposal.get_acceptance(proposal_link, self.chain[-1])
#
# File c:\Users\Giacomo\miniconda3\Lib\site-packages\tinyDA\posterior.py:95, in Posterior.create_link(self, parameters)
#      92 prior = self.prior.logpdf(parameters)
#      94 # get the model output and the qoi.
# ---> 95 model_output = self.model(parameters)
#      97 # extract model output and qoi.
#      98 if isinstance(model_output, tuple):
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1672, in LSTM.wrapper_prediction(self, x_test, multi_input)
#    1665         new_inputs = np.concatenate((t_grid_lstm[:,:,_], re_grid_lstm[:,:,_], ulf_train), axis = 2)
#    1667 #        new_inputs=new_inputs.reshape(1,new_inputs.shape[0],new_inputs.shape[1])
#    1668
#    1669 # # ATTENZIONE  sarebbe da rivedere. Qui stai adattando a dimensioni e ordine del caso Bruger, sarebbe da generalizzare mettendo parametri sempre in fondo o quanto meno specificare
#    1670 #         # new_inputs = np.concatenate((self.inputs[:, :1], x_final, self.inputs[:, 1:]), axis=1)
#    1671 #         # new_inputs=new_inputs.reshape(1,new_inputs.shape[0],new_inputs.shape[1])
# -> 1672         rep=self.prediction(new_inputs).flatten()
#    1674         return rep
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\prova_Burger\../utils\Structure2.py:1584, in LSTM.prediction(self, x_test)
#    1582     y_pred=self.model.predict(x_test)#[:,0]             # <-------------  commentato il 6/03
#    1583 else:
# -> 1584     with Suppressor():
#    1586         y_pred = self.model.predict(x_test)#[:,0]       # <--------------- commentato il 6/03
#    1587 return y_pred
#
# File c:\Users\Giacomo\miniconda3\Lib\contextlib.py:141, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     138     except StopIteration:
#     139         raise RuntimeError("generator didn't yield") from None
# --> 141 def __exit__(self, typ, value, traceback):
#     142     if typ is None:
#     143         try:
#
# KeyboardInterrupt:

# %%
# true parameters
sigma_noise=[0.05,0.1]
n_data=[70]
parameter=np.array([re_grid_lstm_test[0,0]])
#indices = np.where(input_test[:,:,1] == parameter)[0]
mean_prior=np.array([.5])
cov_prior=np.diag([.5])
# cov_linkelihood
sigma=np.array([0.5,1,2,4.])   # NB, con sigma piccolo (e.g. 1) funzia, sigma troppo gaìrande no

# adaptive metropolis
rwmh_cov = np.eye(1)
rmwh_scaling = np.array([0.2])    # 0.05 sembra problema sia esplorazione
rwmh_adaptive = True
iterations =2000
burnin = 1500
n_chains=2

algo="MH"


# # true parameters
# sigma_noise=[0.05,0.1]
# n_data=[70]
# parameter=np.array([re_grid_lstm_test[0,0]])
# indices = np.where(input_test[:,:,1] == parameter)[0]
# mean_prior=np.array([.5])
# cov_prior=np.diag([ .5])
# # cov_linkelihood
# sigma=np.array([.5,4.])   # NB, con sigma piccolo (e.g. 1) funzia, sigma troppo gaìrande no

# # adaptive metropolis
# rwmh_cov = np.eye(1)
# rmwh_scaling = np.array([0.1,0.5,2.])
# rwmh_adaptive = True
# iterations =2000
# burnin = 1000
# n_chains=2

# algo="MH"
nh=50


estimateMF, errorMF= run_simulation(basis_new,input_test, T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
# FUnziona, obiettivo ora, ridurre varianza della posterior
# Out:
# Running chain, α = 0.30: 100%|██████████| 2000/2000 [03:43<00:00,  8.95it/s]
# Running chain, α = 0.30: 100%|██████████| 2000/2000 [04:25<00:00,  7.54it/s]
# Running chain, α = 0.22: 100%|██████████| 2000/2000 [04:59<00:00,  6.68it/s]
# c:\Users\Giacomo\miniconda3\Lib\site-packages\arviz\data\inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_30144\3456175106.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Running chain, α = 0.79:  10%|█         | 206/2000 [00:30<04:21,  6.86it/s]

# %%
# true parameters
sigma_noise=[0.05,0.1]
n_data=[110]
parameter=np.array([re_grid_lstm_test[0,0]])
#indices = np.where(input_test[:,:,1] == parameter)[0]
mean_prior=np.array([.5])
cov_prior=np.diag([1])
# cov_linkelihood
sigma=np.array([1,2,4.])   # NB, con sigma piccolo (e.g. 1) funzia, sigma troppo gaìrande no

# adaptive metropolis
rwmh_cov = np.eye(1)
rmwh_scaling = np.array([0.1,0.2,0.05])
rwmh_adaptive = True
iterations =2000
burnin = 1000
n_chains=2

algo="MH"


estimateMF, errorMF= run_simulation(basis,input_test, T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
# FUnziona, obiettivo ora, ridurre varianza della posterior
# Out:
# Noise: 0.05
# Number of data: 110
# sigma: 1.0
# step random walk: 0.1
# (1, 110, 18)
# real values are [0.36842105]
# Sampling chain 1/2
# Running chain, α = 0.26: 100%|██████████| 2000/2000 [09:22<00:00,  3.55it/s]
# Sampling chain 2/2
# Running chain, α = 0.18: 100%|██████████| 2000/2000 [09:22<00:00,  3.56it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [0.186]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  0.186  0.061   0.066    0.273      0.004    0.003     263.0     279.0
#
#     r_hat
# x0   1.01
# Autocorrelation...
# the difference between estimated values [0.18242105]
# The function param_inverse took 1126.8373420238495 seconds.
# step random walk: 0.2
# (1, 110, 18)
# real values are [0.36842105]
# Sampling chain 1/2
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_13904\3456175106.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Running chain, α = 0.25: 100%|██████████| 2000/2000 [09:15<00:00,  3.60it/s]
# Sampling chain 2/2
# Running chain, α = 0.13: 100%|██████████| 2000/2000 [09:08<00:00,  3.65it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [0.196]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  0.196  0.059   0.071    0.272      0.004    0.003     215.0     334.0
#
#     r_hat
# x0   1.01
# Autocorrelation...
# the difference between estimated values [0.17242105]
# The function param_inverse took 1105.7467200756073 seconds.
# step random walk: 0.05
# (1, 110, 18)
# real values are [0.36842105]
# Sampling chain 1/2
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_13904\3456175106.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Running chain, α = 0.23: 100%|██████████| 2000/2000 [09:14<00:00,  3.61it/s]
# Sampling chain 2/2
# Running chain, α = 0.29: 100%|██████████| 2000/2000 [09:13<00:00,  3.61it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [0.321]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  0.321  0.277   0.055    0.933       0.17    0.136       4.0      25.0
#
#     r_hat
# x0   1.42
# Autocorrelation...
# the difference between estimated values [0.04742105]
# The function param_inverse took 1110.0197749137878 seconds.
# sigma: 2.0
# step random walk: 0.1
# (1, 110, 18)
# real values are [0.36842105]
# Sampling chain 1/2
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_13904\3456175106.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Running chain, α = 0.09: 100%|██████████| 2000/2000 [09:18<00:00,  3.58it/s]
# Sampling chain 2/2
# Running chain, α = 0.26: 100%|██████████| 2000/2000 [09:17<00:00,  3.59it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [-0.368]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0 -0.368  0.931  -1.266    1.252      0.613    0.505       3.0      38.0
#
#     r_hat
# x0   1.85
# Autocorrelation...
# the difference between estimated values [0.73642105]
# The function param_inverse took 1117.4563705921173 seconds.
# step random walk: 0.2
# (1, 110, 18)
# real values are [0.36842105]
# Sampling chain 1/2
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_13904\3456175106.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Running chain, α = 0.25:   1%|          | 23/2000 [00:07<10:13,  3.22it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 22
#      17 n_chains=2
#      19 algo="MH"
# ---> 22 estimateMF, errorMF= run_simulation(basis,input_test, T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
#      23 # FUnziona, obiettivo ora, ridurre varianza della posterior
#
# Cell In[14], line 103, in run_simulation(basis, datahf, T, mean_prior, cov_prior, Yhf, sigma_noise, n_data, parameters, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, final_model, algo)
#     101             nearest_x, y_obs = process_data(datahf, parameters, t_eval, Yhf)
#     102             print(nearest_x.shape)
# --> 103             estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
#     105 smallest_index = np.unravel_index(np.argmin(error), error.shape)
#     106 print(f"The best estimate is given by: sigma_noise={sigma_noise[smallest_index[0]]}, number of data= {n_data[smallest_index[1]]}, sigma={sigma[smallest_index[2]]}, rmwh_scaling={rmwh_scaling[smallest_index[3]]}")
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:101, in compute_time.<locals>.wrapper(*args, **kwargs)
#      99 def wrapper(*args, **kwargs):
#     100     init = time.time()
# --> 101     res = function(*args, **kwargs)
#     102     end = time.time()
#     103     timespam = end - init
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:1117, in LSTM.param_inverse(self, basis, mean_prior, x_data, cov_prior, cov_noise, cov_likelihood, y_obs, x_real, number_chains, N, burn_in, levels, diagnostic, rwmh_cov, rmwh_scaling, rwmh_adaptive, algo, transformation)
#    1114 if(rwmh_cov is None):
#    1115     rwmh_cov = np.eye(len(x_real))
# -> 1117 estimates=MCMC(my_posterior,N,burn_in,number_chains,diagnostic=diagnostic,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive,algo=algo,dim=dim)
#    1119 if diagnostic is True:
#    1120     plot_hist(estimates,x_real, self.wrapper_prediction(estimates), self.wrapper_prediction(x_real))
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\module_utils.py:64, in MCMC(my_posterior, N, burnin, n, diagnostic, rwmh_cov, rmwh_scaling, period, t0, rwmh_adaptive, algo, dim)
#      61 else:
#      62     raise ValueError("Unknown algorithm %s"%algo)
# ---> 64 my_chains = tda.sample(my_posterior, my_proposal, iterations=N, n_chains=n, force_sequential=True, initial_parameters=MAP)
#      65 idata = tda.to_inference_data(my_chains, burnin=burnin)
#      66 estimates=np.array(az.summary(idata)['mean'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\sampler.py:198, in sample(posteriors, proposal, iterations, n_chains, initial_parameters, subsampling_rate, adaptive_error_model, store_coarse_chain, force_sequential, force_progress_bar)
#     195 if n_levels == 1:
#     196     # sequential sampling.
#     197     if not ray_is_available or n_chains == 1 or force_sequential:
# --> 198         samples = _sample_sequential(
#     199             posteriors, proposal, iterations, n_chains, initial_parameters
#     200         )
#     201     # parallel sampling.
#     202     else:
#     203         samples = _sample_parallel(
#     204             posteriors,
#     205             proposal,
#    (...)
#     209             force_progress_bar,
#     210         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\sampler.py:283, in _sample_sequential(posteriors, proposal, iterations, n_chains, initial_parameters)
#     281     print("Sampling chain {}/{}".format(i + 1, n_chains))
#     282     chains.append(Chain(posteriors[0], proposal[i], initial_parameters[i]))
# --> 283     chains[i].sample(iterations)
#     285 info = {"sampler": "MH", "n_chains": n_chains, "iterations": iterations + 1}
#     286 chains = {"chain_{}".format(i): chain.chain for i, chain in enumerate(chains)}
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\chain.py:105, in Chain.sample(self, iterations, progressbar)
#     102 proposal = self.proposal.make_proposal(self.chain[-1])
#     104 # create a link from that proposal.
# --> 105 proposal_link = self.posterior.create_link(proposal)
#     107 # compute the acceptance probability, which is unique to
#     108 # the proposal.
#     109 alpha = self.proposal.get_acceptance(proposal_link, self.chain[-1])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\posterior.py:80, in Posterior.create_link(self, parameters)
#      77 prior = self.prior.logpdf(parameters)
#      79 # get the model output and the qoi.
# ---> 80 model_output = self.model(parameters)
#      82 # extract model output and qoi.
#      83 if isinstance(model_output, tuple):
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:1026, in LSTM.wrapper_prediction(self, x_test, multi_input)
#    1024     for i in range(x.shape[0]):
#    1025         u_lf[0, n, i] = u_LF(x[i], self.inputs[0,n,0], denormalization(x_final[0],re_max,re_min))
# -> 1026         u_hf[0, n, i] = u_HF(x[i], self.inputs[0,n,0], denormalization(x_final[0],re_max,re_min))
#    1029 u_hf=np.reshape(u_hf, (110,nh))
#    1030 basis, S = compute_randomized_SVD(u_hf, n_POD, nh, 1)
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:1002, in LSTM.wrapper_prediction.<locals>.u_HF(x, t, re)
#     999     A0 = np.exp(re/8.0)
#    1000     return x/(t+1)/(1.0+np.exp(re*(x)/(4*t+4))*((t+1)/A0)**0.5)
# -> 1002 def u_HF(x, t, re):
#    1003     A0 = np.exp(re/8.0)
#    1004     return x/(t+1)/(1.0+np.exp(re*(x**2)/(4*t+4))*((t+1)/A0)**0.5)
#
# KeyboardInterrupt:

# %%
re_grid_lstm_test[2,0]
# Out:
# 0.7894736842105263

# %%
# true parameters
sigma_noise=[0.05,0.1]
n_data=[70]
parameter=np.array([re_grid_lstm_test[2,0]])
#indices = np.where(input_test[:,:,1] == parameter)[0]
mean_prior=np.array([.5])
cov_prior=np.diag([.5])
# cov_linkelihood
sigma=np.array([0.1,0.3,0.5,1,2,4.])   # NB, con sigma piccolo (e.g. 1) funzia, sigma troppo gaìrande no

# adaptive metropolis
rwmh_cov = np.eye(1)
rmwh_scaling = np.array([0.2])    # 0.05 sembra problema sia esplorazione
rwmh_adaptive = True
iterations =3000
burnin = 2000
n_chains=3

algo="MH"


estimateMF, errorMF= run_simulation(basis,input_test, T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
# FUnziona, obiettivo ora, ridurre varianza della posterior
# Out:
# Noise: 0.05
# Number of data: 70
# sigma: 0.1
# step random walk: 0.2
# (1, 70, 18)
# real values are [0.78947368]
# Sampling chain 1/3
# Running chain, α = 0.22: 100%|██████████| 3000/3000 [06:42<00:00,  7.46it/s]
# Sampling chain 2/3
# Running chain, α = 0.24: 100%|██████████| 3000/3000 [06:38<00:00,  7.54it/s]
# Sampling chain 3/3
# Running chain, α = 0.19: 100%|██████████| 3000/3000 [06:27<00:00,  7.74it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [0.915]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  0.915  0.145   0.653    1.195      0.006    0.005     533.0     366.0
#
#     r_hat
# x0   1.01
# Autocorrelation...
# the difference between estimated values [0.12552632]
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_901768\3456175106.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# The function param_inverse took 1188.80401968956 seconds.
# sigma: 0.3
# step random walk: 0.2
# (1, 70, 18)
# real values are [0.78947368]
# Sampling chain 1/3
# Running chain, α = 0.17: 100%|██████████| 3000/3000 [06:27<00:00,  7.73it/s]
# Sampling chain 2/3
# Running chain, α = 0.19: 100%|██████████| 3000/3000 [06:30<00:00,  7.69it/s]
# Sampling chain 3/3
# Running chain, α = 0.32: 100%|██████████| 3000/3000 [06:31<00:00,  7.67it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [1.027]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  1.027  0.345   0.464     1.64      0.017    0.012     416.0     316.0
#
#     r_hat
# x0   1.01
# Autocorrelation...
# the difference between estimated values [0.23752632]
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_901768\3456175106.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# The function param_inverse took 1170.5323848724365 seconds.
# sigma: 0.5
# step random walk: 0.2
# (1, 70, 18)
# real values are [0.78947368]
# Sampling chain 1/3
# Running chain, α = 0.19:  50%|████▉     | 1490/3000 [03:13<03:08,  8.02it/s]c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:1002: RuntimeWarning: overflow encountered in exp
#   return x/(t+1)/(1.0+np.exp(re*(x)/(4*t+4))*((t+1)/A0)**0.5)
# Running chain, α = 0.12: 100%|██████████| 3000/3000 [06:30<00:00,  7.68it/s]
# Sampling chain 2/3
# Running chain, α = 0.68:   8%|▊         | 225/3000 [00:31<06:23,  7.23it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 22
#      17 n_chains=3
#      19 algo="MH"
# ---> 22 estimateMF, errorMF= run_simulation(basis,input_test, T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
#      23 # FUnziona, obiettivo ora, ridurre varianza della posterior
#
# Cell In[14], line 103, in run_simulation(basis, datahf, T, mean_prior, cov_prior, Yhf, sigma_noise, n_data, parameters, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, final_model, algo)
#     101             nearest_x, y_obs = process_data(datahf, parameters, t_eval, Yhf)
#     102             print(nearest_x.shape)
# --> 103             estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
#     105 smallest_index = np.unravel_index(np.argmin(error), error.shape)
#     106 print(f"The best estimate is given by: sigma_noise={sigma_noise[smallest_index[0]]}, number of data= {n_data[smallest_index[1]]}, sigma={sigma[smallest_index[2]]}, rmwh_scaling={rmwh_scaling[smallest_index[3]]}")
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:101, in compute_time.<locals>.wrapper(*args, **kwargs)
#      99 def wrapper(*args, **kwargs):
#     100     init = time.time()
# --> 101     res = function(*args, **kwargs)
#     102     end = time.time()
#     103     timespam = end - init
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:1124, in LSTM.param_inverse(self, basis, mean_prior, x_data, cov_prior, cov_noise, cov_likelihood, y_obs, x_real, number_chains, N, burn_in, levels, diagnostic, rwmh_cov, rmwh_scaling, rwmh_adaptive, algo, transformation)
#    1121 if(rwmh_cov is None):
#    1122     rwmh_cov = np.eye(len(x_real))
# -> 1124 estimates=MCMC(my_posterior,N,burn_in,number_chains,diagnostic=diagnostic,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive,algo=algo,dim=dim)
#    1126 if diagnostic is True:
#    1127     plot_hist(estimates,x_real, self.wrapper_prediction(estimates), self.wrapper_prediction(x_real))
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\module_utils.py:64, in MCMC(my_posterior, N, burnin, n, diagnostic, rwmh_cov, rmwh_scaling, period, t0, rwmh_adaptive, algo, dim)
#      61 else:
#      62     raise ValueError("Unknown algorithm %s"%algo)
# ---> 64 my_chains = tda.sample(my_posterior, my_proposal, iterations=N, n_chains=n, force_sequential=True, initial_parameters=MAP)
#      65 idata = tda.to_inference_data(my_chains, burnin=burnin)
#      66 estimates=np.array(az.summary(idata)['mean'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\sampler.py:198, in sample(posteriors, proposal, iterations, n_chains, initial_parameters, subsampling_rate, adaptive_error_model, store_coarse_chain, force_sequential, force_progress_bar)
#     195 if n_levels == 1:
#     196     # sequential sampling.
#     197     if not ray_is_available or n_chains == 1 or force_sequential:
# --> 198         samples = _sample_sequential(
#     199             posteriors, proposal, iterations, n_chains, initial_parameters
#     200         )
#     201     # parallel sampling.
#     202     else:
#     203         samples = _sample_parallel(
#     204             posteriors,
#     205             proposal,
#    (...)
#     209             force_progress_bar,
#     210         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\sampler.py:283, in _sample_sequential(posteriors, proposal, iterations, n_chains, initial_parameters)
#     281     print("Sampling chain {}/{}".format(i + 1, n_chains))
#     282     chains.append(Chain(posteriors[0], proposal[i], initial_parameters[i]))
# --> 283     chains[i].sample(iterations)
#     285 info = {"sampler": "MH", "n_chains": n_chains, "iterations": iterations + 1}
#     286 chains = {"chain_{}".format(i): chain.chain for i, chain in enumerate(chains)}
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\chain.py:105, in Chain.sample(self, iterations, progressbar)
#     102 proposal = self.proposal.make_proposal(self.chain[-1])
#     104 # create a link from that proposal.
# --> 105 proposal_link = self.posterior.create_link(proposal)
#     107 # compute the acceptance probability, which is unique to
#     108 # the proposal.
#     109 alpha = self.proposal.get_acceptance(proposal_link, self.chain[-1])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\posterior.py:80, in Posterior.create_link(self, parameters)
#      77 prior = self.prior.logpdf(parameters)
#      79 # get the model output and the qoi.
# ---> 80 model_output = self.model(parameters)
#      82 # extract model output and qoi.
#      83 if isinstance(model_output, tuple):
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:1027, in LSTM.wrapper_prediction(self, x_test, multi_input)
#    1025         for n in range(self.inputs.shape[1]):
#    1026             for i in range(x.shape[0]):
# -> 1027                 u_lf[0, n, i] = u_LF(x[i], self.inputs[0,n,0], denormalization(x_final[0],re_max,re_min))
#    1028 #                 u_hf[0, n, i] = u_HF(x[i], self.inputs[0,n,0], denormalization(x_final[0],re_max,re_min))
#    1030         u_lf_pod=np.reshape(u_lf,(70,nh))
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:1002, in LSTM.wrapper_prediction.<locals>.u_LF(x, t, re)
#    1000 def u_LF(x, t, re):
#    1001     A0 = np.exp(re/8.0)
# -> 1002     return x/(t+1)/(1.0+np.exp(re*(x)/(4*t+4))*((t+1)/A0)**0.5)
#
# KeyboardInterrupt:

# %%
# true parameters
sigma_noise=[0.05,0.1]
n_data=[110]
parameter=np.array([re_grid_lstm_test[2,0]])
#indices = np.where(input_test[:,:,1] == parameter)[0]
mean_prior=np.array([.5])
cov_prior=np.diag([.5])
# cov_linkelihood
sigma=np.array([0.1,0.3,0.5,1,2,4.])   # NB, con sigma piccolo (e.g. 1) funzia, sigma troppo gaìrande no

# adaptive metropolis
rwmh_cov = np.eye(1)
rmwh_scaling = np.array([0.5,0.2])    # 0.05 sembra problema sia esplorazione
rwmh_adaptive = True
iterations =3000
burnin = 2000
n_chains=2

algo="MH"


estimateMF, errorMF= run_simulation(basis,input_test, T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
# FUnziona, obiettivo ora, ridurre varianza della posterior
# Out:
# Noise: 0.05
# Number of data: 110
# sigma: 0.1
# step random walk: 0.5
# (1, 110, 18)
# real values are [0.78947368]
# Sampling chain 1/2
# Running chain, α = 0.29: 100%|██████████| 3000/3000 [09:49<00:00,  5.09it/s]
# Sampling chain 2/2
# Running chain, α = 0.25: 100%|██████████| 3000/3000 [09:40<00:00,  5.17it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [0.963]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  0.963  0.103   0.758    1.138      0.006    0.004     353.0     426.0
#
#     r_hat
# x0   1.01
# Autocorrelation...
# the difference between estimated values [0.17352632]
# The function param_inverse took 1171.2950723171234 seconds.
# step random walk: 0.2
# (1, 110, 18)
# real values are [0.78947368]
# Sampling chain 1/2
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_56072\3456175106.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Running chain, α = 0.37:   2%|▏         | 74/3000 [00:14<09:44,  5.00it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 22
#      17 n_chains=2
#      19 algo="MH"
# ---> 22 estimateMF, errorMF= run_simulation(basis,input_test, T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
#      23 # FUnziona, obiettivo ora, ridurre varianza della posterior
#
# Cell In[15], line 103, in run_simulation(basis, datahf, T, mean_prior, cov_prior, Yhf, sigma_noise, n_data, parameters, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, final_model, algo)
#     101             nearest_x, y_obs = process_data(datahf, parameters, t_eval, Yhf)
#     102             print(nearest_x.shape)
# --> 103             estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
#     105 smallest_index = np.unravel_index(np.argmin(error), error.shape)
#     106 print(f"The best estimate is given by: sigma_noise={sigma_noise[smallest_index[0]]}, number of data= {n_data[smallest_index[1]]}, sigma={sigma[smallest_index[2]]}, rmwh_scaling={rmwh_scaling[smallest_index[3]]}")
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:101, in compute_time.<locals>.wrapper(*args, **kwargs)
#      99 def wrapper(*args, **kwargs):
#     100     init = time.time()
# --> 101     res = function(*args, **kwargs)
#     102     end = time.time()
#     103     timespam = end - init
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:1124, in LSTM.param_inverse(self, basis, mean_prior, x_data, cov_prior, cov_noise, cov_likelihood, y_obs, x_real, number_chains, N, burn_in, levels, diagnostic, rwmh_cov, rmwh_scaling, rwmh_adaptive, algo, transformation)
#    1121 if(rwmh_cov is None):
#    1122     rwmh_cov = np.eye(len(x_real))
# -> 1124 estimates=MCMC(my_posterior,N,burn_in,number_chains,diagnostic=diagnostic,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive,algo=algo,dim=dim)
#    1126 if diagnostic is True:
#    1127     plot_hist(estimates,x_real, self.wrapper_prediction(estimates), self.wrapper_prediction(x_real))
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\module_utils.py:64, in MCMC(my_posterior, N, burnin, n, diagnostic, rwmh_cov, rmwh_scaling, period, t0, rwmh_adaptive, algo, dim)
#      61 else:
#      62     raise ValueError("Unknown algorithm %s"%algo)
# ---> 64 my_chains = tda.sample(my_posterior, my_proposal, iterations=N, n_chains=n, force_sequential=True, initial_parameters=MAP)
#      65 idata = tda.to_inference_data(my_chains, burnin=burnin)
#      66 estimates=np.array(az.summary(idata)['mean'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\sampler.py:198, in sample(posteriors, proposal, iterations, n_chains, initial_parameters, subsampling_rate, adaptive_error_model, store_coarse_chain, force_sequential, force_progress_bar)
#     195 if n_levels == 1:
#     196     # sequential sampling.
#     197     if not ray_is_available or n_chains == 1 or force_sequential:
# --> 198         samples = _sample_sequential(
#     199             posteriors, proposal, iterations, n_chains, initial_parameters
#     200         )
#     201     # parallel sampling.
#     202     else:
#     203         samples = _sample_parallel(
#     204             posteriors,
#     205             proposal,
#    (...)
#     209             force_progress_bar,
#     210         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\sampler.py:283, in _sample_sequential(posteriors, proposal, iterations, n_chains, initial_parameters)
#     281     print("Sampling chain {}/{}".format(i + 1, n_chains))
#     282     chains.append(Chain(posteriors[0], proposal[i], initial_parameters[i]))
# --> 283     chains[i].sample(iterations)
#     285 info = {"sampler": "MH", "n_chains": n_chains, "iterations": iterations + 1}
#     286 chains = {"chain_{}".format(i): chain.chain for i, chain in enumerate(chains)}
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\chain.py:105, in Chain.sample(self, iterations, progressbar)
#     102 proposal = self.proposal.make_proposal(self.chain[-1])
#     104 # create a link from that proposal.
# --> 105 proposal_link = self.posterior.create_link(proposal)
#     107 # compute the acceptance probability, which is unique to
#     108 # the proposal.
#     109 alpha = self.proposal.get_acceptance(proposal_link, self.chain[-1])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\posterior.py:80, in Posterior.create_link(self, parameters)
#      77 prior = self.prior.logpdf(parameters)
#      79 # get the model output and the qoi.
# ---> 80 model_output = self.model(parameters)
#      82 # extract model output and qoi.
#      83 if isinstance(model_output, tuple):
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:1027, in LSTM.wrapper_prediction(self, x_test, multi_input)
#    1025         for n in range(self.inputs.shape[1]):
#    1026             for i in range(x.shape[0]):
# -> 1027                 u_lf[0, n, i] = u_LF(x[i], self.inputs[0,n,0], denormalization(x_final[0],re_max,re_min))
#    1028 #                 u_hf[0, n, i] = u_HF(x[i], self.inputs[0,n,0], denormalization(x_final[0],re_max,re_min))
#    1030         u_lf_pod=np.reshape(u_lf,(110,nh))
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\module_utils.py:40, in denormalization(x, xmax, xmin)
#      35 def  normalization(x, xmax,xmin):
#      36     return (x - xmin) / (
#      37     xmax - xmin
#      38 )
# ---> 40 def  denormalization(x, xmax,xmin ):
#      41     return x*(xmax-xmin) +xmin
#      43 def MCMC(my_posterior,N, burnin, n=1, diagnostic=True,rwmh_cov=None,rmwh_scaling=0.1, period=100, t0=0, rwmh_adaptive=False,algo="MH",dim=0):
#      44     #print("check 1")
#
# KeyboardInterrupt:

# %%
# true parameters
sigma_noise=[0.05,0.1]
n_data=[110]
parameter=np.array([re_grid_lstm_test[0,0]])
#indices = np.where(input_test[:,:,1] == parameter)[0]
mean_prior=np.array([.5])
cov_prior=np.diag([.5])
# cov_linkelihood
sigma=np.array([0.1,0.3,0.5,1,2,4.])   # NB, con sigma piccolo (e.g. 1) funzia, sigma troppo gaìrande no

# adaptive metropolis
rwmh_cov = np.eye(1)
rmwh_scaling = np.array([0.5,0.2])    # 0.05 sembra problema sia esplorazione
rwmh_adaptive = True
iterations =3000
burnin = 2000
n_chains=2

algo="MH"


estimateMF, errorMF= run_simulation(basis,input_test, T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
# FUnziona, obiettivo ora, ridurre varianza della posterior
# Out:
# Noise: 0.05
# Number of data: 110
# sigma: 0.1
# step random walk: 0.5
# (1, 110, 18)
# real values are [0.36842105]
# Sampling chain 1/2
# Running chain, α = 0.50:   0%|          | 1/3000 [00:00<07:23,  6.76it/s]C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\proposal.py:238: RuntimeWarning: overflow encountered in exp
#   return np.exp(proposal_link.posterior - previous_link.posterior)
# Running chain, α = 0.28: 100%|██████████| 3000/3000 [10:49<00:00,  4.62it/s]
# Sampling chain 2/2
# Running chain, α = 0.20: 100%|██████████| 3000/3000 [11:12<00:00,  4.46it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [0.361]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  0.361  0.026   0.319    0.408      0.002    0.001     301.0     277.0
#
#     r_hat
# x0   1.01
# Autocorrelation...
# the difference between estimated values [0.00742105]
# The function param_inverse took 1323.2723925113678 seconds.
# step random walk: 0.2
# (1, 110, 18)
# real values are [0.36842105]
# Sampling chain 1/2
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_56072\3456175106.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Running chain, α = 0.33:   0%|          | 2/3000 [00:00<09:09,  5.45it/s]C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\proposal.py:238: RuntimeWarning: overflow encountered in exp
#   return np.exp(proposal_link.posterior - previous_link.posterior)
# Running chain, α = 0.32:   1%|          | 24/3000 [00:04<09:44,  5.09it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 22
#      17 n_chains=2
#      19 algo="MH"
# ---> 22 estimateMF, errorMF= run_simulation(basis,input_test, T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
#      23 # FUnziona, obiettivo ora, ridurre varianza della posterior
#
# Cell In[15], line 103, in run_simulation(basis, datahf, T, mean_prior, cov_prior, Yhf, sigma_noise, n_data, parameters, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, final_model, algo)
#     101             nearest_x, y_obs = process_data(datahf, parameters, t_eval, Yhf)
#     102             print(nearest_x.shape)
# --> 103             estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
#     105 smallest_index = np.unravel_index(np.argmin(error), error.shape)
#     106 print(f"The best estimate is given by: sigma_noise={sigma_noise[smallest_index[0]]}, number of data= {n_data[smallest_index[1]]}, sigma={sigma[smallest_index[2]]}, rmwh_scaling={rmwh_scaling[smallest_index[3]]}")
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:101, in compute_time.<locals>.wrapper(*args, **kwargs)
#      99 def wrapper(*args, **kwargs):
#     100     init = time.time()
# --> 101     res = function(*args, **kwargs)
#     102     end = time.time()
#     103     timespam = end - init
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:1124, in LSTM.param_inverse(self, basis, mean_prior, x_data, cov_prior, cov_noise, cov_likelihood, y_obs, x_real, number_chains, N, burn_in, levels, diagnostic, rwmh_cov, rmwh_scaling, rwmh_adaptive, algo, transformation)
#    1121 if(rwmh_cov is None):
#    1122     rwmh_cov = np.eye(len(x_real))
# -> 1124 estimates=MCMC(my_posterior,N,burn_in,number_chains,diagnostic=diagnostic,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive,algo=algo,dim=dim)
#    1126 if diagnostic is True:
#    1127     plot_hist(estimates,x_real, self.wrapper_prediction(estimates), self.wrapper_prediction(x_real))
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\module_utils.py:64, in MCMC(my_posterior, N, burnin, n, diagnostic, rwmh_cov, rmwh_scaling, period, t0, rwmh_adaptive, algo, dim)
#      61 else:
#      62     raise ValueError("Unknown algorithm %s"%algo)
# ---> 64 my_chains = tda.sample(my_posterior, my_proposal, iterations=N, n_chains=n, force_sequential=True, initial_parameters=MAP)
#      65 idata = tda.to_inference_data(my_chains, burnin=burnin)
#      66 estimates=np.array(az.summary(idata)['mean'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\sampler.py:198, in sample(posteriors, proposal, iterations, n_chains, initial_parameters, subsampling_rate, adaptive_error_model, store_coarse_chain, force_sequential, force_progress_bar)
#     195 if n_levels == 1:
#     196     # sequential sampling.
#     197     if not ray_is_available or n_chains == 1 or force_sequential:
# --> 198         samples = _sample_sequential(
#     199             posteriors, proposal, iterations, n_chains, initial_parameters
#     200         )
#     201     # parallel sampling.
#     202     else:
#     203         samples = _sample_parallel(
#     204             posteriors,
#     205             proposal,
#    (...)
#     209             force_progress_bar,
#     210         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\sampler.py:283, in _sample_sequential(posteriors, proposal, iterations, n_chains, initial_parameters)
#     281     print("Sampling chain {}/{}".format(i + 1, n_chains))
#     282     chains.append(Chain(posteriors[0], proposal[i], initial_parameters[i]))
# --> 283     chains[i].sample(iterations)
#     285 info = {"sampler": "MH", "n_chains": n_chains, "iterations": iterations + 1}
#     286 chains = {"chain_{}".format(i): chain.chain for i, chain in enumerate(chains)}
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\chain.py:105, in Chain.sample(self, iterations, progressbar)
#     102 proposal = self.proposal.make_proposal(self.chain[-1])
#     104 # create a link from that proposal.
# --> 105 proposal_link = self.posterior.create_link(proposal)
#     107 # compute the acceptance probability, which is unique to
#     108 # the proposal.
#     109 alpha = self.proposal.get_acceptance(proposal_link, self.chain[-1])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\posterior.py:80, in Posterior.create_link(self, parameters)
#      77 prior = self.prior.logpdf(parameters)
#      79 # get the model output and the qoi.
# ---> 80 model_output = self.model(parameters)
#      82 # extract model output and qoi.
#      83 if isinstance(model_output, tuple):
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:1040, in LSTM.wrapper_prediction(self, x_test, multi_input)
#    1032         ulf_train=np.reshape(ulf_train,(1,110,n_POD))
#    1033 #         u_hf=np.reshape(u_hf, (110,nh))
#    1034 #         basis, S = compute_randomized_SVD(u_hf, n_POD, nh, 1)
#    1035 #         new_inputs=np.reshape(u_lf,(110,nh))@ basis
#    (...)
#    1038 # ##########################
#    1039 #         new_inputs=np.concatenate((self.inputs[0,:, :1], x_final, new_inputs[0,:, :]), axis=1)
# -> 1040         t_grid_lstm, re_grid_lstm = np.meshgrid(self.inputs[0,:,:1], x_final[0])
#    1041         new_inputs = np.concatenate((t_grid_lstm[:,:,np.newaxis], re_grid_lstm[:,:,np.newaxis], ulf_train), axis = 2)
#    1043 #        new_inputs=new_inputs.reshape(1,new_inputs.shape[0],new_inputs.shape[1])
#    1044
#    1045 # # ATTENZIONE  sarebbe da rivedere. Qui stai adattando a dimensioni e ordine del caso Bruger, sarebbe da generalizzare mettendo parametri sempre in fondo o quanto meno specificare
#    1046 #         # new_inputs = np.concatenate((self.inputs[:, :1], x_final, self.inputs[:, 1:]), axis=1)
#    1047 #         # new_inputs=new_inputs.reshape(1,new_inputs.shape[0],new_inputs.shape[1])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:5164, in meshgrid(copy, sparse, indexing, *xi)
#    5161     output = np.broadcast_arrays(*output, subok=True)
#    5163 if copy:
# -> 5164     output = [x.copy() for x in output]
#    5166 return output
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:5164, in <listcomp>(.0)
#    5161     output = np.broadcast_arrays(*output, subok=True)
#    5163 if copy:
# -> 5164     output = [x.copy() for x in output]
#    5166 return output
#
# KeyboardInterrupt:

# %%
# true parameters
sigma_noise=[0.05,0.1]
n_data=[110]
parameter=np.array([re_grid_lstm_test[0,0]])
#indices = np.where(input_test[:,:,1] == parameter)[0]
mean_prior=np.array([.5])
cov_prior=np.diag([.5])
# cov_linkelihood
sigma=np.array([0.3,0.5,1,2,4.])   # NB, con sigma piccolo (e.g. 1) funzia, sigma troppo gaìrande no

# adaptive metropolis
rwmh_cov = np.eye(1)
rmwh_scaling = np.array([0.5,0.2])    # 0.05 sembra problema sia esplorazione
rwmh_adaptive = True
iterations =3000
burnin = 2000
n_chains=2

algo="MH"


estimateMF, errorMF= run_simulation(basis,input_test, T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
# FUnziona, obiettivo ora, ridurre varianza della posterior
# Out:
# Noise: 0.05
# Number of data: 110
# sigma: 0.3
# step random walk: 0.5
# (1, 110, 18)
# real values are [0.36842105]
# Sampling chain 1/2
# Running chain, α = 1.00:   0%|          | 0/3000 [00:00<?, ?it/s]C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\proposal.py:238: RuntimeWarning: overflow encountered in exp
#   return np.exp(proposal_link.posterior - previous_link.posterior)
# Running chain, α = 0.26: 100%|██████████| 3000/3000 [08:54<00:00,  5.62it/s]
# Sampling chain 2/2
# Running chain, α = 0.19: 100%|██████████| 3000/3000 [14:19<00:00,  3.49it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [0.413]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  0.413  0.104   0.265    0.605      0.006    0.004     320.0     360.0
#
#     r_hat
# x0   1.01
# Autocorrelation...
# the difference between estimated values [0.04457895]
# The function param_inverse took 1394.3833403587341 seconds.
# step random walk: 0.2
# (1, 110, 18)
# real values are [0.36842105]
# Sampling chain 1/2
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_56072\3456175106.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# Running chain, α = 0.17: 100%|██████████| 3000/3000 [09:20<00:00,  5.35it/s]
# Sampling chain 2/2
# Running chain, α = 0.29: 100%|██████████| 3000/3000 [12:57<00:00,  3.86it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [0.436]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  0.436  0.096   0.281    0.611      0.007    0.005     180.0     252.0
#
#     r_hat
# x0   1.01
# Autocorrelation...
# the difference between estimated values [0.06757895]
# C:\Users\Giacomo\AppData\Local\Temp\ipykernel_56072\3456175106.py:103: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
# The function param_inverse took 1339.11505651474 seconds.
# sigma: 0.5
# step random walk: 0.5
# (1, 110, 18)
# real values are [0.36842105]
# Sampling chain 1/2
# Running chain, α = 0.41:   2%|▏         | 67/3000 [00:13<09:30,  5.14it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 22
#      17 n_chains=2
#      19 algo="MH"
# ---> 22 estimateMF, errorMF= run_simulation(basis,input_test, T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
#      23 # FUnziona, obiettivo ora, ridurre varianza della posterior
#
# Cell In[15], line 103, in run_simulation(basis, datahf, T, mean_prior, cov_prior, Yhf, sigma_noise, n_data, parameters, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, final_model, algo)
#     101             nearest_x, y_obs = process_data(datahf, parameters, t_eval, Yhf)
#     102             print(nearest_x.shape)
# --> 103             estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
#     105 smallest_index = np.unravel_index(np.argmin(error), error.shape)
#     106 print(f"The best estimate is given by: sigma_noise={sigma_noise[smallest_index[0]]}, number of data= {n_data[smallest_index[1]]}, sigma={sigma[smallest_index[2]]}, rmwh_scaling={rmwh_scaling[smallest_index[3]]}")
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:101, in compute_time.<locals>.wrapper(*args, **kwargs)
#      99 def wrapper(*args, **kwargs):
#     100     init = time.time()
# --> 101     res = function(*args, **kwargs)
#     102     end = time.time()
#     103     timespam = end - init
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:1124, in LSTM.param_inverse(self, basis, mean_prior, x_data, cov_prior, cov_noise, cov_likelihood, y_obs, x_real, number_chains, N, burn_in, levels, diagnostic, rwmh_cov, rmwh_scaling, rwmh_adaptive, algo, transformation)
#    1121 if(rwmh_cov is None):
#    1122     rwmh_cov = np.eye(len(x_real))
# -> 1124 estimates=MCMC(my_posterior,N,burn_in,number_chains,diagnostic=diagnostic,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive,algo=algo,dim=dim)
#    1126 if diagnostic is True:
#    1127     plot_hist(estimates,x_real, self.wrapper_prediction(estimates), self.wrapper_prediction(x_real))
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\module_utils.py:64, in MCMC(my_posterior, N, burnin, n, diagnostic, rwmh_cov, rmwh_scaling, period, t0, rwmh_adaptive, algo, dim)
#      61 else:
#      62     raise ValueError("Unknown algorithm %s"%algo)
# ---> 64 my_chains = tda.sample(my_posterior, my_proposal, iterations=N, n_chains=n, force_sequential=True, initial_parameters=MAP)
#      65 idata = tda.to_inference_data(my_chains, burnin=burnin)
#      66 estimates=np.array(az.summary(idata)['mean'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\sampler.py:198, in sample(posteriors, proposal, iterations, n_chains, initial_parameters, subsampling_rate, adaptive_error_model, store_coarse_chain, force_sequential, force_progress_bar)
#     195 if n_levels == 1:
#     196     # sequential sampling.
#     197     if not ray_is_available or n_chains == 1 or force_sequential:
# --> 198         samples = _sample_sequential(
#     199             posteriors, proposal, iterations, n_chains, initial_parameters
#     200         )
#     201     # parallel sampling.
#     202     else:
#     203         samples = _sample_parallel(
#     204             posteriors,
#     205             proposal,
#    (...)
#     209             force_progress_bar,
#     210         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\sampler.py:283, in _sample_sequential(posteriors, proposal, iterations, n_chains, initial_parameters)
#     281     print("Sampling chain {}/{}".format(i + 1, n_chains))
#     282     chains.append(Chain(posteriors[0], proposal[i], initial_parameters[i]))
# --> 283     chains[i].sample(iterations)
#     285 info = {"sampler": "MH", "n_chains": n_chains, "iterations": iterations + 1}
#     286 chains = {"chain_{}".format(i): chain.chain for i, chain in enumerate(chains)}
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\chain.py:105, in Chain.sample(self, iterations, progressbar)
#     102 proposal = self.proposal.make_proposal(self.chain[-1])
#     104 # create a link from that proposal.
# --> 105 proposal_link = self.posterior.create_link(proposal)
#     107 # compute the acceptance probability, which is unique to
#     108 # the proposal.
#     109 alpha = self.proposal.get_acceptance(proposal_link, self.chain[-1])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\posterior.py:80, in Posterior.create_link(self, parameters)
#      77 prior = self.prior.logpdf(parameters)
#      79 # get the model output and the qoi.
# ---> 80 model_output = self.model(parameters)
#      82 # extract model output and qoi.
#      83 if isinstance(model_output, tuple):
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:1048, in LSTM.wrapper_prediction(self, x_test, multi_input)
#    1041         new_inputs = np.concatenate((t_grid_lstm[:,:,np.newaxis], re_grid_lstm[:,:,np.newaxis], ulf_train), axis = 2)
#    1043 #        new_inputs=new_inputs.reshape(1,new_inputs.shape[0],new_inputs.shape[1])
#    1044
#    1045 # # ATTENZIONE  sarebbe da rivedere. Qui stai adattando a dimensioni e ordine del caso Bruger, sarebbe da generalizzare mettendo parametri sempre in fondo o quanto meno specificare
#    1046 #         # new_inputs = np.concatenate((self.inputs[:, :1], x_final, self.inputs[:, 1:]), axis=1)
#    1047 #         # new_inputs=new_inputs.reshape(1,new_inputs.shape[0],new_inputs.shape[1])
# -> 1048         rep=self.prediction(new_inputs).flatten()
#    1050         return rep
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:951, in LSTM.prediction(self, x_test)
#     948 else:
#     949     with Suppressor():
# --> 951         y_pred = self.model.predict(x_test)#[:,0]       # <--------------- commentato il 6/03
#     952 return y_pred
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\engine\training.py:2651, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2649     self._steps_per_execution_tuner.start()
#    2650 batch_outputs = None
# -> 2651 for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    2652     with data_handler.catch_stop_iteration():
#    2653         for step in data_handler.steps():
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\engine\data_adapter.py:1341, in DataHandler.enumerate_epochs(self)
#    1339 """Yields `(epoch, tf.data.Iterator)`."""
#    1340 with self._truncate_execution_to_epoch():
# -> 1341     data_iterator = iter(self._dataset)
#    1342     for epoch in range(self._initial_epoch, self._epochs):
#    1343         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\data\ops\dataset_ops.py:500, in DatasetV2.__iter__(self)
#     498 if context.executing_eagerly() or ops.inside_function():
#     499   with ops.colocate_with(self._variant_tensor):
# --> 500     return iterator_ops.OwnedIterator(self)
#     501 else:
#     502   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     503                      "iteration in eager mode or within tf.function.")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\data\ops\iterator_ops.py:706, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     702   if (components is not None or element_spec is not None):
#     703     raise ValueError(
#     704         "When `dataset` is provided, `element_spec` and `components` must "
#     705         "not be specified.")
# --> 706   self._create_iterator(dataset)
#     708 self._get_next_call_count = 0
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\data\ops\iterator_ops.py:745, in OwnedIterator._create_iterator(self, dataset)
#     742   assert len(fulltype.args[0].args[0].args) == len(
#     743       self._flat_output_types)
#     744   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 745 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3421, in make_iterator(dataset, iterator, name)
#    3419 if tld.is_eager:
#    3420   try:
# -> 3421     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3422       _ctx, "MakeIterator", name, dataset, iterator)
#    3423     return _result
#    3424   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
basis.shape
# Out:
# (101, 16)

# %%
# true parameters
sigma_noise=[0.05,0.1]
n_data=[110]
parameter=np.array([re_grid_lstm_test[0,0]])
#indices = np.where(input_test[:,:,1] == parameter)[0]
mean_prior=np.array([.5])
cov_prior=np.diag([1])
# cov_linkelihood
sigma=np.array([1,2,4.])   # NB, con sigma piccolo (e.g. 1) funzia, sigma troppo gaìrande no

# adaptive metropolis
rwmh_cov = np.eye(1)
rmwh_scaling = np.array([0.1,0.2,0.05])
rwmh_adaptive = True
iterations =3000
burnin = 1500
n_chains=3

algo="MH"


estimateMF, errorMF= run_simulation(basis,input_test, T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
# FUnziona, obiettivo ora, ridurre varianza della posterior
# Out:
# Noise: 0.05
# Number of data: 110
# sigma: 1.0
# step random walk: 0.1
# (1, 110, 18)
# real values are [0.36842105]
# Sampling chain 1/3
# Running chain, α = 0.46:  17%|█▋        | 512/3000 [01:30<07:19,  5.66it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 22
#      17 n_chains=3
#      19 algo="MH"
# ---> 22 estimateMF, errorMF= run_simulation(basis,input_test, T,mean_prior, cov_prior, output_test, sigma_noise, n_data, parameter, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, model,algo)
#      23 # FUnziona, obiettivo ora, ridurre varianza della posterior
#
# Cell In[14], line 103, in run_simulation(basis, datahf, T, mean_prior, cov_prior, Yhf, sigma_noise, n_data, parameters, sigma, rmwh_scaling, rwmh_cov, rwmh_adaptive, iterations, burnin, n_chains, final_model, algo)
#     101             nearest_x, y_obs = process_data(datahf, parameters, t_eval, Yhf)
#     102             print(nearest_x.shape)
# --> 103             estimate_MF[i,k,t,j],error[i,k,t,j] = final_model.param_inverse(basis,mean_prior, nearest_x, cov_prior=cov_prior, rmwh_scaling=r, cov_noise=noise, cov_likelihood=s**2 * np.eye(t_eval.shape[0]), y_obs=y_obs, x_real=parameters, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True, rwmh_cov=rwmh_cov, rwmh_adaptive=rwmh_adaptive, algo=algo)
#     105 smallest_index = np.unravel_index(np.argmin(error), error.shape)
#     106 print(f"The best estimate is given by: sigma_noise={sigma_noise[smallest_index[0]]}, number of data= {n_data[smallest_index[1]]}, sigma={sigma[smallest_index[2]]}, rmwh_scaling={rmwh_scaling[smallest_index[3]]}")
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:101, in compute_time.<locals>.wrapper(*args, **kwargs)
#      99 def wrapper(*args, **kwargs):
#     100     init = time.time()
# --> 101     res = function(*args, **kwargs)
#     102     end = time.time()
#     103     timespam = end - init
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:1122, in LSTM.param_inverse(self, basis, mean_prior, x_data, cov_prior, cov_noise, cov_likelihood, y_obs, x_real, number_chains, N, burn_in, levels, diagnostic, rwmh_cov, rmwh_scaling, rwmh_adaptive, algo, transformation)
#    1119 if(rwmh_cov is None):
#    1120     rwmh_cov = np.eye(len(x_real))
# -> 1122 estimates=MCMC(my_posterior,N,burn_in,number_chains,diagnostic=diagnostic,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive,algo=algo,dim=dim)
#    1124 if diagnostic is True:
#    1125     plot_hist(estimates,x_real, self.wrapper_prediction(estimates), self.wrapper_prediction(x_real))
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\module_utils.py:64, in MCMC(my_posterior, N, burnin, n, diagnostic, rwmh_cov, rmwh_scaling, period, t0, rwmh_adaptive, algo, dim)
#      61 else:
#      62     raise ValueError("Unknown algorithm %s"%algo)
# ---> 64 my_chains = tda.sample(my_posterior, my_proposal, iterations=N, n_chains=n, force_sequential=True, initial_parameters=MAP)
#      65 idata = tda.to_inference_data(my_chains, burnin=burnin)
#      66 estimates=np.array(az.summary(idata)['mean'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\sampler.py:198, in sample(posteriors, proposal, iterations, n_chains, initial_parameters, subsampling_rate, adaptive_error_model, store_coarse_chain, force_sequential, force_progress_bar)
#     195 if n_levels == 1:
#     196     # sequential sampling.
#     197     if not ray_is_available or n_chains == 1 or force_sequential:
# --> 198         samples = _sample_sequential(
#     199             posteriors, proposal, iterations, n_chains, initial_parameters
#     200         )
#     201     # parallel sampling.
#     202     else:
#     203         samples = _sample_parallel(
#     204             posteriors,
#     205             proposal,
#    (...)
#     209             force_progress_bar,
#     210         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\sampler.py:283, in _sample_sequential(posteriors, proposal, iterations, n_chains, initial_parameters)
#     281     print("Sampling chain {}/{}".format(i + 1, n_chains))
#     282     chains.append(Chain(posteriors[0], proposal[i], initial_parameters[i]))
# --> 283     chains[i].sample(iterations)
#     285 info = {"sampler": "MH", "n_chains": n_chains, "iterations": iterations + 1}
#     286 chains = {"chain_{}".format(i): chain.chain for i, chain in enumerate(chains)}
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\chain.py:105, in Chain.sample(self, iterations, progressbar)
#     102 proposal = self.proposal.make_proposal(self.chain[-1])
#     104 # create a link from that proposal.
# --> 105 proposal_link = self.posterior.create_link(proposal)
#     107 # compute the acceptance probability, which is unique to
#     108 # the proposal.
#     109 alpha = self.proposal.get_acceptance(proposal_link, self.chain[-1])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\posterior.py:80, in Posterior.create_link(self, parameters)
#      77 prior = self.prior.logpdf(parameters)
#      79 # get the model output and the qoi.
# ---> 80 model_output = self.model(parameters)
#      82 # extract model output and qoi.
#      83 if isinstance(model_output, tuple):
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\../utils\Structure.py:1025, in LSTM.wrapper_prediction(self, x_test, multi_input)
#    1023         for n in range(self.inputs.shape[1]):
#    1024             for i in range(x.shape[0]):
# -> 1025                 u_lf[0, n, i] = u_LF(x[i], self.inputs[0,n,0], denormalization(x_final[0],re_max,re_min))
#    1026 #                 u_hf[0, n, i] = u_HF(x[i], self.inputs[0,n,0], denormalization(x_final[0],re_max,re_min))
#    1028         u_lf_pod=np.reshape(u_lf,(110,nh))
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\Burgers\module_utils.py:40, in denormalization(x, xmax, xmin)
#      35 def  normalization(x, xmax,xmin):
#      36     return (x - xmin) / (
#      37     xmax - xmin
#      38 )
# ---> 40 def  denormalization(x, xmax,xmin ):
#      41     return x*(xmax-xmin) +xmin
#      43 def MCMC(my_posterior,N, burnin, n=1, diagnostic=True,rwmh_cov=None,rmwh_scaling=0.1, period=100, t0=0, rwmh_adaptive=False,algo="MH",dim=0):
#      44     #print("check 1")
#
# KeyboardInterrupt:

# %%
    @compute_time
    def param_inverse(self, mean_prior, x_data, cov_prior=None, cov_noise=0.1, cov_likelihood=None, y_obs=None, x_real=None, number_chains=1, N=1000, burn_in=500, levels=1,diagnostic=True,rwmh_cov=None,rmwh_scaling=0.1,rwmh_adaptive=True, algo="MH",transformation=[]):
            # I should insert the 
        self.transformations=transformation
        self.inputs=x_data

        # rivedere la questione dimensioni (x_real!=y_obs)
        if x_real is not None:
            dim = x_real.shape[0]
        elif y_obs is not None:
            dim=y_obs.shape[0]
        else: 
            warning_message = "No observation nor data given"
            warnings.warn(warning_message, UserWarning)    

        if (N<=burn_in):
            warning_message = "number of steps insufficient, smaller or equal than burn-in"
            warnings.warn(warning_message, UserWarning) 

        if(cov_prior is None):
            cov_prior=mean_prior*0.2

        if(cov_likelihood is None):
            cov_likelihood=cov_noise**2*np.eye(x_real.shape[0])
# Out:
# 0.7894736842105263
