# %% [markdown]
# # Example

# %% [markdown]
# In this notebook a simple case is presented in order to show the general scheme which has been followed.
# A 2 step Neural Network is considered for the forward model

# %%
import tensorflow.keras.backend as K
from tensorflow.keras.regularizers import l2
from hyperopt import STATUS_OK, tpe, Trials, hp, fmin
from hyperopt.pyll.stochastic import sample
from hyperopt.pyll.base import scope
from sklearn.model_selection import KFold
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.optimizers import Adam,Nadam,Adamax
from time import perf_counter
import tensorflow as tf

import tinyDA as tda
from scipy.stats import multivariate_normal, uniform
import arviz as az
import keras

from module_utils import * 
sys.path.append('../utils')
from Structure import *

from pathlib import Path

# path to the current notebook
current_file_path = Path().resolve()
# path to the current folder
load_context_functions(current_file_path.parent.name)
# Out:
# True

# %%
# For reproducibility purposes , we set the seed to a fixed number
seed = 10
tf.random.set_seed(seed)
np.random.seed(seed)
keras.utils.set_random_seed(seed)

# %%
# The high fidelity (true) function and the low fidelity (noisy version) function are introduced 
highfid = lambda x: np.sin(x)+0.5*np.sin(2*x)+0.3*np.sin(3*x)
lowfid=lambda x:highfid(x)+0.2*np.sin(20*x)+0.1*np.sin(10*x)+0.1*np.sin(30*x)-0.4*np.sin(3*x)


Nhf = 7 # number of points to train the High Fidelity model
Nlf = 30 # number of points to train the Low Fidelity model
N = Nhf + Nlf

# training and test data
xhf = np.linspace(0,5,Nhf)
xlf = np.linspace(0,5,Nlf)
x_test = np.linspace(0,5,1000)
Yhf = highfid(xhf)
Ylf = lowfid(xlf)

# number of epochs
NepoLF = 2000
NepoHF = 750

# %%
plt.figure()
plt.plot(x_test,highfid(x_test),'r', label = 'high-fidelity sol')
plt.plot(x_test,lowfid(x_test),'g', label = 'low-fidelity sol')
plt.plot(xhf,highfid(xhf),'ro', label = 'high-fidelity data', markersize = 4)
plt.plot(xlf,lowfid(xlf),'go', label = 'low-fidelity data', markersize = 4)
plt.xlabel('x')
plt.legend()
plt.title('Benchmark 1D')
plt.show()

# %% [markdown]
# The low fidelity model can be seen as a noised version of the high fidelity model. In general, the data from a low fidelity model are easier or less expensive to be obtained

# %% [markdown]
# # Low-fidelity model

# %%
bestLF_params = {'lr' : 0.0255, 'kernel_init' : 'glorot_uniform', 'opt' : 'Adam'} 
modelLF=NetworkFactory.build_network('LF',params=bestLF_params,data_train=xlf,output_train=Ylf,N=NepoLF,n=Nlf,train=True,do_HPO=False,verbose=False) # Neural_network is the class that contains all the informations and the functions related to a Neural Network
yLF=modelLF.prediction(x_test) # associates to x_test the correspondent prediction of y using LF model
(mse_LF,R_LF)=modelLF.performance(x_test,highfid(x_test)) # quality test of the model
# Out:
# The function training took 12.030045747756958 seconds.
# Test MSE: 0.09651147116930565
# R^2: 0.7829948010554499

# %% [markdown]
# # High-fidelity model

# %%
bestHF_params = {'lr' : 0.0255, 'kernel_init' : 'glorot_uniform', 'opt' : 'Adam'}
modelHF=NetworkFactory.build_network('LF',params=bestHF_params,data_train=xhf,output_train=Yhf,N=NepoHF,n=Nhf,train=True,do_HPO=False,verbose=False)
yHF=modelHF.prediction(x_test)
(mse_HF,R_HF)=modelHF.performance(x_test,highfid(x_test))
# Out:
# The function training took 7.229218482971191 seconds.
# Test MSE: 0.08387025587656029
# R^2: 0.8114184630954866

# %% [markdown]
# # 2 steps model

# %%
bestLF_params = {'lr' : 0.0255, 'kernel_init' : 'glorot_uniform', 'opt' : 'Adam'}
best_params = {'kernel_init': 'uniform', 'l2weight': 0.00010018625799978436, 'lr': 0.07093837044166487, 'nodes': 74.0, 'opt': 'Adamax'}
N=[NepoLF,NepoHF]
n=[Nlf,Nhf]
names=['LF','HF']

params=[bestLF_params,best_params]
final_model=NetworkFactory.build_network("2step",names,params=params,data_train=[xlf,xhf],output_train=[Ylf,Yhf],N=N,n=n,do_HPO=False,verbose=False) # Multifidelity connects different neural network classes, to build a multifidelity model
y_test=final_model.prediction(x_test)

input_HF = np.concatenate(
                    (x_test.reshape(-1,1),  final_model.model_list[0].prediction(x_test).reshape(-1,1)),axis=1
                ) 
(mse_MF,R_MF)=final_model.model_list[1].performance(input_HF,highfid(x_test))
# Out:
# The function training took 5.436534404754639 seconds.
# The function training took 1.900782585144043 seconds.
# Test MSE: 0.014535307435652334
# R^2: 0.967317488340214

# %%
#LF
plt.figure()
plt.plot(xlf,Ylf,'go', label = 'LF training data', markersize = 4)
plt.plot(x_test,lowfid(x_test),'g', label = 'exact LF') 
plt.plot(x_test,yLF,'k--', label = 'pred LF')
plt.legend()
plt.title('Low fidelity model')

#HF single-fidelity
plt.figure()
plt.plot(xhf,Yhf,'ro', label = 'HF training data')
plt.plot(x_test,highfid(x_test),'-r', label = 'exact HF')
plt.plot(x_test,yHF,'--k', label = 'pred HF')
plt.legend()
plt.title('High fidelity model - single-fidelity')

#2-step MF
plt.figure()
plt.plot(xhf,Yhf,'ro', label = 'HF training data')
plt.plot(x_test,highfid(x_test),'-r', label = 'exact HF')
plt.plot(x_test,y_test,'--k', label = 'pred HF')
plt.legend()
plt.title('High fidelity model - 2-step')
# Out:
# Text(0.5, 1.0, 'High fidelity model - 2-step')

# %% [markdown]
# It is possible to notice that the 2 steps neural network has a better approximation of the original function w.r.t. the high fidelity model alone

# %% [markdown]
# ## Markov Chain Monte Carlo

# %% [markdown]
# The Markov Chain Monte Carlo method, using Metropolis Hastings algorithm, is introduced in order to associate the most probable input to the given output

# %%
dim=4
#real_x = np.random.rand(dim)*5
real_x=np.array([1.,2.,3.,4.])
mean_prior = np.ones(dim)*2.5
cov_prior = np.ones(dim)*5*0.1  # like Manzoni paper -> 1% of the width of the ranges 
sigma=0.45
rwmh_cov = np.eye(len(real_x)) # !
rmwh_scaling = 0.1
rwmh_adaptive = False
iterations =5000
burnin = 3000
n_chains=6

# %%
estimate_MF=final_model.inverse(mean_prior, cov_prior=cov_prior, cov_noise=sigma, cov_likelihood=sigma*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive)
estimate_LF=modelLF.inverse(mean_prior, cov_prior=cov_prior, cov_noise=sigma, cov_likelihood=sigma*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive)
estimate_HF=modelHF.inverse(mean_prior, cov_prior=cov_prior, cov_noise=sigma, cov_likelihood=sigma*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive)
# Out:
# real values are [1. 2. 3. 4.]
# Sampling chain 1/6
# Running chain, α = 0.87: 100%|██████████| 5000/5000 [07:48<00:00, 10.67it/s]
# Sampling chain 2/6
# Running chain, α = 0.92: 100%|██████████| 5000/5000 [08:17<00:00, 10.06it/s]
# Sampling chain 3/6
# Running chain, α = 0.79: 100%|██████████| 5000/5000 [08:14<00:00, 10.11it/s]
# Sampling chain 4/6
# Running chain, α = 0.87: 100%|██████████| 5000/5000 [08:15<00:00, 10.09it/s]
# Sampling chain 5/6
# Running chain, α = 0.88: 100%|██████████| 5000/5000 [08:16<00:00, 10.07it/s]
# Sampling chain 6/6
# Running chain, α = 0.90: 100%|██████████| 5000/5000 [08:39<00:00,  9.63it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [1.707 2.257 2.884 2.801]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  1.707  0.522   0.723    2.665      0.058    0.041      83.0     266.0
# x1  2.257  0.640   1.078    3.462      0.113    0.081      31.0      59.0
# x2  2.884  0.592   1.843    4.027      0.110    0.081      31.0      80.0
# x3  2.801  0.585   1.681    3.960      0.066    0.047      80.0     111.0
#
#     r_hat
# x0   1.05
# x1   1.15
# x2   1.13
# x3   1.10
# Autocorrelation...
# the estimated values are [0.707 0.257 0.116 1.199]
#  the difference between outputs of two models are [0.45030653 0.18340129 0.06895646 0.57098491]
# The function inverse took 3003.223361492157 seconds.
# real values are [1. 2. 3. 4.]
# Sampling chain 1/6
# Running chain, α = 0.87: 100%|██████████| 5000/5000 [04:14<00:00, 19.64it/s]
# Sampling chain 2/6
# Running chain, α = 0.84: 100%|██████████| 5000/5000 [03:52<00:00, 21.54it/s]
# Sampling chain 3/6
# Running chain, α = 0.63: 100%|██████████| 5000/5000 [03:49<00:00, 21.81it/s]
# Sampling chain 4/6
# Running chain, α = 0.86: 100%|██████████| 5000/5000 [03:48<00:00, 21.89it/s]
# Sampling chain 5/6
# Running chain, α = 0.88: 100%|██████████| 5000/5000 [03:49<00:00, 21.81it/s]
# Sampling chain 6/6
# Running chain, α = 0.84: 100%|██████████| 5000/5000 [03:50<00:00, 21.72it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [2.435 2.253 2.618 2.821]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  2.435  0.721   1.213    3.833      0.098    0.070      56.0     117.0
# x1  2.253  0.691   1.202    3.771      0.089    0.063      63.0     197.0
# x2  2.618  0.642   1.534    3.871      0.131    0.095      24.0     134.0
# x3  2.821  0.507   2.018    3.900      0.069    0.052      75.0      86.0
#
#     r_hat
# x0   1.11
# x1   1.05
# x2   1.18
# x3   1.08
# Autocorrelation...
# the estimated values are [1.435 0.253 0.382 1.179]
#  the difference between outputs of two models are [1.5493315  0.28215283 0.3309453  0.14752185]
# The function inverse took 1408.636519908905 seconds.
# real values are [1. 2. 3. 4.]
# Sampling chain 1/6
# Running chain, α = 0.89: 100%|██████████| 5000/5000 [04:09<00:00, 20.04it/s]
# Sampling chain 2/6
# Running chain, α = 0.88: 100%|██████████| 5000/5000 [04:17<00:00, 19.43it/s]
# Sampling chain 3/6
# Running chain, α = 0.84: 100%|██████████| 5000/5000 [04:18<00:00, 19.32it/s]
# Sampling chain 4/6
# Running chain, α = 0.83: 100%|██████████| 5000/5000 [04:44<00:00, 17.55it/s]
# Sampling chain 5/6
# Running chain, α = 0.85: 100%|██████████| 5000/5000 [04:23<00:00, 18.99it/s]
# Sampling chain 6/6
# Running chain, α = 0.88: 100%|██████████| 5000/5000 [04:41<00:00, 17.74it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [2.105 2.712 2.888 2.886]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  2.105  0.575   1.071    3.259      0.113    0.081      26.0      30.0
# x1  2.712  0.633   1.499    3.870      0.104    0.074      39.0     218.0
# x2  2.888  0.633   1.666    4.031      0.071    0.050      80.0     174.0
# x3  2.886  0.647   1.684    4.162      0.108    0.079      36.0     143.0
#
#     r_hat
# x0   1.16
# x1   1.13
# x2   1.05
# x3   1.13
# Autocorrelation...
# the estimated values are [1.105 0.712 0.112 1.114]
#  the difference between outputs of two models are [0.3843432  0.29608178 0.08852769 0.50902694]
# The function inverse took 1600.544960975647 seconds.

# %%
estimate_MF2=final_model.inverse(mean_prior, cov_prior=cov_prior, cov_noise=0.1, cov_likelihood=sigma*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive,algo="AM")
estimate_LF2=modelLF.inverse(mean_prior, cov_prior=cov_prior, cov_noise=0.1, cov_likelihood=sigma*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive,algo="AM")
estimate_HF2=modelHF.inverse(mean_prior, cov_prior=cov_prior, cov_noise=0.1, cov_likelihood=sigma*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive,algo="AM")
# Out:
# real values are [1. 2. 3. 4.]
# Sampling chain 1/6
# Running chain, α = 0.35: 100%|██████████| 5000/5000 [07:57<00:00, 10.46it/s]
# Sampling chain 2/6
# Running chain, α = 0.44: 100%|██████████| 5000/5000 [07:51<00:00, 10.60it/s]
# Sampling chain 3/6
# Running chain, α = 0.34: 100%|██████████| 5000/5000 [07:35<00:00, 10.97it/s]
# Sampling chain 4/6
# Running chain, α = 0.35: 100%|██████████| 5000/5000 [07:35<00:00, 10.98it/s]
# Sampling chain 5/6
# Running chain, α = 0.42: 100%|██████████| 5000/5000 [07:37<00:00, 10.93it/s]
# Sampling chain 6/6
# Running chain, α = 0.36: 100%|██████████| 5000/5000 [07:33<00:00, 11.03it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [1.993 2.411 2.651 2.802]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  1.993  0.629   0.813    3.150      0.024    0.017     698.0    1386.0
# x1  2.411  0.633   1.197    3.529      0.024    0.017     724.0    1012.0
# x2  2.651  0.616   1.501    3.745      0.023    0.016     698.0    1297.0
# x3  2.802  0.631   1.627    3.959      0.025    0.018     694.0     961.0
#
#     r_hat
# x0   1.01
# x1   1.01
# x2   1.01
# x3   1.01
# Autocorrelation...
# the estimated values are [0.993 0.411 0.349 1.198]
#  the difference between outputs of two models are [0.65632027 0.27878898 0.19717302 0.57042558]
# The function inverse took 2797.293425798416 seconds.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 estimate_MF2=final_model.inverse(mean_prior, cov_prior=cov_prior, cov_noise=0.1, cov_likelihood=sigma*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive,algo="AM")
# ----> 2 estimate_LF2=modelLF.inverse(mean_prior, cov_prior=cov_prior, cov_noise=0.1, cov_likelihood=sigma*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive,algo="AM")
#       3 estimate_HF2=modelHF.inverse(mean_prior, cov_prior=cov_prior, cov_noise=0.1, cov_likelihood=sigma*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive,algo="AM")
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\test_case\../utils\Structure.py:57, in compute_time.<locals>.wrapper(*args, **kwargs)
#      55 def wrapper(*args, **kwargs):
#      56     init = time.time()
# ---> 57     res = function(*args, **kwargs)
#      58     end = time.time()
#      59     timespam = end - init
#
# TypeError: Neural_Network.inverse() got an unexpected keyword argument 'algo'

# %% [markdown]
# Higher standard deviation likelihood

# %%
dim=4
#real_x = np.random.rand(dim)*5
real_x=np.array([1.,2.,3.,4.])
mean_prior = np.ones(dim)*2.5
cov_prior = np.ones(dim)*5*0.1  # like Manzoni paper -> 1% of the width of the ranges 
sigma=0.9
cov_noise=0.1
rwmh_cov = np.eye(len(real_x)) # !
rmwh_scaling = 0.1
rwmh_adaptive = False
iterations =5000
burnin = 3000
n_chains=4

# %%
estimate_MF=final_model.inverse(mean_prior, cov_prior=cov_prior, cov_noise=cov_noise, cov_likelihood=sigma**2*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive)
estimate_LF=modelLF.inverse(mean_prior, cov_prior=cov_prior, cov_noise=cov_noise, cov_likelihood=sigma**2*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive)
estimate_HF=modelHF.inverse(mean_prior, cov_prior=cov_prior, cov_noise=cov_noise, cov_likelihood=sigma**2*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive)
# Out:
# real values are [1. 2. 3. 4.]
# Sampling chain 1/4
# Running chain, α = 0.85: 100%|██████████| 5000/5000 [09:12<00:00,  9.06it/s]
# Sampling chain 2/4
# Running chain, α = 0.87: 100%|██████████| 5000/5000 [09:04<00:00,  9.18it/s]
# Sampling chain 3/4
# Running chain, α = 0.91: 100%|██████████| 5000/5000 [09:42<00:00,  8.58it/s]
# Sampling chain 4/4
# Running chain, α = 0.90: 100%|██████████| 5000/5000 [08:53<00:00,  9.37it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [2.085 2.425 2.425 2.546]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  2.085  0.643   0.889    3.242      0.095    0.069      46.0      97.0
# x1  2.425  0.588   1.316    3.584      0.100    0.076      35.0     145.0
# x2  2.425  0.599   1.364    3.610      0.072    0.052      71.0     130.0
# x3  2.546  0.685   1.166    3.845      0.103    0.074      46.0      70.0
#
#     r_hat
# x0   1.08
# x1   1.10
# x2   1.04
# x3   1.08
# Autocorrelation...
# the estimated values are [1.085 0.425 0.575 1.454]
#  the difference between outputs of two models are [0.72749555 0.28291968 0.28680997 0.70126291]
# The function inverse took 2242.0666694641113 seconds.
# real values are [1. 2. 3. 4.]
# Sampling chain 1/4
# Running chain, α = 0.87: 100%|██████████| 5000/5000 [04:19<00:00, 19.24it/s]
# Sampling chain 2/4
# Running chain, α = 0.88: 100%|██████████| 5000/5000 [04:09<00:00, 20.03it/s]
# Sampling chain 3/4
# Running chain, α = 0.92: 100%|██████████| 5000/5000 [04:58<00:00, 16.73it/s]
# Sampling chain 4/4
# Running chain, α = 0.89: 100%|██████████| 5000/5000 [04:34<00:00, 18.19it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [2.139 2.603 2.625 2.485]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  2.139  0.670   1.133    3.633      0.112    0.082      40.0      93.0
# x1  2.603  0.670   1.357    3.831      0.097    0.069      48.0      99.0
# x2  2.625  0.623   1.424    3.843      0.099    0.071      40.0      92.0
# x3  2.485  0.491   1.600    3.413      0.082    0.058      34.0     134.0
#
#     r_hat
# x0   1.08
# x1   1.05
# x2   1.09
# x3   1.11
# Autocorrelation...
# the estimated values are [1.139 0.603 0.375 1.515]
#  the difference between outputs of two models are [1.0638739  0.25236464 0.30844298 0.26118115]
# The function inverse took 1096.192230939865 seconds.
# real values are [1. 2. 3. 4.]
# Sampling chain 1/4
# Running chain, α = 0.91: 100%|██████████| 5000/5000 [04:30<00:00, 18.48it/s]
# Sampling chain 2/4
# Running chain, α = 0.92: 100%|██████████| 5000/5000 [04:41<00:00, 17.78it/s]
# Sampling chain 3/4
# Running chain, α = 0.93: 100%|██████████| 5000/5000 [04:20<00:00, 19.19it/s]
# Sampling chain 4/4
# Running chain, α = 0.85: 100%|██████████| 5000/5000 [04:05<00:00, 20.37it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [2.138 2.4   2.523 2.849]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  2.138  0.645   0.835    3.213      0.095    0.068      45.0     112.0
# x1  2.400  0.622   1.233    3.478      0.148    0.107      18.0      29.0
# x2  2.523  0.585   1.404    3.758      0.134    0.096      20.0      93.0
# x3  2.849  0.656   1.645    4.103      0.104    0.074      40.0     105.0
#
#     r_hat
# x0   1.11
# x1   1.17
# x2   1.15
# x3   1.12
# Autocorrelation...
# the estimated values are [1.138 0.4   0.477 1.151]
#  the difference between outputs of two models are [0.39209688 0.11457032 0.34820402 0.5388322 ]
# The function inverse took 1077.0690531730652 seconds.

# %% [markdown]
# ### Adaptive Metropolis Hastings

# %% [markdown]
# # MCMC using CuqiPy

# %%
dim=4
#real_x = np.random.rand(dim)*5
real_x=np.array([1.,2.,3.,4.])
mean_prior = np.ones(dim)*2.5
cov_prior = np.ones(dim)*5*0.1  # like Manzoni paper -> 1% of the width of the ranges 
sigma=0.2
#rwmh_cov = np.eye(len(real_x)) # !

iterations =4000
burnin = 3000
n_chains=2

# %%
estimate_MF=final_model.inverse_cuqi(mean_prior, sd_noise=sigma, proposal_sd=sigma*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True)
estimate_LF=modelLF.inverse_cuqi(mean_prior, sd_noise=sigma, proposal_sd=sigma*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True)
estimate_HF=modelHF.inverse_cuqi(mean_prior, sd_noise=sigma, proposal_sd=sigma*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True)
# Out:
# Sample 3840 / 4000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 estimate_MF=final_model.inverse_cuqi(mean_prior, sd_noise=sigma, proposal_sd=sigma*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True)
#       2 estimate_LF=modelLF.inverse_cuqi(mean_prior, sd_noise=sigma, proposal_sd=sigma*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True)
#       3 estimate_HF=modelHF.inverse_cuqi(mean_prior, sd_noise=sigma, proposal_sd=sigma*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True)
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\test_case\../utils\Structure.py:57, in compute_time.<locals>.wrapper(*args, **kwargs)
#      55 def wrapper(*args, **kwargs):
#      56     init = time.time()
# ---> 57     res = function(*args, **kwargs)
#      58     end = time.time()
#      59     timespam = end - init
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\test_case\../utils\Structure.py:473, in MultiFidelity.inverse_cuqi(self, mean_prior, x_real, y_obs, N, burn_in, sd_noise, proposal_sd, x_init, diagnostic, number_chains, algo)
#     454     y_obs=y_obs+np.random.normal(loc=0., scale=sd_noise,size=y_obs.shape)
#     459 # posterior=JointDistribution(y,x)(y=y_obs)
#     460
#     461 # sampler=MH(posterior,x0=x_init)   # rendere variabile per altri sampler
#    (...)
#     470 #     samples.plot_autocorrelation()
#     471 #     plot_hist(estimates,x_real, self.wrapper_prediction(mean), self.wrapper_prediction(x_real))
# --> 473 estimates= MCMC_cuqi(y,x,y_obs,N,burn_in,number_chains,diagnostic=diagnostic,algo=algo)
#     474 estimates=np.mean(estimates,axis=1)
#     475 if diagnostic is True:
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\test_case\module_utils.py:102, in MCMC_cuqi(y, x, observation, N, burn_in, n, diagnostic, algo)
#     100       else:
#     101           sampler=MH(posterior,x0=x_init[:,i])
# --> 102       samples=sampler.sample_adapt(N-burn_in,burn_in)
#     103       estimates=np.column_stack((estimates,samples.mean()[:, np.newaxis]))
#     104      # ESSs=np.column_stack((ESSs,samples.compute_ess()[:, np.newaxis]))
#     105 #      Rhat=np.column_stack((Rhat,samples.compute_rhat()[:, np.newaxis]))
#     106       #print(Geweke)
#     107       #Geweke=np.column_stack((Geweke,samples.diagnostics()[:, np.newaxis][0]))
#     108               # chains=np.concatenate(chains, samplesMH_LF.samples)
#     109       #printsamples.shape)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\cuqi\sampler\_sampler.py:97, in Sampler.sample_adapt(self, N, Nb)
#      95 def sample_adapt(self,N,Nb=0):
#      96     # Get samples from the samplers sample method
# ---> 97     result = self._sample_adapt(N,Nb)
#      98     return self._create_Sample_object(result,N+Nb)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\cuqi\sampler\_mh.py:136, in MH._sample_adapt(self, N, Nb)
#     133 # run MCMC
#     134 for s in range(Ns-1):
#     135     # run component by component
# --> 136     samples[:, s+1], target_eval[s+1], acc[s+1] = self.single_update(samples[:, s], target_eval[s])
#     138     # adapt prop spread using acc of past samples
#     139     if ((s+1) % Na == 0):
#     140         # evaluate average acceptance rate
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\cuqi\sampler\_mh.py:173, in MH.single_update(self, x_t, target_eval_t)
#     170 x_star = x_t + self.scale*xi.flatten()   # MH proposal
#     172 # evaluate target
# --> 173 target_eval_star = self.target.logd(x_star)
#     175 # ratio and acceptance probability
#     176 ratio = target_eval_star - target_eval_t  # proposal is symmetric
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\cuqi\distribution\_distribution.py:219, in Distribution.logd(self, *args, **kwargs)
#     215         return new_dist.logd(**main_params)
#     217 # Not conditional distribution, simply evaluate log density directly
#     218 else:
# --> 219     return super().logd(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\cuqi\density\_density.py:91, in Density.logd(self, *args, **kwargs)
#      88     # Ensure that the keyword arguments are given in the correct order and use them as positional arguments.
#      89     args = [kwargs[name] for name in par_names]
# ---> 91 return self._logd(*args) + self._constant
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\cuqi\distribution\_distribution.py:222, in Distribution._logd(self, *args)
#     221 def _logd(self, *args):
# --> 222     return self.logpdf(*args)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\cuqi\distribution\_posterior.py:86, in Posterior.logpdf(self, *args, **kwargs)
#      84 def logpdf(self, *args, **kwargs):
#      85     """ Returns the logpdf of the posterior distribution"""
# ---> 86     return self.likelihood.logd(*args, **kwargs)+ self.prior.logd(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\cuqi\density\_density.py:91, in Density.logd(self, *args, **kwargs)
#      88     # Ensure that the keyword arguments are given in the correct order and use them as positional arguments.
#      89     args = [kwargs[name] for name in par_names]
# ---> 91 return self._logd(*args) + self._constant
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\cuqi\likelihood\_likelihood.py:62, in Likelihood._logd(self, *args, **kwargs)
#      60 def _logd(self, *args, **kwargs):
#      61     """Return the log-likelihood function at given value"""
# ---> 62     return self.distribution(*args, **kwargs).logd(self.data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\cuqi\distribution\_distribution.py:351, in Distribution.__call__(self, *args, **kwargs)
#     350 def __call__(self, *args, **kwargs) -> Union[Distribution, Likelihood, EvaluatedDensity]:
# --> 351     return super().__call__(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\cuqi\density\_density.py:141, in Density.__call__(self, *args, **kwargs)
#     132 def __call__(self, *args, **kwargs):
#     133     """ Condition the density on a set of parameters.
#     134
#     135     Positional arguments must follow the order of the parameter names.
#    (...)
#     139
#     140     """
# --> 141     return self._condition(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\cuqi\distribution\_distribution.py:313, in Distribution._condition(self, *args, **kwargs)
#     310 # If any keywords matched we evaluate callable variable
#     311 if len(var_args)==len(accepted_keywords):  #All keywords found
#     312     # Define variable as the output of callable function
# --> 313     setattr(new_dist, var_key, var_val(**var_args))
#     315 elif len(var_args)>0:                      #Some keywords found
#     316     # Define new partial function with partially defined args
#     317     func = partial(var_val, **var_args)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\cuqi\model\_model.py:349, in Model.__call__(self, *args, **kwargs)
#     348 def __call__(self, *args, **kwargs):
# --> 349     return self.forward(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\cuqi\model\_model.py:343, in Model.forward(self, is_par, *args, **kwargs)
#     340     return new_model
#     342 # Else we apply the forward operator
# --> 343 return self._apply_func(self._forward_func,
#     344                         self.range_geometry,
#     345                         self.domain_geometry,
#     346                         x, is_par)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\cuqi\model\_model.py:273, in Model._apply_func(self, func, func_range_geometry, func_domain_geometry, x, is_par, **kwargs)
#     270 is_CUQIarray = type(x) is CUQIarray
#     272 x = self._2fun(x, func_domain_geometry, is_par=is_par)
# --> 273 out = func(x, **kwargs)
#     275 # Return output as parameters
#     276 # (and wrapped in CUQIarray if input was CUQIarray)
#     277 return self._2par(out, func_range_geometry,
#     278                             to_CUQIarray=is_CUQIarray)
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\test_case\../utils\Structure.py:378, in MultiFidelity.wrapper_prediction(self, x_test)
#     376 else:
#     377     x_final = x_test
# --> 378 return self.prediction(x_final)
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\test_case\../utils\Structure.py:366, in MultiFidelity.prediction(self, data_test)
#     363     self.outputs=self.outputs.reshape(-1,1)
#     364 for index, _ in enumerate(self.names):
#     365     #print("check")
# --> 366     self.outputs=np.c_[self.outputs,self.model_list[index].prediction(self.outputs)]
#     367 return self.outputs[:,-1]
#
# File c:\Users\Giacomo\Documents\GitHub\pacs_new\PACS_project2\test_case\../utils\Structure.py:139, in Neural_Network.prediction(self, x_test)
#     137 else:
#     138     with Suppressor():
# --> 139         y_pred = self.model.predict(x_test)[:,0]
#     140 return y_pred
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\engine\training.py:2620, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2611     except ValueError:
#    2612         warnings.warn(
#    2613             "Using Model.predict with MultiWorkerMirroredStrategy "
#    2614             "or TPUStrategy and AutoShardPolicy.FILE might lead to "
#    (...)
#    2617             stacklevel=2,
#    2618         )
# -> 2620 data_handler = data_adapter.get_data_handler(
#    2621     x=x,
#    2622     batch_size=batch_size,
#    2623     steps_per_epoch=steps,
#    2624     initial_epoch=0,
#    2625     epochs=1,
#    2626     max_queue_size=max_queue_size,
#    2627     workers=workers,
#    2628     use_multiprocessing=use_multiprocessing,
#    2629     model=self,
#    2630     steps_per_execution=self._steps_per_execution,
#    2631 )
#    2633 # Container that configures and calls `tf.keras.Callback`s.
#    2634 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\engine\data_adapter.py:1688, in get_data_handler(*args, **kwargs)
#    1686         return _ClusterCoordinatorExactEvalDataHandler(*args, **kwargs)
#    1687     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1688 return DataHandler(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\engine\data_adapter.py:1292, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute, pss_evaluation_shards)
#    1289     self._steps_per_execution = steps_per_execution
#    1291 adapter_cls = select_data_adapter(x, y)
# -> 1292 self._adapter = adapter_cls(
#    1293     x,
#    1294     y,
#    1295     batch_size=batch_size,
#    1296     steps=steps_per_epoch,
#    1297     epochs=epochs - initial_epoch,
#    1298     sample_weights=sample_weight,
#    1299     shuffle=shuffle,
#    1300     max_queue_size=max_queue_size,
#    1301     workers=workers,
#    1302     use_multiprocessing=use_multiprocessing,
#    1303     distribution_strategy=tf.distribute.get_strategy(),
#    1304     model=model,
#    1305     pss_evaluation_shards=pss_evaluation_shards,
#    1306 )
#    1308 strategy = tf.distribute.get_strategy()
#    1310 self._current_step = 0
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\engine\data_adapter.py:353, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     350         flat_dataset = flat_dataset.shuffle(1024).repeat(epochs)
#     351     return flat_dataset
# --> 353 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     355 dataset = self.slice_inputs(indices_dataset, inputs)
#     357 if shuffle == "batch":
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\data\ops\dataset_ops.py:2325, in DatasetV2.flat_map(self, map_func, name)
#    2321 # Loaded lazily due to a circular dependency (dataset_ops -> flat_map_op ->
#    2322 # dataset_ops).
#    2323 # pylint: disable=g-import-not-at-top,protected-access
#    2324 from tensorflow.python.data.ops import flat_map_op
# -> 2325 return flat_map_op._flat_map(self, map_func, name=name)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\data\ops\flat_map_op.py:24, in _flat_map(input_dataset, map_func, name)
#      22 def _flat_map(input_dataset, map_func, name=None):  # pylint: disable=unused-private-name
#      23   """See `Dataset.flat_map()` for details."""
# ---> 24   return _FlatMapDataset(input_dataset, map_func, name)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\data\ops\flat_map_op.py:42, in _FlatMapDataset.__init__(self, input_dataset, map_func, name)
#      40 self._structure = self._map_func.output_structure._element_spec
#      41 self._name = name
# ---> 42 variant_tensor = gen_dataset_ops.flat_map_dataset(
#      43     input_dataset._variant_tensor,  # pylint: disable=protected-access
#      44     self._map_func.function.captured_inputs,
#      45     f=self._map_func.function,
#      46     **self._common_args)
#      47 super().__init__(input_dataset, variant_tensor)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\ops\gen_dataset_ops.py:2369, in flat_map_dataset(input_dataset, other_arguments, f, output_types, output_shapes, metadata, name)
#    2367 if tld.is_eager:
#    2368   try:
# -> 2369     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    2370       _ctx, "FlatMapDataset", name, input_dataset, other_arguments, "f", f,
#    2371       "output_types", output_types, "output_shapes", output_shapes,
#    2372       "metadata", metadata)
#    2373     return _result
#    2374   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Reducing the standard deviation of the posterior

# %%
dim=4
#real_x = np.random.rand(dim)*5
real_x=np.array([1.,2.,3.,4.])
mean_prior = np.ones(dim)*2.5
cov_prior = np.ones(dim)*5*0.1  # like Manzoni paper -> 1% of the width of the ranges 
sigma=0.1
rwmh_cov = np.eye(len(real_x)) # !
rmwh_scaling = 0.1
rwmh_adaptive = False
iterations =5000
burnin = 1500
n_chains=2

# %%
estimate_MF=final_model.inverse(mean_prior, cov_prior=cov_prior, cov_noise=sigma, cov_likelihood=sigma*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive)
estimate_LF=modelLF.inverse(mean_prior, cov_prior=cov_prior, cov_noise=sigma, cov_likelihood=sigma*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive)
estimate_HF=modelHF.inverse(mean_prior, cov_prior=cov_prior, cov_noise=sigma, cov_likelihood=sigma*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive)
# Out:
# real values are [1. 2. 3. 4.]
# Sampling chain 1/2
# Running chain, α = 0.74: 100%|██████████| 5000/5000 [07:23<00:00, 11.27it/s]
# Sampling chain 2/2
# Running chain, α = 0.77: 100%|██████████| 5000/5000 [07:23<00:00, 11.28it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [1.382 2.264 2.611 3.256]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  1.382  0.385   0.666    2.116      0.042    0.031      83.0     152.0
# x1  2.264  0.453   1.453    3.107      0.058    0.041      62.0     198.0
# x2  2.611  0.433   1.759    3.374      0.079    0.057      28.0     210.0
# x3  3.256  0.448   2.366    4.054      0.059    0.042      59.0     131.0
#
#     r_hat
# x0   1.03
# x1   1.01
# x2   1.10
# x3   1.01
# Autocorrelation...
# the estimated values are [0.382 0.264 0.389 0.744]
#  the difference between outputs of two models are [0.21216381 0.18922609 0.21707673 0.3678261 ]
# The function inverse took 906.032173871994 seconds.
# real values are [1. 2. 3. 4.]
# Sampling chain 1/2
# Running chain, α = 0.78: 100%|██████████| 5000/5000 [03:49<00:00, 21.77it/s]
# Sampling chain 2/2
# Running chain, α = 0.74: 100%|██████████| 5000/5000 [03:47<00:00, 22.00it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [1.451 2.586 2.615 3.023]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  1.451  0.316   0.811    1.982      0.028    0.020     129.0     215.0
# x1  2.586  0.524   1.892    3.800      0.080    0.057      49.0     123.0
# x2  2.615  0.518   1.881    3.664      0.141    0.102      13.0      84.0
# x3  3.023  0.520   2.300    4.093      0.137    0.099      15.0     104.0
#
#     r_hat
# x0   1.01
# x1   1.04
# x2   1.10
# x3   1.12
# Autocorrelation...
# the estimated values are [0.451 0.586 0.385 0.977]
#  the difference between outputs of two models are [0.04838049 0.2191081  0.3401382  0.16070125]
# The function inverse took 472.1435754299164 seconds.
# real values are [1. 2. 3. 4.]
# Sampling chain 1/2
# Running chain, α = 0.72: 100%|██████████| 5000/5000 [03:45<00:00, 22.15it/s]
# Sampling chain 2/2
# Running chain, α = 0.87: 100%|██████████| 5000/5000 [03:45<00:00, 22.20it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [1.179 2.236 2.79  3.366]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  1.179  0.509   0.580    2.139      0.080    0.057      53.0     157.0
# x1  2.236  0.483   1.227    3.009      0.074    0.053      46.0     144.0
# x2  2.790  0.563   1.623    3.754      0.100    0.071      34.0      58.0
# x3  3.366  0.390   2.656    4.135      0.042    0.030      90.0     237.0
#
#     r_hat
# x0   1.05
# x1   1.02
# x2   1.05
# x3   1.03
# Autocorrelation...
# the estimated values are [0.179 0.236 0.21  0.634]
#  the difference between outputs of two models are [0.18956786 0.05577302 0.16692202 0.19767542]
# The function inverse took 462.08625316619873 seconds.

# %% [markdown]
# HF similar to MF, but more vaariance

# %% [markdown]
# ### Adding more chains

# %%
dim=4
#real_x = np.random.rand(dim)*5
real_x=np.array([1.,2.,3.,4.])
mean_prior = np.ones(dim)*2.5
cov_prior = np.ones(dim)*5*0.1  # like Manzoni paper -> 1% of the width of the ranges 
sigma=0.1
rwmh_cov = np.eye(len(real_x)) # !
rmwh_scaling = 0.1
rwmh_adaptive = False
iterations =5000
burnin = 1500
n_chains=4

# %%
estimate_MF=final_model.inverse(mean_prior, cov_prior=cov_prior, cov_noise=sigma, cov_likelihood=sigma*np.eye(real_x.shape[0]), y_obs=highfid(real_x), x_real=real_x, number_chains=n_chains, N=iterations, burn_in=burnin, diagnostic=True,rwmh_cov=rwmh_cov,rmwh_scaling=rmwh_scaling,rwmh_adaptive=rwmh_adaptive)
# Out:
# real values are [1. 2. 3. 4.]
# Sampling chain 1/4
# Running chain, α = 0.86: 100%|██████████| 5000/5000 [07:07<00:00, 11.71it/s]
# Sampling chain 2/4
# Running chain, α = 0.83: 100%|██████████| 5000/5000 [07:02<00:00, 11.83it/s]
# Sampling chain 3/4
# Running chain, α = 0.85: 100%|██████████| 5000/5000 [07:09<00:00, 11.64it/s]
# Sampling chain 4/4
# Running chain, α = 0.78: 100%|██████████| 5000/5000 [07:10<00:00, 11.61it/s]
# C:\Users\Giacomo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\arviz\data\inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# estimated values are [1.372 2.449 2.621 3.188]
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  1.372  0.380   0.664    2.100      0.030    0.021     161.0     291.0
# x1  2.449  0.442   1.646    3.313      0.036    0.026     151.0     291.0
# x2  2.621  0.412   1.862    3.417      0.031    0.022     175.0     411.0
# x3  3.188  0.479   2.253    4.015      0.044    0.031     120.0     338.0
#
#     r_hat
# x0   1.04
# x1   1.02
# x2   1.01
# x3   1.03
# Autocorrelation...
# the estimated values are [0.372 0.449 0.379 0.812]
#  the difference between outputs of two models are [0.20661545 0.28987908 0.21221758 0.3945763 ]
# The function inverse took 1713.010972738266 seconds.
