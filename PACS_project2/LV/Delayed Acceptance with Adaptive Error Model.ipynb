# %% [markdown]
# # Delayed Acceptance example: Predator/Prey model

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

from scipy.integrate import solve_ivp

import tinyDA as tda
# Out:
# Ray module not found. Multiprocessing features are not available

# %%
np.random.seed(987)

# %% [markdown]
# ### Define the predator/prey model
# We use scipy.integrate.solve_ivp to solve the predator-prey model. The method `dydx` is the differential equation.

# %%
class PredatorPreyModel:
    def __init__(self, datapoints, method):
        
        # set the timesteps, where we are collecting the model output
        self.datapoints = datapoints
        
        # set the span of the integration.
        self.t_span = [0, self.datapoints[-1]]
        
        # set the integration method
        self.method = method
        
    def dydx(self, t, y, a, b, c, d):
        # Lotka-Volterra Model model, see e.g. https://en.wikipedia.org/wiki/Lotka%E2%80%93Volterra_equations
        return np.array([a*y[0] - b*y[0]*y[1], c*y[0]*y[1] - d*y[1]])

    def __call__(self, parameters):
        
        # extract the parameters, and take the exponential to keep them positive
        P_0, Q_0, a, b, c, d = np.exp(parameters)
        
        # solve the initial value problem.
        self.y = solve_ivp(lambda t, y: self.dydx(t, y, a, b, c, d), self.t_span, np.array([P_0, Q_0]), t_eval=self.datapoints, method=self.method) 
        #print(self.y)
        # return the results, only if the integration succeeded.
        if self.y.success:
            return self.y.y.flatten(), True
        else:
            return np.nan, False

# %% [markdown]
# ### Set up the true model

# %%
# #set the true parameters
P_0 = 10
Q_0 = 5
a = 1.0
b = 0.3
c = 0.2
d = 1.0

# collect the parameters in a vector and take the logarithm. 
# we sample the log of the parameters and take the exponential
# inside the model to keep the parameters positive.
true_parameters = np.log(np.array([P_0, Q_0, a, b, c, d]))

# set the integration points.
t_span = [0,12]
n_eval = 1000
t_eval = np.linspace(t_span[0], t_span[1], n_eval)

# initalise the true model and solve it
my_model = PredatorPreyModel(t_eval, method='Radau')
y_true = my_model(true_parameters)[0]

# %%
print(y_true.shape)
# Out:
# (2000,)

# %% [markdown]
# ### Set up the forward models

# %%
n_data = 25 # number of datapoints
t_eval_data = np.linspace(t_span[0], t_span[1], n_data) # datapoints

# fine model
my_fine_model = PredatorPreyModel(t_eval_data, method='Radau') # initialise model

# coarse model
my_coarse_model = PredatorPreyModel(t_eval_data, method='RK45') # initialise model

# %%
my_fine_model

# %% [markdown]
# ### Generate data

# %%
my_fine_model(true_parameters)
# Out:
# (array([10.        ,  6.57748259,  3.6922253 ,  2.33178902,  1.83140775,
#          1.75538907,  1.95381603,  2.41031048,  3.17565686,  4.34210713,
#          6.00514994,  8.14071171, 10.25273816, 10.75187346,  8.14080857,
#          4.69981769,  2.75899055,  1.97328068,  1.74931386,  1.83982818,
#          2.1846049 ,  2.81085871,  3.79587954,  5.24065025,  7.19896882,
#          5.        ,  7.0129538 ,  7.01034148,  5.68834448,  4.22856589,
#          3.06057696,  2.22998373,  1.67863393,  1.34216966,  1.18102765,
#          1.19609226,  1.46756197,  2.24353618,  3.97961639,  6.35121938,
#          7.25961752,  6.3114866 ,  4.8185924 ,  3.5090429 ,  2.54114867,
#          1.88077371,  1.4607266 ,  1.22854058,  1.16597642,  1.31173989]),
#  True)

# %%
# set the noise level
sigma = 1.0

noise = np.random.normal(scale=sigma, size=(t_eval_data.size,2)) # fine noise
data = my_fine_model(true_parameters)[0] + np.hstack((noise[:,0], noise[:,1])) # noisy fine data, it gives to you the elements in a row.
data[data < 0] = 0 # make sure all the data is positive.

# %% [markdown]
# ### Plot the true model and the data

# %%
my_fine_model(true_parameters)
# Out:
# (array([10.        ,  6.57748259,  3.6922253 ,  2.33178902,  1.83140775,
#          1.75538907,  1.95381603,  2.41031048,  3.17565686,  4.34210713,
#          6.00514994,  8.14071171, 10.25273816, 10.75187346,  8.14080857,
#          4.69981769,  2.75899055,  1.97328068,  1.74931386,  1.83982818,
#          2.1846049 ,  2.81085871,  3.79587954,  5.24065025,  7.19896882,
#          5.        ,  7.0129538 ,  7.01034148,  5.68834448,  4.22856589,
#          3.06057696,  2.22998373,  1.67863393,  1.34216966,  1.18102765,
#          1.19609226,  1.46756197,  2.24353618,  3.97961639,  6.35121938,
#          7.25961752,  6.3114866 ,  4.8185924 ,  3.5090429 ,  2.54114867,
#          1.88077371,  1.4607266 ,  1.22854058,  1.16597642,  1.31173989]),
#  True)

# %%
y_coarse = PredatorPreyModel(t_eval, method='RK45')(true_parameters)[0]
fig, axes = plt.subplots(figsize=(16,5), nrows=1, ncols=2)

axes[0].set_title('Prey', fontsize=12)
axes[0].plot(t_eval, y_true[:n_eval], '--', color='cornflowerblue')
axes[0].plot(t_eval, y_coarse[:n_eval], '--', color='limegreen')
axes[0].scatter(t_eval_data, data[:n_data], color='tomato')
axes[0].tick_params(axis='both', labelsize=12)
axes[0].set_xlabel('Time', fontsize=12)
axes[0].set_ylim(0, 14); axes[0].set_ylabel('Density', fontsize=12)
#axes[0].legend(loc=2, fontsize=12)

axes[1].set_title('Predators', fontsize=12)
axes[1].plot(t_eval, y_true[n_eval:], '--', color='cornflowerblue', label='Fine model')
axes[1].plot(t_eval, y_coarse[n_eval:], '--', color='limegreen', label='Coarse model')
axes[1].scatter(t_eval_data, data[n_data:], color='tomato', label='Noisy data')
axes[1].tick_params(axis='both', labelsize=12)
axes[1].set_xlabel('Time', fontsize=12)
axes[1].set_ylim(0, 14); axes[1].set_ylabel('Density', fontsize=12)
axes[1].legend(loc=1, fontsize=12)

plt.show()

# %% [markdown]
# ### Set up the statistical model  and draw some samples from the prior
# We need a fairly well-informed prior, since the model is nonlinear and the data is quite noisy. Hence, we assume that we have pretty good knowledge about the birth- and death rates of the prey and predators, respectively. The predation rate and the growth rate for the predators are left to be fairly uncertain.

# %%
# prior distribution
mean_prior = np.array([np.log(data[0]), np.log(data[n_data]), 0, -1, -1.5, 0])
cov_prior = np.diag([0.1, 0.1, 0.001, 0.1, 0.1, 0.001])
my_prior = stats.multivariate_normal(mean_prior, cov_prior)

# draw some samples and plot them
prior_samples = np.exp(my_prior.rvs(1000))
fig, axes = plt.subplots(nrows=1, ncols=my_prior.dim, figsize = (8*my_prior.dim, 6))
for i in range(my_prior.dim):
    axes[i].set_title('Theta_{}'.format(i))
    axes[i].hist(prior_samples[:,i], color='c')

# %%
print(mean_prior)
print(true_parameters)
# Out:
# [ 2.39194855  1.39293952  0.         -1.         -1.5         0.        ]
# [ 2.30258509  1.60943791  0.         -1.2039728  -1.60943791  0.        ]

# %%
print(data.shape)
# Out:
# (50,)

# %%
# define the likelihood
cov_likelihood = sigma**2*np.eye(data.size)

my_loglike_fine = tda.GaussianLogLike(data, cov_likelihood)
my_loglike_coarse = tda.AdaptiveGaussianLogLike(data, cov_likelihood)

# %% [markdown]
# ### Set up the link factories and get the MAP point

# %%
# set up the link factories
my_posterior_coarse = tda.Posterior(my_prior, my_loglike_coarse, my_coarse_model)
my_posterior_fine = tda.Posterior(my_prior, my_loglike_fine, my_fine_model)

my_posteriors = [my_posterior_coarse, my_posterior_fine]

# %%
print(data)
# Out:
# [ 8.31407294  6.46568252  4.35326521  1.24846139  1.98968591  2.28219979
#   3.47734685  3.93624609  2.1412085   4.31752242  5.80266453  7.52157485
#  11.50040195  9.21425081  6.65213323  5.60170174  3.03111841  1.68928176
#   2.44825526  1.08662917  2.28683131  1.42433448  4.57050855  4.89819346
#   6.87725143  3.52888008  8.04932359  7.89325389  4.84121279  4.3276632
#   2.52888203  1.91499856  2.74268196  0.36102112  1.98744947  1.83916482
#   1.17502808  4.40654017  3.99557422  6.13101195  5.91189647  6.51908303
#   5.60864626  4.46915448  2.04025556  3.51696132  2.6094675   2.64128845
#   0.912178    2.15070393]

# %%
# get the maximum a posteriori point.
MAP = tda.get_MAP(my_posterior_fine)
# Out:
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 7.715e+00  4.483e+00 ...  1.966e+00  2.925e+00]
#             [ 4.073e+00  7.152e+00 ...  6.915e-01  6.315e-01]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 309
#      njev: 11
#       nlu: 50
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 7.715e+00  4.483e+00 ...  1.966e+00  2.925e+00]
#             [ 4.073e+00  7.152e+00 ...  6.915e-01  6.315e-01]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 309
#      njev: 11
#       nlu: 50
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 7.715e+00  4.483e+00 ...  1.966e+00  2.925e+00]
#             [ 4.073e+00  7.152e+00 ...  6.915e-01  6.315e-01]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 309
#      njev: 11
#       nlu: 50
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 7.715e+00  4.483e+00 ...  1.966e+00  2.925e+00]
#             [ 4.073e+00  7.152e+00 ...  6.915e-01  6.315e-01]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 309
#      njev: 11
#       nlu: 50
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 7.715e+00  4.483e+00 ...  1.966e+00  2.925e+00]
#             [ 4.073e+00  7.152e+00 ...  6.915e-01  6.315e-01]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 309
#      njev: 11
#       nlu: 50
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 7.715e+00  4.483e+00 ...  1.966e+00  2.925e+00]
#             [ 4.073e+00  7.152e+00 ...  6.915e-01  6.315e-01]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 309
#      njev: 11
#       nlu: 50
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 7.715e+00  4.483e+00 ...  1.966e+00  2.925e+00]
#             [ 4.073e+00  7.152e+00 ...  6.915e-01  6.315e-01]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 309
#      njev: 11
#       nlu: 50
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 9.026e+00  6.361e+00 ...  5.286e+00  7.025e+00]
#             [ 4.995e+00  6.735e+00 ...  1.419e+00  1.617e+00]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 264
#      njev: 10
#       nlu: 48
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 9.026e+00  6.361e+00 ...  5.286e+00  7.025e+00]
#             [ 4.995e+00  6.735e+00 ...  1.419e+00  1.617e+00]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 264
#      njev: 10
#       nlu: 48
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 9.026e+00  6.361e+00 ...  5.286e+00  7.025e+00]
#             [ 4.995e+00  6.735e+00 ...  1.419e+00  1.617e+00]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 264
#      njev: 10
#       nlu: 48
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 9.026e+00  6.361e+00 ...  5.286e+00  7.025e+00]
#             [ 4.995e+00  6.735e+00 ...  1.419e+00  1.617e+00]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 264
#      njev: 10
#       nlu: 48
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 9.026e+00  6.361e+00 ...  5.286e+00  7.025e+00]
#             [ 4.995e+00  6.735e+00 ...  1.419e+00  1.617e+00]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 264
#      njev: 10
#       nlu: 48

# %% [markdown]
# ### Set up the proposal

# %%
# random walk Metropolis
#rwmh_cov = np.eye(2)
#rmwh_scaling = 0.1
#rwmh_adaptive = True
#my_proposal = tda.GaussianRandomWalk(C=rwmh_cov, scaling=rmwh_scaling, adaptive=rwmh_adaptive)

# preconditioned Crank-Niconson
#pcn_scaling = 0.1
#pcn_adaptive = True
#my_proposal = tda.CrankNicolson(scaling=pcn_scaling, adaptive=pcn_adaptive)

# Adaptive Metropolis
am_cov = np.eye(true_parameters.size)
am_t0 = 100
am_sd = None
am_epsilon = 1e-6
am_adaptive = True
my_proposal = tda.AdaptiveMetropolis(C0=am_cov, t0=am_t0, sd=am_sd, epsilon=am_epsilon)

# %%
print(y_true.shape)
# Out:
# (2000,)

# %% [markdown]
# ### Sample

# %%
import os
if "CI" in os.environ:
    iterations = 120
    burnin = 20
else:
    iterations = 12000
    burnin = 2000

# %%
# initialise the chain
my_chain = tda.sample(my_posteriors, my_proposal, iterations=iterations, n_chains=2, initial_parameters=MAP, subsampling_rate=5, adaptive_error_model='state-independent')
# Out:
# Sampling chain 1/2
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 9.026e+00  6.368e+00 ...  5.276e+00  7.033e+00]
#             [ 4.995e+00  6.731e+00 ...  1.398e+00  1.591e+00]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 104
#      njev: 0
#       nlu: 0
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 9.026e+00  6.361e+00 ...  5.286e+00  7.025e+00]
#             [ 4.995e+00  6.735e+00 ...  1.419e+00  1.617e+00]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 264
#      njev: 10
#       nlu: 48
# Running chain, α_c = 0.143, α_f = 0.50:   0%|          | 0/12000 [00:00<?, ?it/s]
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 5.306e+00  1.198e-03 ...  8.222e-06  1.673e-05]
#             [ 1.151e+01  1.069e+01 ...  1.505e-01  1.241e-01]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 158
#      njev: 0
#       nlu: 0
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 7.288e+00  8.271e-04 ...  1.769e-06  2.827e-06]
#             [ 9.813e+00  8.561e+00 ...  1.498e-01  1.247e-01]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 164
#      njev: 0
#       nlu: 0
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 2.119e+01 -1.170e-07 ...  2.941e-05  1.397e-04]
#             [ 2.658e+01  2.704e+01 ...  6.506e-01  5.492e-01]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 296
#      njev: 0
#       nlu: 0
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 1.880e+00  4.912e+00 ...  4.966e+01  1.962e+01]
#             [ 3.400e+00  2.524e+00 ...  6.594e+00  1.947e+01]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 236
#      njev: 0
#       nlu: 0
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[
#      njev: 0
#       nlu: 0
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 9.129e+00  6.442e+00 ...  5.325e+00  7.145e+00]
#             [ 4.502e+00  6.529e+00 ...  1.284e+00  1.538e+00]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 92
#      njev: 0
#       nlu: 0
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 9.135e+00  6.490e+00 ...  5.423e+00  7.204e+00]
#             [ 4.217e+00  6.120e+00 ...  1.184e+00  1.424e+00]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 92
#      njev: 0
#       nlu: 0
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 8.807e+00  6.129e+00 ...  5.392e+00  7.243e+00]
#             [ 4.694e+00  6.512e+00 ...  1.360e+00  1.641e+00]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 98
#      njev: 0
#       nlu: 0
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 8.894e+00  5.954e+00 ...  5.708e+00  7.662e+00]
#             [ 4.895e+00  6.745e+00 ...  1.232e+00  1.546e+00]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 110
#      njev: 0
#       nlu: 0
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  5.000e-01 ...  1.150e+01  1.200e+01]
#         y: [[ 9.129e+00  6.444e+00 ...  5.258e+00  7.095e+00]
#             [ 4.502e+00  6.528e+00 ...  1.256e+00  1.498e+00]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 275
#      njev: 9
#       nlu: 48
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 2
#       1 # initialise the chain
# ----> 2 my_chain = tda.sample(my_posteriors, my_proposal, iterations=iterations, n_chains=2, initial_parameters=MAP, subsampling_rate=5, adaptive_error_model='state-independent')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\sampler.py:216, in sample(posteriors, proposal, iterations, n_chains, initial_parameters, subsampling_rate, adaptive_error_model, store_coarse_chain, force_sequential, force_progress_bar)
#     213 elif n_levels == 2:
#     214     # sequential sampling.
#     215     if not ray_is_available or n_chains == 1 or force_sequential:
# --> 216         samples = _sample_sequential_da(
#     217             posteriors,
#     218             proposal,
#     219             iterations,
#     220             n_chains,
#     221             initial_parameters,
#     222             subsampling_rate,
#     223             adaptive_error_model,
#     224             store_coarse_chain,
#     225         )
#     226     # parallel sampling.
#     227     else:
#     228         samples = _sample_parallel_da(
#     229             posteriors,
#     230             proposal,
#    (...)
#     237             force_progress_bar,
#     238         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\sampler.py:342, in _sample_sequential_da(posteriors, proposal, iterations, n_chains, initial_parameters, subsampling_rate, adaptive_error_model, store_coarse_chain)
#     330     print("Sampling chain {}/{}".format(i + 1, n_chains))
#     331     chains.append(
#     332         DAChain(
#     333             posteriors[0],
#    (...)
#     340         )
#     341     )
# --> 342     chains[i].sample(iterations)
#     344 info = {
#     345     "sampler": "DA",
#     346     "n_chains": n_chains,
#     347     "iterations": iterations + 1,
#     348     "subsampling_rate": subsampling_rate,
#     349 }
#     351 # collect the coarse samples.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\chain.py:322, in DAChain.sample(self, iterations, progressbar)
#     312     pbar.set_description(
#     313         "Running chain, \u03B1_c = {0:.3f}, \u03B1_f = {1:.2f}".format(
#     314             np.mean(
#    (...)
#     318         )
#     319     )
#     321 # run the coarse chain.
# --> 322 self._sample_coarse()
#     324 # if nothing was accepted on the coarse, repeat the previous sample.
#     325 if sum(self.accepted_coarse[-self.subsampling_rate :]) == 0:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\chain.py:384, in DAChain._sample_coarse(self)
#     381 proposal = self.proposal.make_proposal(self.chain_coarse[-1])
#     383 # create a link from that proposal.
# --> 384 proposal_link_coarse = self.posterior_coarse.create_link(proposal)
#     386 # compute the acceptance probability, which is unique to
#     387 # the proposal.
#     388 alpha_1 = self.proposal.get_acceptance(
#     389     proposal_link_coarse, self.chain_coarse[-1]
#     390 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tinyDA\posterior.py:80, in Posterior.create_link(self, parameters)
#      77 prior = self.prior.logpdf(parameters)
#      79 # get the model output and the qoi.
# ---> 80 model_output = self.model(parameters)
#      82 # extract model output and qoi.
#      83 if isinstance(model_output, tuple):
#
# Cell In[14], line 23, in PredatorPreyModel.__call__(self, parameters)
#      20 P_0, Q_0, a, b, c, d = np.exp(parameters)
#      22 # solve the initial value problem.
# ---> 23 self.y = solve_ivp(lambda t, y: self.dydx(t, y, a, b, c, d), self.t_span, np.array([P_0, Q_0]), t_eval=self.datapoints, method=self.method)
#      24 print(self.y)
#      25 # return the results, only if the integration succeeded.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\integrate\_ivp\ivp.py:650, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     648 status = None
#     649 while status is None:
# --> 650     message = solver.step()
#     652     if solver.status == 'finished':
#     653         status = 0
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\integrate\_ivp\base.py:197, in OdeSolver.step(self)
#     195 else:
#     196     t = self.t
# --> 197     success, message = self._step_impl()
#     199     if not success:
#     200         self.status = 'failed'
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\integrate\_ivp\rk.py:144, in RungeKutta._step_impl(self)
#     141 h = t_new - t
#     142 h_abs = np.abs(h)
# --> 144 y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     145                        self.B, self.C, self.K)
#     146 scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#     147 error_norm = self._estimate_error_norm(self.K, h, scale)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\integrate\_ivp\rk.py:66, in rk_step(fun, t, y, f, h, A, B, C, K)
#      63     dy = np.dot(K[:s].T, a[:s]) * h
#      64     K[s] = fun(t + c * h, y + dy)
# ---> 66 y_new = y + h * np.dot(K[:-1].T, B)
#      67 f_new = fun(t + h, y_new)
#      69 K[-1] = f_new
#
# KeyboardInterrupt:

# %% [markdown]
# ### Diagnostics

# %%
idata = tda.to_inference_data(my_chain, level='fine', burnin=burnin)
# Out:
# /home/mikkel/.cache/pypoetry/virtualenvs/tinyda-p_DUFDjW-py3.10/lib/python3.10/site-packages/arviz/data/inference_data.py:146: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(

# %%
import arviz as az

# %%
az.summary(idata)
# Out:
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  2.192  0.053   2.093    2.291      0.001    0.001    3714.0    5868.0
# x1  1.602  0.086   1.439    1.759      0.001    0.001    4125.0    6054.0
# x2 -0.006  0.026  -0.057    0.039      0.000    0.000    4010.0    6096.0
# x3 -1.253  0.057  -1.361   -1.148      0.001    0.001    4099.0    6919.0
# x4 -1.586  0.052  -1.683   -1.488      0.001    0.001    4339.0    6907.0
# x5 -0.013  0.026  -0.061    0.038      0.000    0.000    4276.0    6255.0
#
#     r_hat
# x0    1.0
# x1    1.0
# x2    1.0
# x3    1.0
# x4    1.0
# x5    1.0

# %%
az.plot_trace(idata)
plt.tight_layout()
plt.show()
